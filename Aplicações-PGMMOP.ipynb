# %% [markdown]
# <a href="https://colab.research.google.com/github/Andrezanincruz01/DissertacaoAndre/blob/main/Aplica%C3%A7%C3%B5es-PGMMOP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#==========================================================
# Multi-start do problema Das e Dennis (Não convexa)
#=========================================================
# !pip install pygmo # Use antes de rodar
import time  # Importa o módulo para medição de tempo
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize
import pygmo as pg  # Certifique-se de instalar o PyGMO (pip install pygmo)
from matplotlib.patches import Polygon
np.random.seed(40)
# ——————————————————————————————
# 1) Use MathText sem LaTeX externo, mas com Computer Modern
plt.rcParams['text.usetex']        = False
plt.rcParams['font.family']        = 'serif'
plt.rcParams['font.serif']         = ['Computer Modern']
plt.rcParams['mathtext.fontset']   = 'cm'
# ——————————————————————————————
#=======================================
# 1° FUNÇÃO: DAS & DENNIS (não convexa)
#========================================

def F(x):
    """
    Função principal (Das e Dennis – não convexa)
    Entrada: x em R^5
    Saída: [f1, f2]
      f1 = x[0]² + x[1]² + x[2]³ + x[3]² + x[4]⁵
      f2 = 3*x[0] + 2*x[1] - (x[2]/3) + 0.01*(x[3] - x[4])³
    """
    f1 = x[0]**2 + x[1]**2 + x[2]**3 + x[3]**2 + x[4]**5
    f2 = 3*x[0] + 2*x[1] - (x[2]/3) + 0.01*(x[3] - x[4])**3
    return [f1, f2]

def Dasdennisgrad(x):
    """
    Gradientes de f1 e f2.
    """
    grad_f1 = np.array([2*x[0], 2*x[1], 3*x[2]**2, 2*x[3], 5*x[4]**4])
    grad_f2 = np.array([3, 2, -1/3, 0.03*(x[3] - x[4])**2, -0.03*(x[3] - x[4])**2])
    return grad_f1, grad_f2

#=============================================
# FUNÇÕES AUXILIARES PARA A BUSCA
#==============================================

def Armijo_tamanho_passo(z, d, F, J, A_k, delta):
    """
    Seleciona tamanho de passo t através do critério de Armijo não-monótono do tipo máximo..
    Parâmetros:
    z : Ponto atual (x,y)
    d : Direção de busca obtida pelo SLSQP
    F : Função objetivo.
    J : Avaliação do gradiente em z na direção d
    A_k : Par (A₁, A₂) acumulado nas últimas iterações.
    delta : Parâmetro usado apenas em Armijo.

    Retorna: O maior tamanho de passo t=1/2^j (j = 0, 1, ...,19) que satisfaz a cond. de Armijo
        F(z + td) ≤ A_k + delta* t *J;
        retorna 1.0 se nenhum j satisfizer.
    """
    for j in range(20):
        t_val = 1/(2**j)
        z_next = z + t_val*d
        F_next = np.array(F(z_next))
        rhs = np.array(A_k) + delta*t_val*J
        if np.all(F_next <= rhs):
            return t_val
    return 1


def compute_A_k(f_values, k, M=10):
    """
    Calcula o valor de A_k para Armijo não-monótono.

    Parâmetros usados:
    f_values : Histórico de valores de F(z) (cada um sendo um vetor de dimensão 2).
    k : índice da iteração atual.
    M : Número máximo de iterações consideradas em A_k (M=10).

    Retorna:
    A_k : Par (A₁, A₂), onde cada componente é o máximo de F_j nas últimas min(k, M) iterações.
    """
    m_k = min(k, M)
    recentes = f_values[max(0, k-m_k) : k+1] #Seleciona o conjunto de valores F(z^j) desde j = k–m_k até j = k
    if not recentes:  # Caso k=0 e f_values tem só um elemento
        return f_values[-1]
    A1 = max(f[0] for f in recentes)
    A2 = max(f[1] for f in recentes)
    return (A1, A2)


def projecao_caixa(x, bounds):
    """
    Projeta x na caixa definida por bounds.
    """
    lower = np.array([b[0] for b in bounds])
    upper = np.array([b[1] for b in bounds])
    return np.clip(x, lower, upper)

# ======================================================================
# Busca da direção por função suave
# ======================================================================
def buscadirecao(x, bounds, tol_slsqp=1e-10):

    g1, g2 = Dasdennisgrad(x)

    dt0 = np.concatenate([np.zeros_like(x), [0.0]])  # ponto inicial na busca de direção

    # objetivo
    obj        = lambda dt: dt[-1] + 0.5*np.dot(dt[:-1], dt[:-1])
    obj_grad   = lambda dt: np.concatenate([dt[:-1], [1.0]])

    # restrições do epígrafe
    cons = [
        {'type':'ineq', 'fun': lambda dt: dt[-1] - np.dot(g1, dt[:-1])},
        {'type':'ineq', 'fun': lambda dt: dt[-1] - np.dot(g2, dt[:-1])},
    ]

    # caixa para garantir x+d dentro dos bounds
    for i,(lo,up) in enumerate(bounds):
        cons.append({'type':'ineq', 'fun': lambda dt,i=i,up=up:  up - (x[i] + dt[i])})
        cons.append({'type':'ineq', 'fun': lambda dt,i=i,lo=lo: (x[i] + dt[i]) - lo})

    res = minimize(obj, dt0, jac=obj_grad, constraints=cons,
                   method='SLSQP',
                   options={'ftol':tol_slsqp,'maxiter':500,'disp':False})

    d_opt = res.x[:-1]
    t_opt = res.x[-1]
    phi   = obj(res.x)
    return d_opt, t_opt, phi
#======================================================================
# PARÂMETROS GERAIS
#=======================================================================

bounds = [(-20, 20), (-20, 20), (-20, 20), (-20, 20), (-20, 20)]
#=========================================================
# algoritmo principal
# ==========================================================
def PGMMOP(x0, max_iter=50, M=10, delta=0.5,
                     tol_inner=1e-8, bounds=bounds):
    """
    Devolve:
      x*         – ponto final
      d_last     – direção da última iteração
      k          – nº de iterações executadas
      phi_last   – phi final
      F(x*)      – imagem final
      gamma_hist – histórico de phi(d^k)
    """
    x = x0.copy()
    f_vals, gamma_hist = [], []

    for k in range(max_iter):
        Fx = F(x)
        f_vals.append(Fx)

        # Chama a função que encontra a direção
        d, t, phi_val = buscadirecao(x, bounds)
        gamma_hist.append(phi_val)

        # critério de parada
        if np.linalg.norm(d) <= tol_inner:
            break
        A_k = compute_A_k(f_vals, k, M)
        J    = Dasdennisgrad(x)
        Jd   = np.array([np.dot(J[0], d), np.dot(J[1], d)])
        t    = Armijo_tamanho_passo(x, d, F, Jd, A_k, delta)


        x = projecao_caixa(x + t*d, bounds) #Atualização

    return x, d, k, phi_val, F(x), gamma_hist



#==================================
# LOOP DO MULTI-START
#===============================

num_starts = 50  # Quantidade de pontos iniciais a serem testados
solucoes = []          # Armazena os pontos ótimos x*
solucoes_imagens = []    # Armazena F(x*) para cada partida
all_details = []        # Para guardar detalhes (ponto inicial, x*, dk, iterações, final_phi, F(x*))

initial_points = []

# Registra o tempo de início do multi-start
start_time = time.time()

for i in range(num_starts):
    # Geração de um ponto inicial aleatório dentro dos bounds
    x_ini = np.random.uniform([b[0] for b in bounds], [b[1] for b in bounds])
    x_ini = projecao_caixa(x_ini, bounds)
    initial_points.append(x_ini)

print("===== Resultados Multi-Start =====")
for i, x0 in enumerate(initial_points):
    x_opt, subproblem_vec, iters, final_phi, Fx, gamma_historico = PGMMOP(x0)
    solucoes.append(x_opt)
    solucoes_imagens.append(Fx)
    all_details.append((x0, x_opt, subproblem_vec, iters, final_phi, Fx))
    print(f"\n--- Início {i+1} ---")
    print("Ponto inicial (após projeção):", x0)
    print("Ponto ótimo x*:", x_opt)
    print("Vetor do subproblema final:", subproblem_vec)
    print("Número de iterações:", iters)
    print("Valor final de φ:", final_phi)
    print("Imagem da solução ótima F(x*):", Fx)

# Registra o tempo final e calcula a diferença
end_time = time.time()
print("\nTempo de execução do multi-start: {:.4f} segundos".format(end_time - start_time))

#================================================
# GERAÇÃO DOS PONTOS PARA O ESPAÇO DOS OBJETIVOS
#===============================================

num_pontos = 1000000  # Quantidade de pontos a serem gerados na caixa
amostras = np.random.uniform(
    [b[0] for b in bounds],
    [b[1] for b in bounds],
    size=(num_pontos, len(bounds))
)
# Mapeamento para o espaço dos objetivos
objetivo_valor = np.array([F(amostra) for amostra in amostras])
f1_valor = objetivo_valor[:, 0]
f2_valor = objetivo_valor[:, 1]

#=================================
# Filtro de dominância
#=================================

def domina(sol1, sol2):
    """
    Retorna True se sol1 domina sol2:
    sol1 é <= sol2 em todas as componentes e
    sol1 é < sol2 em pelo menos uma componente
    """
    sol1, sol2 = np.array(sol1), np.array(sol2)
    return np.all(sol1 <= sol2) and np.any(sol1 < sol2)


solu_dominada, solu_naodominada = [], [] # Para separar as soluções encontradas em "dominadas" e "não dominadas"
for sol in solucoes_imagens: # percorre cada solução candidata
    dominado = False                      # assume que ainda não foi dominada
     # verifica dominância entre as próprias soluções do algoritmo
    for outro in solucoes_imagens:
        if not np.array_equal(sol, outro) and domina(outro, sol):
            dominado = True           # achou alguém que domina
            break                    # pode sair do processo interno
    #Aqui se ainda não foi dominado, vamos verificar contra todos os pontos gerados
    if not dominado:
        cond_all = np.all(objetivo_valor <= sol, axis=1) # verifica se cada valor objetivo <= 'sol' em todas as componentes. Devolve um vetor
        cond_any = np.any(objetivo_valor < sol, axis=1)  # O "objetivo_valor <= sol" é uma matriz de boolerianos n°pontos x 2 (f1,f2) e axis=1 é para operar ao longo das colunas, verifica f_1_1<=f_sol,f_1_2<=f_sol_1... e depois para f
        dominado = np.any(cond_all & cond_any)           # Faz o AND entre os vetores boolerianos
    if dominado:
      #coloca a solução na lista de dominado
       solu_dominada.append(sol)
    else:
      # coloca na lista de não dominado
      solu_naodominada.append(sol)

#========================================================
# PLOT DO ESPAÇO DOS OBJETIVOS E DAS SOLUÇÕES
#=========================================================
#Plot da figura
plt.figure(figsize=(8, 6))

# Pontos dos pontos gerados (em azul)
plt.scatter(f1_valor, f2_valor, alpha=0.5, s=10, marker='o', color="blue", label="Pontos Objetivo")

# Soluções dominadas (amarelo)
for sol in solu_dominada:
    plt.scatter(sol[0], sol[1], color="yellow", s=30, marker='o', edgecolor="black",
                label="Solução Dominada" if "Solução Dominada" not in plt.gca().get_legend_handles_labels()[1] else "")

# Soluções não dominadas (vermelho)
for sol in solu_naodominada:
    plt.scatter(sol[0], sol[1], color="red", s=30, marker='o', edgecolor="black",
                label="Solução Não Dominada" if "Solução Não Dominada" not in plt.gca().get_legend_handles_labels()[1] else "")

plt.title("Espaço dos Objetivos:\nPontos Gerados (Azul) e Soluções Multi-Start\nDominadas (Amarelo) vs. Não Dominadas (Vermelho)", fontsize=12)
plt.xlabel(r"$f_1(x)$", fontsize=12)
plt.ylabel(r"$f_2(x)$", fontsize=12)
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ===== Resultados Multi-Start =====
#
# --- Início 1 ---
# Ponto inicial (após projeção): [ -3.69251888 -17.7853584   11.5413951   -8.50779261  -1.98597652]
# Ponto ótimo x*: [-20.         -20.           2.60366935 -20.           3.68590732]
# Vetor do subproblema final: [-4.44414130e-15 -8.88828260e-16 -3.82439227e-02  1.28614912e-15
#   8.44376053e-04]
# Número de iterações: 49
# Valor final de φ: -0.0007316552904250749
# Imagem da solução ótima F(x*): [np.float64(1897.9843322307565), np.float64(-233.7510894780395)]
#
# --- Início 2 ---
# Ponto inicial (após projeção): [-7.84350779  1.05598097  4.95248852 11.07101831  7.44966581]
# Ponto ótimo x*: [-20.         -19.99007551   9.48958829   8.81938845   7.3545398 ]
# Vetor do subproblema final: [-4.82406472e-16 -1.05861181e-02  3.32030889e-01 -6.47814272e-02
#  -6.06402002e-03]
# Número de iterações: 49
# Valor final de φ: -0.07835301255369953
# Imagem da solução ótima F(x*): [np.float64(23248.73542219207), np.float64(-103.11191467331709)]
#
# --- Início 3 ---
# Ponto inicial (após projeção): [ 19.23755453   4.03264369  12.5587408    8.34580609 -18.89861279]
# Ponto ótimo x*: [-20.         -20.          17.60860756 -17.15197507 -18.90522936]
# Vetor do subproblema final: [ 1.41190537e-15  1.41190537e-15  3.33198129e-01 -9.23630893e-02
#  -4.90123089e-04]
# Número de iterações: 49
# Valor final de φ: -0.05977608656581707
# Imagem da solução ótima F(x*): [np.float64(-2408404.9818971795), np.float64(-105.81564255976718)]
#
# --- Início 4 ---
# Ponto inicial (após projeção): [ 16.17068869  -2.00380595 -15.24301384  13.41200704 -11.91007095]
# Ponto ótimo x*: [-20.         -20.           1.09933162 -11.33862335 -11.95198018]
# Vetor do subproblema final: [-2.81274774e-15 -3.75033032e-15  3.33333092e-01 -1.17186195e-02
#  -9.44303165e-06]
# Número de iterações: 49
# Valor final de φ: -0.05562413837592463
# Imagem da solução ótima F(x*): [np.float64(-242963.09926924753), np.float64(-100.3641363840497)]
#
# --- Início 5 ---
# Ponto inicial (após projeção): [-13.03189318  -2.03411681   6.79179122  18.29596436  13.33333003]
# Ponto ótimo x*: [-20.         -19.9861213   10.79818153  15.04045914  13.32404161]
# Vetor do subproblema final: [ 1.46388141e-15 -1.43264020e-02  3.33135098e-01 -8.86829899e-02
#  -7.25692493e-04]
# Número de iterações: 49
# Valor final de φ: -0.08797193675716515
# Imagem da solução ótima F(x*): [np.float64(422217.63597129757), np.float64(-103.52106924823758)]
#
# --- Início 6 ---
# Ponto inicial (após projeção): [ 0.3323986   5.20094191 13.40138744 -2.10673419 10.49161897]
# Ponto ótimo x*: [-20.         -20.          14.70445702 -20.          10.45689997]
# Vetor do subproblema final: [ 2.84053953e-15 -1.24831883e-15  3.13891277e-02  1.63916652e-16
#  -3.40571131e-04]
# Número de iterações: 49
# Valor final de φ: -0.0004926966635292559
# Imagem da solução ótima F(x*): [np.float64(129409.56762003935), np.float64(-387.4266204240006)]
#
# --- Início 7 ---
# Ponto inicial (após projeção): [  5.47688969  -5.50816424 -19.41701802   1.67939564  -7.27378076]
# Ponto ótimo x*: [-20.         -20.          -3.51637217  -7.11302861  -7.78787974]
# Vetor do subproblema final: [ 1.40640097e-15 -2.57840177e-15  3.33296707e-01 -1.41980365e-02
#  -8.23018744e-04]
# Número de iterações: 49
# Valor final de φ: -0.05564447848695389
# Imagem da solução ótima F(x*): [np.float64(-27841.007994587864), np.float64(-98.82480250927894)]
#
# --- Início 8 ---
# Ponto inicial (após projeção): [-14.20038611   1.95567789 -12.50074907  -4.04074095 -10.39847174]
# Ponto ótimo x*: [-20.         -20.           2.29907559  -9.79941637 -10.44472881]
# Vetor do subproblema final: [-2.34397655e-15  9.37590621e-16  3.33330014e-01 -1.25490428e-02
#  -9.16389916e-05]
# Número de iterações: 49
# Valor final de φ: -0.05563319249568466
# Imagem da solução ótima F(x*): [np.float64(-123396.03014140659), np.float64(-100.76367126859505)]
#
# --- Início 9 ---
# Ponto inicial (após projeção): [-18.53380589   2.74179029  16.91059196 -12.83779577   8.12310673]
# Ponto ótimo x*: [-20.         -20.          12.42858234 -20.           8.22226244]
# Vetor do subproblema final: [-2.37291556e-15 -4.18145726e-15 -1.51379152e-01 -4.62994910e-15
#   3.07117203e-03]
# Número de iterações: 49
# Valor final de φ: -0.011462539722488792
# Imagem da solução ótima F(x*): [np.float64(40699.83008288574), np.float64(-328.9320797816997)]
#
# --- Início 10 ---
# Ponto inicial (após projeção): [  8.8005118  -18.75743926   3.31301227   7.90710382  16.39413871]
# Ponto ótimo x*: [-20.         -20.           8.26365303 -20.          16.39015197]
# Vetor do subproblema final: [ 6.51752500e-15  2.09491875e-15  3.10796526e-01  9.51913072e-15
#  -1.76310223e-04]
# Número de iterações: 49
# Valor final de φ: -0.048297255809339065
# Imagem da solução ótima F(x*): [np.float64(1184574.0735328102), np.float64(-584.6486494075045)]
#
# --- Início 11 ---
# Ponto inicial (após projeção): [ 18.66791973  13.42918127  18.04485478   0.25302117 -12.22006473]
# Ponto ótimo x*: [-20.         -20.          20.         -11.55377661 -12.24281881]
# Vetor do subproblema final: [ 0.00000000e+00  0.00000000e+00  1.11010045e-16 -1.48577889e-02
#  -3.05445418e-06]
# Número de iterações: 49
# Valor final de φ: -0.00011042570401095514
# Imagem da solução ótima F(x*): [np.float64(-266113.6354898911), np.float64(-106.66339523800326)]
#
# --- Início 12 ---
# Ponto inicial (após projeção): [-17.21420985  17.03182682  -4.34694076  -3.67317087 -13.16379797]
# Ponto ótimo x*: [-20.         -20.           3.66141018 -12.04034684 -13.16708606]
# Vetor do subproblema final: [ 1.40725212e-15  4.69084040e-16  3.33323104e-01 -3.82414350e-02
#  -9.50611028e-05]
# Número de iterações: 49
# Valor final de φ: -0.05628335406924733
# Imagem da solução ótima F(x*): [np.float64(-394780.9580127901), np.float64(-101.20616563926673)]
#
# --- Início 13 ---
# Ponto inicial (após projeção): [-14.70619435   0.39922328  -6.37023405  -1.72321995 -18.05596101]
# Ponto ótimo x*: [-20.         -20.           3.00197993 -17.04802845 -18.05821752]
# Vetor do subproblema final: [ 4.68971881e-16  7.03457821e-16  3.33331788e-01 -3.08464879e-02
#  -1.86701563e-05]
# Número de iterações: 49
# Valor final de φ: -0.056030793449640064
# Imagem da solução ótima F(x*): [np.float64(-1919205.8284564188), np.float64(-100.99035117983284)]
#
# --- Início 14 ---
# Ponto inicial (após projeção): [ -9.73600416  16.8437457  -16.46585189   4.52067529  10.05316088]
# Ponto ótimo x*: [-20.         -20.         -16.29547222 -20.          10.03200793]
# Vetor do subproblema final: [-3.16519924e-15 -6.66475051e-15 -8.78353351e-02 -6.01499785e-15
#   1.36740393e-03]
# Número de iterações: 49
# Valor final de φ: -0.0038584579338409824
# Imagem da solução ótima F(x*): [np.float64(98483.53535720966), np.float64(-365.433312411044)]
#
# --- Início 15 ---
# Ponto inicial (após projeção): [-1.27029923  5.33771079 -2.85172581 18.32569982 15.19427426]
# Ponto ótimo x*: [-20.         -20.           3.7002654   16.25800239  15.19133435]
# Vetor do subproblema final: [-2.34510450e-15 -1.64157315e-15  3.33328056e-01 -3.42746557e-02
#  -4.70753426e-05]
# Número de iterações: 49
# Valor final de φ: -0.056141173648175335
# Imagem da solução ótima F(x*): [np.float64(810172.9020997962), np.float64(-101.22128545817641)]
#
# --- Início 16 ---
# Ponto inicial (após projeção): [-15.27195039 -16.90202366  15.80562419 -19.51671446   9.82971134]
# Ponto ótimo x*: [-20.         -20.          14.94730467 -20.           9.83602432]
# Vetor do subproblema final: [-1.11156392e-14 -9.55944973e-15 -4.91431667e-02 -1.68283837e-14
#   7.03844144e-04]
# Número de iterações: 49
# Valor final de φ: -0.0012077731217893398
# Imagem da solução ótima F(x*): [np.float64(96605.27879723701), np.float64(-370.57924669082735)]
#
# --- Início 17 ---
# Ponto inicial (após projeção): [-14.65111315 -14.08988203  -1.77160872  12.95307394  -3.9321437 ]
# Ponto ótimo x*: [-20.         -20.           3.78122399  -2.5613104   -4.16877465]
# Vetor do subproblema final: [ 1.87901457e-15  4.69753644e-16  3.30852511e-01 -7.76274392e-02
#  -9.64003819e-03]
# Número de iterações: 49
# Valor final de φ: -0.057791167072771286
# Imagem da solução ótima F(x*): [np.float64(-398.42450473071267), np.float64(-101.21887206250342)]
#
# --- Início 18 ---
# Ponto inicial (após projeção): [  6.34104313  -4.65735077  17.29040826 -14.34374091  14.66117042]
# Ponto ótimo x*: [-20.         -20.          19.37440796 -20.          14.64760174]
# Vetor do subproblema final: [ 1.63584809e-15 -9.75921910e-15  1.57148578e-01 -5.07743028e-15
#  -7.68779156e-04]
# Número de iterações: 49
# Valor final de φ: -0.012348133295696097
# Imagem da solução ótima F(x*): [np.float64(682740.6299729738), np.float64(-522.3874559298575)]
#
# --- Início 19 ---
# Ponto inicial (após projeção): [ -0.27323417 -14.67697204  15.05240907 -15.49136975   0.97010732]
# Ponto ótimo x*: [ -3.62254663 -16.6613037   11.06230845 -18.59101329   4.51135125]
# Vetor do subproblema final: [-2.92717805 -1.73293061 -2.65029913 -1.61027053  0.43246278]
# Número de iterações: 49
# Valor final de φ: -32.66458546587965
# Imagem da solução ótima F(x*): [np.float64(3858.7665514635546), np.float64(-171.1794495226193)]
#
# --- Início 20 ---
# Ponto inicial (após projeção): [ -8.64433171 -12.75013043   6.66795179   0.78577989  -8.41593017]
# Ponto ótimo x*: [-20.         -20.           9.70080316  -6.05831621  -8.46384601]
# Vetor do subproblema final: [-4.75219404e-16 -9.50438808e-16  3.31375614e-01 -1.74282094e-01
#  -3.72610964e-03]
# Número de iterações: 49
# Valor final de φ: -0.07009896487769912
# Imagem da solução ótima F(x*): [np.float64(-41685.29117053843), np.float64(-103.09440330199148)]
#
# --- Início 21 ---
# Ponto inicial (após projeção): [  8.43075024  18.63175798 -19.83102525 -11.28819789  -1.5494146 ]
# Ponto ótimo x*: [-12.52776662  -8.35036248 -20.         -20.           2.23076968]
# Vetor do subproblema final: [ 1.63774445e-04 -2.45712380e-04 -2.84217082e-14 -3.55271352e-15
#  -9.59523974e-10]
# Número de iterações: 49
# Valor final de φ: -4.3600146396902745e-08
# Imagem da solução ótima F(x*): [np.float64(-7318.083966128853), np.float64(-157.48340492537451)]
#
# --- Início 22 ---
# Ponto inicial (após projeção): [17.04423708 -3.83468584 16.17894751 16.41965495 -1.7400237 ]
# Ponto ótimo x*: [-20.         -20.          15.5779885    4.59007069   2.82211318]
# Vetor do subproblema final: [-4.46706428e-16 -8.93412856e-16  1.98817622e-02 -9.77731506e-02
#  -4.28021985e-02]
# Número de iterações: 49
# Valor final de φ: -0.005893450815483847
# Imagem da solução ótima F(x*): [np.float64(4780.445134133488), np.float64(-105.13740225034493)]
#
# --- Início 23 ---
# Ponto inicial (após projeção): [  9.91433412 -10.10626216  10.49100093  12.3037609   18.81509716]
# Ponto ótimo x*: [-20.         -20.          15.44404855 -20.          18.80936306]
# Vetor do subproblema final: [ 1.20043837e-14 -9.00328779e-15  2.81680079e-01 -8.39902931e-15
#  -3.22000345e-04]
# Número de iterações: 49
# Valor final de φ: -0.03967188503811802
# Imagem da solução ótima F(x*): [np.float64(2359230.5498284935), np.float64(-689.6817037842615)]
#
# --- Início 24 ---
# Ponto inicial (após projeção): [ 11.5893429    4.83124324 -18.02762767   3.95969799  -9.65940175]
# Ponto ótimo x*: [-20.         -20.          -1.78625897  -9.18366185  -9.80963534]
# Vetor do subproblema final: [-1.40638017e-15 -3.28155374e-15  3.33329658e-01 -1.22094482e-02
#  -1.04276911e-04]
# Número de iterações: 49
# Valor final de φ: -0.05562887136227531
# Imagem da solução ótima F(x*): [np.float64(-89958.68056608086), np.float64(-99.40212751205998)]
#
# --- Início 25 ---
# Ponto inicial (após projeção): [ -4.72352056   3.79918504  -9.8172486  -19.98293322 -11.77568606]
# Ponto ótimo x*: [-20.         -20.           2.61817807 -20.         -11.79418718]
# Vetor do subproblema final: [ 1.40609486e-15 -4.68698285e-16  3.32910526e-01  8.43627479e-16
#  -6.96770052e-05]
# Número de iterações: 49
# Valor final de φ: -0.05541471164062745
# Imagem da solução ótima F(x*): [np.float64(-226994.89502246215), np.float64(-106.39813995693697)]
#
# --- Início 26 ---
# Ponto inicial (após projeção): [-4.94774919 -0.01370321 -2.51085446 -3.05149469 -8.33590921]
# Ponto ótimo x*: [-20.         -20.           3.4457993   -7.05046747  -8.3721491 ]
# Vetor do subproblema final: [-9.38729261e-16 -9.38729261e-16  3.33256433e-01 -5.26332912e-02
#  -5.12254967e-04]
# Número de iterações: 49
# Valor final de φ: -0.05691518761863025
# Imagem da solução ótima F(x*): [np.float64(-40241.84532039996), np.float64(-101.12551207305847)]
#
# --- Início 27 ---
# Ponto inicial (após projeção): [  7.03190448   3.57551794  14.10306687 -19.76585168 -16.68753572]
# Ponto ótimo x*: [-20.         -19.93690747  18.64595514 -20.         -16.69895005]
# Vetor do subproblema final: [-6.38009495e-16 -6.51277763e-02  3.32454623e-01  1.10292486e-15
#  -8.98169383e-04]
# Número de iterações: 49
# Valor final de φ: -0.18339588152374345
# Imagem da solução ótima F(x*): [np.float64(-1290831.4343602262), np.float64(-106.44884644103695)]
#
# --- Início 28 ---
# Ponto inicial (após projeção): [  0.67443888  -9.09558805   1.40416409 -15.33287823  12.52955805]
# Ponto ótimo x*: [-20.         -20.           5.64401141 -20.          12.52031435]
# Vetor do subproblema final: [-3.74128441e-10 -4.74507048e-09  3.08744715e-01  8.78195841e-15
#  -2.39276060e-04]
# Número de iterações: 49
# Valor final de φ: -0.04766168894342601
# Imagem da solução ótima F(x*): [np.float64(309043.42285641667), np.float64(-445.8067005855037)]
#
# --- Início 29 ---
# Ponto inicial (após projeção): [ 16.77514919  19.69099688 -10.3296125    9.35183132 -17.97175276]
# Ponto ótimo x*: [-20.         -20.           2.61407126 -17.21482948 -17.97490739]
# Vetor do subproblema final: [ 4.68828190e-16  1.17207047e-15  3.33332658e-01 -1.74298240e-02
#  -1.40407432e-05]
# Número de iterações: 49
# Valor final de φ: -0.05570723015732796
# Imagem da solução ótima F(x*): [np.float64(-1875319.844588173), np.float64(-100.86696597569184)]
#
# --- Início 30 ---
# Ponto inicial (após projeção): [-8.51438765 12.71664931 -1.67319288 -3.44147212 -9.32906834]
# Ponto ótimo x*: [-20.         -20.           5.03410328  -8.11334567  -9.34908018]
# Vetor do subproblema final: [-4.69217109e-16 -1.17304277e-15  3.33240741e-01 -4.60015646e-02
#  -6.80283925e-04]
# Número de iterações: 49
# Valor final de φ: -0.05658299908598024
# Imagem da solução ótima F(x*): [np.float64(-70430.63999271361), np.float64(-101.6591642689605)]
#
# --- Início 31 ---
# Ponto inicial (após projeção): [-14.32335907   8.29459296  -3.42212979  -1.29763183  -4.3309856 ]
# Ponto ótimo x*: [-20.         -20.           4.10831575  -3.57601099  -4.65533477]
# Vetor do subproblema final: [-9.37823410e-16  1.17227926e-15  3.32431743e-01 -3.50445218e-02
#  -7.18314153e-03]
# Número de iterações: 49
# Valor final de φ: -0.05589528990208101
# Imagem da solução ótima F(x*): [np.float64(-1304.3966144424467), np.float64(-101.3568651105783)]
#
# --- Início 32 ---
# Ponto inicial (após projeção): [ -7.41155096  -6.57060661 -17.10009905   7.62000026 -15.07622508]
# Ponto ótimo x*: [-20.         -20.          -0.66872796 -14.48841092 -15.09965233]
# Vetor do subproblema final: [-2.34395442e-15 -9.37581768e-16  3.33333184e-01 -1.16378503e-02
#  -5.58763501e-06]
# Número de iterações: 49
# Valor final de φ: -0.0556232254118311
# Imagem da solução ótima F(x*): [np.float64(-783927.2725281079), np.float64(-99.77480698288682)]
#
# --- Início 33 ---
# Ponto inicial (após projeção): [  4.23788818  14.37153189 -19.48111859   6.45763266 -11.5014737 ]
# Ponto ótimo x*: [-20.         -20.          -3.1873279  -10.97171737 -11.59410293]
# Vetor do subproblema final: [ 4.68792422e-16  9.37584844e-16  3.33328262e-01 -1.20675786e-02
#  -1.41355849e-04]
# Número de iterações: 49
# Valor final de φ: -0.05562668830215644
# Imagem da solução ótima F(x*): [np.float64(-208612.83660842184), np.float64(-98.93514647094676)]
#
# --- Início 34 ---
# Ponto inicial (após projeção): [  5.40909578  -9.63293433 -17.66487809  -8.34272012  19.12260009]
# Ponto ótimo x*: [-20.         -20.          -2.44608237 -20.          19.11225337]
# Vetor do subproblema final: [-1.59297586e-14 -1.40556693e-15  3.31718116e-01 -4.74420095e-15
#  -1.16748999e-05]
# Número de iterações: 49
# Valor final de φ: -0.05501845394857053
# Imagem da solução ótima F(x*): [np.float64(2551298.6313304952), np.float64(-697.5115174699956)]
#
# --- Início 35 ---
# Ponto inicial (após projeção): [ -6.94376523 -15.19651902   0.1045131    1.00435537  15.71841142]
# Ponto ótimo x*: [-20.         -20.           4.96676155 -20.          15.71427025]
# Vetor do subproblema final: [ 2.00986344e-14  9.11449701e-15  3.24080175e-01  1.80982143e-14
#  -7.83676244e-05]
# Número de iterações: 49
# Valor final de φ: -0.05251398266831191
# Imagem da solução ótima F(x*): [np.float64(959555.4478450735), np.float64(-557.1943540474807)]
#
# --- Início 36 ---
# Ponto inicial (após projeção): [ 11.12722937 -15.97936088 -10.81609278   1.08127939  10.16116949]
# Ponto ótimo x*: [-20.         -20.           2.13430404 -20.          10.11826177]
# Vetor do subproblema final: [ 1.35643426e-14  6.54830334e-15  3.26336416e-01  1.93664998e-14
#  -8.39053468e-05]
# Número de iterações: 49
# Valor final de φ: -0.053247731417079364
# Imagem da solução ótima F(x*): [np.float64(107264.33327714354), np.float64(-373.9171063864523)]
#
# --- Início 37 ---
# Ponto inicial (após projeção): [ 12.13027733  15.77039765 -14.71438616  11.78529044   9.5120201 ]
# Ponto ótimo x*: [-20.         -20.           1.76770226   9.94527398   9.42061847]
# Vetor do subproblema final: [ 4.68776785e-16 -9.37553569e-16  3.33331916e-01 -8.53135796e-03
#  -5.07530583e-05]
# Número de iterações: 49
# Valor final de φ: -0.05559147653921203
# Imagem da solução ótima F(x*): [np.float64(75103.26566427796), np.float64(-100.58778990083289)]
#
# --- Início 38 ---
# Ponto inicial (após projeção): [-9.53188204  9.5779994  10.69311178  7.07275979 16.50434315]
# Ponto ótimo x*: [-20.         -19.97999549  15.67169648 -20.          16.49418772]
# Vetor do subproblema final: [ 5.41851404e-15 -2.06498173e-02  2.53837857e-01  2.67749529e-14
#  -5.07379197e-04]
# Número de iterações: 49
# Valor final de φ: -0.0732098508128152
# Imagem da solução ótima F(x*): [np.float64(1225876.7182526994), np.float64(-591.2228746513937)]
#
# --- Início 39 ---
# Ponto inicial (após projeção): [ -2.17531122  -6.6297367    9.24222734 -16.49607156   8.29299792]
# Ponto ótimo x*: [-20.         -20.          10.03447857 -20.           8.2437939 ]
# Vetor do subproblema final: [ 4.43997643e-16  6.88196347e-15  2.03011962e-02  7.10396229e-15
#  -2.65537913e-04]
# Número de iterações: 49
# Valor final de φ: -0.00020627459638674817
# Imagem da solução ótima F(x*): [np.float64(40285.00378473271), np.float64(-328.6489294988388)]
#
# --- Início 40 ---
# Ponto inicial (após projeção): [ -3.74166014   3.0745075  -10.22825127  -9.74708124  -7.91744528]
# Ponto ótimo x*: [-20.         -20.           2.60286143 -20.          -8.02793053]
# Vetor do subproblema final: [-2.80890670e-15 -1.40445335e-15  3.29188542e-01  4.56315974e-16
#  -3.17287399e-04]
# Número de iterações: 49
# Valor final de φ: -0.05418259820805055
# Imagem da solução ótima F(x*): [np.float64(-32126.39124243516), np.float64(-118.02724122517529)]
#
# --- Início 41 ---
# Ponto inicial (após projeção): [-19.61435695 -11.04573451  -4.20681141 -16.75505405 -18.77514754]
# Ponto ótimo x*: [-20.         -20.           3.1681474  -17.92997269 -18.77587395]
# Vetor do subproblema final: [ 4.68863639e-16 -9.22459430e-27  3.33332292e-01 -2.15335310e-02
#  -1.73628582e-05]
# Número de iterações: 49
# Valor final de φ: -0.0557870547846256
# Imagem da solução ótima F(x*): [np.float64(-2332309.1051823534), np.float64(-101.04999629430866)]
#
# --- Início 42 ---
# Ponto inicial (após projeção): [ 12.26711567  -6.07284391 -19.88499965  15.34748139  -6.23414825]
# Ponto ótimo x*: [-20.         -20.          -5.14992719  -6.32828416  -7.08673664]
# Vetor do subproblema final: [ 1.87524798e-15  2.34405997e-15  3.33186805e-01 -1.79513994e-02
#  -2.41299276e-03]
# Número de iterações: 49
# Valor final de φ: -0.05567076120401253
# Imagem da solução ótima F(x*): [np.float64(-17170.93776094597), np.float64(-98.27899460526399)]
#
# --- Início 43 ---
# Ponto inicial (após projeção): [-3.56719964 19.45334352 -7.64700221 12.93939746  2.62735255]
# Ponto ótimo x*: [-20.         -20.          -8.45247301   2.7402617    1.62890649]
# Vetor do subproblema final: [ 1.33386059e-15 -2.22310099e-16  3.97329508e-03 -4.56601854e-02
#  -1.70503544e-02]
# Número de iterações: 49
# Valor final de φ: -0.001195677096210569
# Imagem da solução ótima F(x*): [np.float64(215.09583411809902), np.float64(-97.16878253253503)]
#
# --- Início 44 ---
# Ponto inicial (após projeção): [  2.77422207 -11.5070468   -3.864541     7.57078691   4.6997471 ]
# Ponto ótimo x*: [-20.         -20.           3.17660584   5.42272267   4.35240522]
# Vetor do subproblema final: [-9.37871569e-16  4.68935785e-16  3.32662158e-01 -3.47255036e-02
#  -5.39008236e-03]
# Número de iterações: 49
# Valor final de φ: -0.05594951220687102
# Imagem da solução ótima F(x*): [np.float64(2423.336719234319), np.float64(-101.04660727558569)]
#
# --- Início 45 ---
# Ponto inicial (após projeção): [ 16.3447265  -18.70816886 -11.89500981  -2.19103832  19.79455488]
# Ponto ótimo x*: [-20.         -20.           2.32456885 -20.          19.79121632]
# Vetor do subproblema final: [ 1.68701284e-14  2.81168806e-15  3.32344525e-01 -6.56359286e-15
#  -6.91839363e-06]
# Número de iterações: 49
# Valor final de φ: -0.055226441400831446
# Imagem da solução ótima F(x*): [np.float64(3037636.6560721584), np.float64(-730.8054575947039)]
#
# --- Início 46 ---
# Ponto inicial (após projeção): [-19.62324877 -18.70796795   5.94791012  13.97611895   7.00630589]
# Ponto ótimo x*: [-20.         -20.           8.09981341   9.81584295   6.98231487]
# Vetor do subproblema final: [-5.47865658e-16 -1.63778450e-15  3.29233406e-01 -2.43816230e-01
#  -5.03480544e-03]
# Número de iterações: 49
# Valor final de φ: -0.08393316947889577
# Imagem da solução ótima F(x*): [np.float64(18023.51512367836), np.float64(-102.47243719279228)]
#
# --- Início 47 ---
# Ponto inicial (após projeção): [ -1.65079213 -12.88980872  -1.22306407  -9.46744567  13.05778951]
# Ponto ótimo x*: [-20.         -20.           3.75118613 -20.          13.04989113]
# Vetor do subproblema final: [-1.35538216e-14 -7.01059740e-15  3.23823377e-01 -2.69565430e-15
#  -9.39775281e-05]
# Número de iterações: 49
# Valor final de φ: -0.052430794035321304
# Imagem da solução ótima F(x*): [np.float64(379725.3836554881), np.float64(-462.2528040806445)]
#
# --- Início 48 ---
# Ponto inicial (após projeção): [ 8.69888367  9.01862738 -1.57216592  9.47296881 10.43703098]
# Ponto ótimo x*: [-20.         -20.           4.75028336   8.38648387  10.4244853 ]
# Vetor do subproblema final: [ 9.44274844e-16  4.72137422e-16  3.33191704e-01 -1.23697559e-01
#  -3.45625987e-04]
# Número de iterações: 49
# Valor final de φ: -0.06315895857661906
# Imagem da solução ótima F(x*): [np.float64(124081.79111014966), np.float64(-101.66807515384534)]
#
# --- Início 49 ---
# Ponto inicial (após projeção): [-13.24059008  -4.60369513   3.54288586   6.23560506   1.75060024]
# Ponto ótimo x*: [-1.42726416e+01 -9.51432923e+00  1.02820564e+00 -1.34168125e-02
#   2.98809632e-01]
# Vetor do subproblema final: [ 8.19033384e-05 -1.25118852e-04  3.33510881e-08 -1.38628203e-04
#  -1.18730025e-03]
# Número de iterações: 49
# Valor final de φ: -7.256333830423626e-07
# Imagem da solução ótima F(x*): [np.float64(295.320346132442), np.float64(-62.18962274096719)]
#
# --- Início 50 ---
# Ponto inicial (após projeção): [ -1.9448994    1.1661439  -15.09215525  -7.30719878  12.96665607]
# Ponto ótimo x*: [-20.         -20.          -1.94297219 -20.          12.93253431]
# Vetor do subproblema final: [ 1.87287569e-15  1.87287569e-15  3.29652188e-01  8.15142983e-16
#  -3.72963105e-05]
# Número de iterações: 49
# Valor final de φ: -0.05433528324466751
# Imagem da solução ótima F(x*): [np.float64(362950.70922184974), np.float64(-456.5227416869468)]
#
# Tempo de execução do multi-start: 19.9898 segundos
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern

# %%
#==========================================================
# Multi-start do problema JOS-1 ( convexa)
#=========================================================
#!pip install pygmo # Use antes de rodar
import time  # Importa o módulo para medição de tempo
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize
import pygmo as pg  # Certifique-se de instalar o PyGMO (pip install pygmo)
from matplotlib.patches import Polygon
np.random.seed(42)
# ——————————————————————————————
# 1) Use MathText sem LaTeX externo, mas com Computer Modern
plt.rcParams['text.usetex']        = False
plt.rcParams['font.family']        = 'serif'
plt.rcParams['font.serif']         = ['Computer Modern']
plt.rcParams['mathtext.fontset']   = 'cm'
# ——————————————————————————————
#=======================================
# 2° FUNÇÃO: JOS1 (convexa)
#========================================

def F(x):
    """f(x) = [(1/5)∑x_i² , (1/5)∑(x_i-2)²]"""
    return [
        0.2*np.sum(x**2),
        0.2*np.sum((x-2)**2)
    ]

def JOS_grad(x):
    """∇f₁ , ∇f₂"""
    g1 = 0.4 * x
    g2 = 0.4 * (x - 2)
    return g1, g2

#=============================================
# FUNÇÕES AUXILIARES PARA A BUSCA (φ, etc.)
#==============================================

def Armijo_tamanho_passo(z, d, F, J, A_k, delta):
    """
    Seleciona tamanho de passo t através do critério de Armijo não-monótono do tipo máximo..
    Parâmetros:
    z : Ponto atual (x,y)
    d : Direção de busca obtida pelo SLSQP
    F : Função objetivo.
    J : Avaliação do gradiente em z na direção d.
    A_k : Par (A₁, A₂) acumulado nas últimas iterações.
    delta : Parâmetro usado apenas em Armijo.

    Retorna: O maior tamanho de passo t=1/2^j (j = 0, 1, ...,20) que satisfaz a cond. de Armijo
        F(z + td) ≤ A_k + δ t J;
        retorna 1.0 se nenhum j satisfizer.
    """
    for j in range(20):
        t_val = 1/(2**j)
        z_next = z + t_val*d
        F_next = np.array(F(z_next))
        rhs = np.array(A_k) + delta*t_val*J
        if np.all(F_next <= rhs):
            return t_val
    return 1


def compute_A_k(f_values, k, M=10):
    """
    Calcula o valor de A_k para Armijo não-monótono.

    Parâmetros usados:
    f_values : Histórico de valores de F(z) (cada um sendo um vetor de dimensão 2).
    k : índice da iteração atual.
    M : Número máximo de iterações consideradas em A_k (M=10).

    Retorna:
    A_k : Par (A₁, A₂), onde cada componente é o máximo de F_j nas últimas min(k, M) iterações.
    """
    m_k = min(k, M)
    recentes = f_values[max(0, k-m_k) : k+1] #Seleciona o conjunto de valores F(z^j) desde j = k–m_k até j = k
    if not recentes:  # Caso k=0 e f_values tem só um elemento
        return f_values[-1]
    A1 = max(f[0] for f in recentes)
    A2 = max(f[1] for f in recentes)
    return (A1, A2)


def projecao_caixa(x, bounds):
    """
    Projeta x na caixa definida por bounds.
    """
    lower = np.array([b[0] for b in bounds])
    upper = np.array([b[1] for b in bounds])
    return np.clip(x, lower, upper)

# ======================================================================
# FUNÇÃO  de DIREÇÃO  (sub-problema suave com variável auxiliar t)
# ======================================================================
def buscadirecao(x, bounds, tol_slsqp=1e-10):
    """

    """
    g1, g2 = JOS_grad(x)

    dt0 = np.concatenate([np.zeros_like(x), [0.0]])  # ponto inicial na busca de direção

    # objetivo
    obj        = lambda dt: dt[-1] + 0.5*np.dot(dt[:-1], dt[:-1])
    obj_grad   = lambda dt: np.concatenate([dt[:-1], [1.0]])

    # restrições do epígrafe
    cons = [
        {'type':'ineq', 'fun': lambda dt: dt[-1] - np.dot(g1, dt[:-1])},
        {'type':'ineq', 'fun': lambda dt: dt[-1] - np.dot(g2, dt[:-1])},
    ]

    # caixa para garantir x+d dentro dos bounds
    for i,(lo,up) in enumerate(bounds):
        cons.append({'type':'ineq', 'fun': lambda dt,i=i,up=up:  up - (x[i] + dt[i])})
        cons.append({'type':'ineq', 'fun': lambda dt,i=i,lo=lo: (x[i] + dt[i]) - lo})

    res = minimize(obj, dt0, jac=obj_grad, constraints=cons,
                   method='SLSQP',
                   options={'ftol':tol_slsqp,'maxiter':500,'disp':False})

    d_opt = res.x[:-1]
    t_opt = res.x[-1]
    phi   = obj(res.x)
    return d_opt, t_opt, phi
#======================================================================
# PARÂMETROS GERAIS
#=======================================================================

bounds     = [(-2,2)]*5          # caixa em R⁵
#=========================================================
# algoritmo principal
# ==========================================================
def PGMMOP(x0, max_iter=50, M=10, delta=0.5,
                     tol_inner=1e-8, bounds=bounds):
    """
    Devolve:
      x*         – ponto final
      d_last     – direção da última iteração
      k          – nº de iterações executadas
      phi_last   – φ final
      F(x*)      – imagem final
      gamma_hist – histórico de φ(d^k)
    """
    x = x0.copy()
    f_vals, gamma_hist = [], []

    for k in range(max_iter):
        Fx = F(x)
        f_vals.append(Fx)

        # Chama a função que encontra a direção
        d, t, phi_val = buscadirecao(x, bounds)
        gamma_hist.append(phi_val)

        # ---- critério de parada:  ‖d‖ ----
        if np.linalg.norm(d) <= tol_inner:
            break
        A_k = compute_A_k(f_vals, k, M)
        J    = Dasdennisgrad(x)
        Jd   = np.array([np.dot(J[0], d), np.dot(J[1], d)])
        t    = Armijo_tamanho_passo(x, d, F, Jd, A_k, delta)


        x = projecao_caixa(x + t*d, bounds) #Atualização

    return x, d, k, phi_val, F(x), gamma_hist



#==================================
# LOOP DO MULTI-START
#===============================

num_starts = 50  # Quantidade de pontos iniciais a serem testados
solucoes = []          # Armazena os pontos ótimos x*
solucoes_imagens = []    # Armazena F(x*) para cada partida
all_details = []        # Para guardar detalhes (ponto inicial, x*, dk, iterações, final_phi, F(x*))

initial_points = []

# Registra o tempo de início do multi-start
start_time = time.time()

for i in range(num_starts):
    # Geração de um ponto inicial aleatório dentro dos bounds
    x_ini = np.random.uniform([b[0] for b in bounds], [b[1] for b in bounds])
    x_ini = projecao_caixa(x_ini, bounds)
    initial_points.append(x_ini)

print("===== Resultados Multi-Start =====")
for i, x0 in enumerate(initial_points):
    x_opt, subproblem_vec, iters, final_phi, Fx, gamma_historico = PGMMOP(x0)
    solucoes.append(x_opt)
    solucoes_imagens.append(Fx)
    all_details.append((x0, x_opt, subproblem_vec, iters, final_phi, Fx))
    print(f"\n--- Início {i+1} ---")
    print("Ponto inicial (após projeção):", x0)
    print("Ponto ótimo x*:", x_opt)
    print("Vetor do subproblema final:", subproblem_vec)
    print("Número de iterações:", iters)
    print("Valor final de φ:", final_phi)
    print("Imagem da solução ótima F(x*):", Fx)

# Registra o tempo final e calcula a diferença
end_time = time.time()
print("\nTempo de execução do multi-start: {:.4f} segundos".format(end_time - start_time))

#================================================
# GERAÇÃO DOS PONTOS PARA O ESPAÇO DOS OBJETIVOS
#===============================================

num_pontos = 1000000  # Quantidade de pontos a serem gerados na caixa
samples = np.random.uniform(
    [b[0] for b in bounds],
    [b[1] for b in bounds],
    size=(num_pontos, len(bounds))
)
# Mapeamento para o espaço dos objetivos
objetivo_valor = np.array([F(sample) for sample in samples])
f1_valor = objetivo_valor[:, 0]
f2_valor = objetivo_valor[:, 1]

#=================================
# Filtro de dominância
#=================================

def domina(sol1, sol2):
    """
    Retorna True se sol1 domina sol2:
    sol1 é <= sol2 em todas as componentes e
    sol1 é < sol2 em pelo menos uma componente
    """
    sol1, sol2 = np.array(sol1), np.array(sol2)
    return np.all(sol1 <= sol2) and np.any(sol1 < sol2)


solu_dominada, solu_naodominada = [], [] # Para separar as soluções encontradas em "dominadas" e "não dominadas"
for sol in solucoes_imagens: # percorre cada solução candidata
    dominado = False                      # assume que ainda não foi dominada
     # verifica dominância entre as próprias soluções do algoritmo
    for outro in solucoes_imagens:
        if not np.array_equal(sol, outro) and domina(outro, sol):
            dominado = True           # achou alguém que domina
            break                    # pode sair do processo interno
    #Aqui se ainda não foi dominado, vamos verificar contra todos os pontos gerados
    if not dominado:
        cond_all = np.all(objetivo_valor <= sol, axis=1) # verifica se cada valor objetivo <= 'sol' em todas as componentes. Devolve um vetor
        cond_any = np.any(objetivo_valor < sol, axis=1)  # O "objetivo_valor <= sol" é uma matriz de boolerianos n°pontos x 2 (f1,f2) e axis=1 é para operar ao longo das colunas, verifica f_1_1<=f_sol,f_1_2<=f_sol_1... e depois para f
        dominado = np.any(cond_all & cond_any)           # Faz o AND entre os vetores boolerianos
    if dominado:
      #coloca a solução na lista de dominado
       solu_dominada.append(sol)
    else:
      # coloca na lista de não dominado
      solu_naodominada.append(sol)


#========================================================
# PLOT DO ESPAÇO DOS OBJETIVOS E DAS SOLUÇÕES
#=========================================================
#Plot da figura
plt.figure(figsize=(8, 6))

# Pontos dos pontos gerados (em azul)
plt.scatter(f1_valor, f2_valor, alpha=0.5, s=10, marker='o', color="blue", label="Pontos Objetivo")

# Soluções dominadas (amarelo)
for sol in solu_dominada:
    plt.scatter(sol[0], sol[1], color="yellow", s=30, marker='o', edgecolor="black",
                label="Solução Dominada" if "Solução Dominada" not in plt.gca().get_legend_handles_labels()[1] else "")

# Soluções não dominadas (vermelho)
for sol in solu_naodominada:
    plt.scatter(sol[0], sol[1], color="red", s=30, marker='o', edgecolor="black",
                label="Solução Não Dominada" if "Solução Não Dominada" not in plt.gca().get_legend_handles_labels()[1] else "")

plt.title("Espaço dos Objetivos:\nPontos Gerados (Azul) e Soluções Multi-Start\nDominadas (Amarelo) vs. Não Dominadas (Vermelho)", fontsize=12)
plt.xlabel(r"$f_1(x)$", fontsize=12)
plt.ylabel(r"$f_2(x)$", fontsize=12)
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ===== Resultados Multi-Start =====
#
# --- Início 1 ---
# Ponto inicial (após projeção): [-0.50183952  1.80285723  0.92797577  0.39463394 -1.37592544]
# Ponto ótimo x*: [0.24953446 0.24955266 0.24954575 0.24954154 0.24952755]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 23
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.06227040799637325), np.float64(3.0641088345406047)]
#
# --- Início 2 ---
# Ponto inicial (após projeção): [-1.37602192 -1.76766555  1.46470458  0.40446005  0.83229031]
# Ponto ótimo x*: [-1.08709585e-05 -1.39650528e-05  1.15715766e-05  3.19534765e-06
#   6.57532674e-06]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 23
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(1.0010939829361772e-10), np.float64(4.0000027951083075)]
#
# --- Início 3 ---
# Ponto inicial (após projeção): [-1.91766202  1.87963941  1.32977056 -1.15064356 -1.27270013]
# Ponto ótimo x*: [-9.08844769e-06  8.90824551e-06  6.30223151e-06 -5.45328835e-06
#  -6.03175560e-06]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 24
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(5.355905421132105e-11), np.float64(4.000004290465258)]
#
# --- Início 4 ---
# Ponto inicial (após projeção): [-1.26638196 -0.78303103  0.09902573 -0.27221993 -0.83508344]
# Ponto ótimo x*: [-1.66748624e-05 -1.03104238e-05  1.30390396e-06 -3.58440803e-06
#  -1.09958146e-05]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 22
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(1.0396239182313318e-10), np.float64(4.00003220938782)]
#
# --- Início 5 ---
# Ponto inicial (após projeção): [ 0.44741158 -1.44202456 -0.83142141 -0.53455263 -0.17572006]
# Ponto ótimo x*: [ 5.89143615e-06 -1.89883228e-05 -1.09480090e-05 -7.03889380e-06
#  -2.31385050e-06]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 22
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(1.1400485076946334e-10), np.float64(4.000026718225982)]
#
# --- Início 6 ---
# Ponto inicial (após projeção): [ 1.14070385 -1.20130487  0.05693775  0.36965828 -1.81419835]
# Ponto ótimo x*: [ 9.01109881e-06 -9.48982246e-06  4.49785123e-07  2.92015077e-06
#  -1.43314330e-05]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 23
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(7.707523841420521e-11), np.float64(4.00000915225371)]
#
# --- Início 7 ---
# Ponto inicial (após projeção): [ 0.43017941 -1.31790351 -1.73979363  1.79554215  1.86252813]
# Ponto ótimo x*: [0.20611193 0.20610088 0.20609821 0.20612056 0.20612098]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 24
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.042481542800901), np.float64(3.2180394991413395)]
#
# --- Início 8 ---
# Ponto inicial (após projeção): [ 1.23358939 -0.78154492 -1.60931154  0.73693211 -0.23939003]
# Ponto ótimo x*: [ 9.74446642e-06 -6.17364127e-06 -1.27124006e-05  5.82123210e-06
#  -1.89100855e-06]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 23
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(6.642725157119097e-11), np.float64(4.00000416914794)]
#
# --- Início 9 ---
# Ponto inicial (após projeção): [-1.51184706 -0.01929236 -1.86244592  1.63728161 -0.96488007]
# Ponto ótimo x*: [-1.19447716e-05 -1.52424802e-07 -1.47147761e-05  1.29358020e-05
#  -7.62330553e-06]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 23
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(1.169350393057325e-10), np.float64(4.00001719969768)]
#
# --- Início 10 ---
# Ponto inicial (após projeção): [ 0.65008914 -0.7531557   0.08027208  0.18684112 -1.26058218]
# Ponto ótimo x*: [ 8.55951236e-06 -9.91655637e-06  1.05691639e-06  2.46007626e-06
#  -1.65976759e-05]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 22
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(9.085104669395003e-11), np.float64(4.000011550272627)]
#
# --- Início 11 ---
# Ponto inicial (após projeção): [1.87833851 1.10053129 1.75799577 1.5793094  0.39159992]
# Ponto ótimo x*: [1.3415644  1.34155075 1.34156229 1.34155915 1.3415383 ]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 22
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(1.7997697578897225), np.float64(0.4335498476757068)]
#
# --- Início 12 ---
# Ponto inicial (após projeção): [ 1.68749694 -1.64602999 -1.21606855 -1.81909084 -0.69867868]
# Ponto ótimo x*: [ 7.99747025e-06 -7.80094793e-06 -5.76325312e-06 -8.62112671e-06
#  -3.31121323e-06]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 24
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(4.866347287649204e-11), np.float64(4.000013999305258)]
#
# --- Início 13 ---
# Ponto inicial (após projeção): [-0.44529084 -0.91460387  1.31495004 -0.57298669 -0.87626196]
# Ponto ótimo x*: [-3.51723460e-06 -7.22421414e-06  1.03864426e-05 -4.52587035e-06
#  -6.92136147e-06]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 23
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(4.816542934611203e-11), np.float64(4.0000094418385075)]
#
# --- Início 14 ---
# Ponto inicial (após projeção): [ 0.17078433 -1.4363031   1.20878792 -1.70179743  1.94754775]
# Ponto ótimo x*: [0.03780465 0.03779551 0.03781056 0.037794   0.03781476]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 25
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.0014291345702967181), np.float64(3.8502135531466752)]
#
# --- Início 15 ---
# Ponto inicial (após projeção): [ 1.08897908 -1.20513727 -1.97791153  1.26184571  0.82742938]
# Ponto ótimo x*: [ 8.60356636e-06 -9.52128334e-06 -1.56266485e-05  9.96931314e-06
#   6.53717211e-06]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 23
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(1.1019803126624701e-10), np.float64(4.000000030414355)]
#
# --- Início 16 ---
# Ponto inicial (após projeção): [ 0.91602867  1.08508139 -1.70382139 -0.56613709 -1.53652376]
# Ponto ótimo x*: [ 7.23674096e-06  8.57227837e-06 -1.34604013e-05 -4.47255344e-06
#  -1.21387292e-05]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 23
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(9.487785182949102e-11), np.float64(4.0000114102265405)]
#
# --- Início 17 ---
# Ponto inicial (após projeção): [ 1.4524137   0.49319251 -0.6764079  -1.7457666  -0.75607071]
# Ponto ótimo x*: [ 1.14736176e-05  3.89606778e-06 -5.34341256e-06 -1.37910144e-05
#  -5.97272418e-06]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 23
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(8.024816315100358e-11), np.float64(4.000007790052882)]
#
# --- Início 18 ---
# Ponto inicial (após projeção): [-0.69926671  0.91842471  0.55022989  1.54885097 -0.1111403 ]
# Ponto ótimo x*: [0.44140469 0.44142599 0.44142114 0.44143429 0.44141244]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 22
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.19485136189435578), np.float64(2.429172515499822)]
#
# --- Início 19 ---
# Ponto inicial (após projeção): [-1.52162302  0.85297915  1.04314019  0.24510879  1.08386872]
# Ponto ótimo x*: [0.34068006 0.34069881 0.34070032 0.34069401 0.34070064]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 23
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.1160729246167614), np.float64(2.7532938548799697)]
#
# --- Início 20 ---
# Ponto inicial (após projeção): [-0.02481761  0.09093132 -0.28983593 -1.89832349 -1.56843429]
# Ponto ótimo x*: [-1.96048940e-07  7.18319912e-07 -2.28958449e-06 -1.49959742e-05
#  -1.23899853e-05]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 23
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(7.683751861322728e-11), np.float64(4.0000233226952275)]
#
# --- Início 21 ---
# Ponto inicial (após projeção): [-1.87428326  0.54564165 -0.74257608  0.03428276  1.6302659 ]
# Ponto ótimo x*: [-1.18439270e-05  3.44800597e-06 -4.69246948e-06  2.16638840e-07
#   1.03019381e-05]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 24
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(5.607269646476879e-11), np.float64(4.000002055906946)]
#
# --- Início 22 ---
# Ponto inicial (após projeção): [-1.00283108 -0.35846831  1.02220455 -1.08480734 -1.69208036]
# Ponto ótimo x*: [-7.92197603e-06 -2.83176051e-06  8.07501879e-06 -8.56955672e-06
#  -1.33667776e-05]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 23
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(7.761810921756494e-11), np.float64(4.000019692119279)]
#
# --- Início 23 ---
# Ponto inicial (após projeção): [-0.84099419 -1.35511485  1.71879061  1.23248152  0.53361503]
# Ponto ótimo x*: [0.25774868 0.25774543 0.25776486 0.25776178 0.25775737]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 24
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.066437961154192), np.float64(3.035415469849319)]
#
# --- Início 24 ---
# Ponto inicial (após projeção): [ 1.48584236  1.21468831 -1.25371976  1.57023599  0.15736897]
# Ponto ótimo x*: [0.63488905 0.63488717 0.63487014 0.63488963 0.63487988]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 36
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.4030766434934897), np.float64(1.863543951240297)]
#
# --- Início 25 ---
# Ponto inicial (após projeção): [ 1.22976062  1.5843652  -0.7279861  -1.5597923  -1.08825935]
# Ponto ótimo x*: [ 8.74333183e-06  1.12644937e-05 -5.17582357e-06 -1.10897856e-05
#  -7.73728835e-06]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 24
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(8.259455915624295e-11), np.float64(4.000003196140155)]
#
# --- Início 26 ---
# Ponto inicial (após projeção): [-0.29156885  1.27205906  1.44292233 -1.97219148  0.04298921]
# Ponto ótimo x*: [0.09883897 0.09885133 0.09885268 0.0988257  0.09884162]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 23
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.00976975228016963), np.float64(3.614401525231868)]
#
# --- Início 27 ---
# Ponto inicial (após projeção): [-0.33035599 -1.11156876 -1.52053853 -0.64953931  1.77163882]
# Ponto ótimo x*: [-2.60980634e-06 -8.78137335e-06 -1.20122274e-05 -5.13134896e-06
#   1.39959153e-05]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 23
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(9.008672009659017e-11), np.float64(4.000011631162661)]
#
# --- Início 28 ---
# Ponto inicial (após projeção): [-0.70718827  0.07516249  0.81207584 -0.54548159  1.88712833]
# Ponto ótimo x*: [0.30433073 0.3043374  0.30434369 0.30433211 0.30435286]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 25
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.0926224450202833), np.float64(2.875265012191992)]
#
# --- Início 29 ---
# Ponto inicial (após projeção): [ 1.84978918 -0.99287082 -0.01100598 -0.79648676 -0.86063802]
# Ponto ótimo x*: [ 1.46123162e-05 -7.84313289e-06 -8.69412735e-08 -6.29180700e-06
#  -6.79856661e-06]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 23
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(7.216988403269729e-11), np.float64(4.000005126577434)]
#
# --- Início 30 ---
# Ponto inicial (após projeção): [-1.85245221  0.43825734  0.01071609 -1.794085   -0.88541414]
# Ponto ótimo x*: [-1.46346210e-05  3.46229168e-06  8.46585322e-08 -1.41735122e-05
#  -6.99489049e-06]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 23
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(9.51967405289366e-11), np.float64(4.000025804953958)]
#
# --- Início 31 ---
# Ponto inicial (após projeção): [ 1.63306354 -1.04175244 -1.42042051 -0.04218896  1.94260182]
# Ponto ótimo x*: [0.21426966 0.21425275 0.21425036 0.21425907 0.21427161]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 24
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.0459076435497032), np.float64(3.188864881719988)]
#
# --- Início 32 ---
# Ponto inicial (após projeção): [-1.03177891  0.68854219  1.04647846 -1.04944982  0.91286539]
# Ponto ótimo x*: [0.11332242 0.11333601 0.11333883 0.11332228 0.11333778]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 23
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.012844020216608265), np.float64(3.5595181743105777)]
#
# --- Início 33 ---
# Ponto inicial (após projeção): [-0.52886747  0.52922332  0.53411884  0.14309874 -1.63884092]
# Ponto ótimo x*: [-6.96427259e-06  6.96895857e-06  7.03342422e-06  1.88436359e-06
#  -2.15807089e-05]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 22
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(1.231628712800014e-10), np.float64(4.000010126711273)]
#
# --- Início 34 ---
# Ponto inicial (após projeção): [ 1.34120998 -0.71687974 -1.25392596 -1.83689943  0.36357177]
# Ponto ótimo x*: [ 9.53543016e-06 -5.09670867e-06 -8.91487791e-06 -1.30595703e-05
#   2.58483999e-06]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 24
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(7.47219380355116e-11), np.float64(4.000011960784117)]
#
# --- Início 35 ---
# Ponto inicial (após projeção): [ 0.71025745 -1.93364868  0.04837223 -1.0940169   0.58069116]
# Ponto ótimo x*: [ 5.61064197e-06 -1.52747582e-05  3.82113974e-07 -8.64213013e-06
#   4.58713997e-06]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 23
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(7.213436355733974e-11), np.float64(4.000010669666039)]
#
# --- Início 36 ---
# Ponto inicial (após projeção): [-1.30253428  0.76375095 -0.45305861  1.74691995 -1.44991622]
# Ponto ótimo x*: [-1.02902017e-05  6.03373871e-06 -3.57922581e-06  1.38009102e-05
#  -1.14545395e-05]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 23
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(9.535534165131995e-11), np.float64(4.000004391549839)]
#
# --- Início 37 ---
# Ponto inicial (após projeção): [-0.6357346  -1.54610592  1.69877447  1.50935741 -0.96823349]
# Ponto ótimo x*: [0.01160646 0.01159927 0.01162491 0.01162341 0.01160384]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 23
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.0001348288397540045), np.float64(3.953688519413988)]
#
# --- Início 38 ---
# Ponto inicial (após projeção): [ 0.63993618  1.2688888   0.22080325  0.11860231 -1.03259084]
# Ponto ótimo x*: [0.24313376 0.24314298 0.24312761 0.24312612 0.24310923]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 34
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.05911119613387214), np.float64(3.0865994295323347)]
#
# --- Início 39 ---
# Ponto inicial (após projeção): [-1.62758893  1.58886303  1.60167223  0.53240583 -0.64388084]
# Ponto ótimo x*: [0.29027911 0.29030452 0.29030463 0.29029618 0.29028688]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 23
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.0842707603871532), np.float64(2.9230937004201847)]
#
# --- Início 40 ---
# Ponto inicial (após projeção): [-0.6031617   0.90382272  1.58844104  1.5483457   1.11950218]
# Ponto ótimo x*: [0.91137403 0.91138991 0.91139712 0.9113967  0.91139218]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 23
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.8306317081934669), np.float64(1.185071760811032)]
#
# --- Início 41 ---
# Ponto inicial (após projeção): [ 0.56812658 -1.66344014 -1.35348514  1.59421675  0.42571624]
# Ponto ótimo x*: [ 4.48828020e-06 -1.31414113e-05 -1.06927231e-05  1.25945371e-05
#   3.36321818e-06]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 23
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(9.542185568528121e-11), np.float64(4.00000271057458)]
#
# --- Início 42 ---
# Ponto inicial (após projeção): [-1.96321179 -1.59411383  0.65400708 -1.97975366 -1.35676779]
# Ponto ótimo x*: [-9.30442748e-06 -7.55512804e-06  3.09959504e-06 -9.38282582e-06
#  -6.43025257e-06]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 24
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(5.65290776599495e-11), np.float64(4.000023658487625)]
#
# --- Início 43 ---
# Ponto inicial (após projeção): [ 0.19493516  0.76758079  0.60784504 -1.10292276  0.84871689]
# Ponto ótimo x*: [0.26323012 0.26323766 0.26323556 0.26321303 0.26323873]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 22
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.06929057099277915), np.float64(3.0163664832973054)]
#
# --- Início 44 ---
# Ponto inicial (após projeção): [-1.05100365 -0.69840121  0.98596562  0.5985316   1.39689364]
# Ponto ótimo x*: [0.24638353 0.24638725 0.24640499 0.24640091 0.24640932]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 23
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.06071158022398565), np.float64(3.0751227805915455)]
#
# --- Início 45 ---
# Ponto inicial (após projeção): [ 0.63045157  0.27323441 -1.62530093 -0.52913679 -0.93919053]
# Ponto ótimo x*: [ 4.97986759e-06  2.15824856e-06 -1.28380732e-05 -4.17959322e-06
#  -7.41856259e-06]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 23
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(5.335546214812625e-11), np.float64(4.000013838543607)]
#
# --- Início 46 ---
# Ponto inicial (após projeção): [-1.02404143  1.89204222 -0.4276091   1.56818622  0.5245545 ]
# Ponto ótimo x*: [0.50661439 0.50663743 0.5066191  0.50663487 0.50662662]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 23
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.25667039345744985), np.float64(2.2301644610534392)]
#
# --- Início 47 ---
# Ponto inicial (após projeção): [ 1.17924521  0.01054837  0.30761554 -0.02992922 -1.21902805]
# Ponto ótimo x*: [0.04970673 0.0496898  0.0496941  0.04968922 0.049672  ]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 34
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.0024691330239875967), np.float64(3.8037076518512993)]
#
# --- Início 48 ---
# Ponto inicial (após projeção): [ 0.88980846 -0.87691055 -1.90273613  0.58188918 -1.29155728]
# Ponto ótimo x*: [ 7.02946134e-06 -6.92756826e-06 -1.50315608e-05  4.59690759e-06
#  -1.02032656e-05]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 23
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(8.971810774056038e-11), np.float64(4.0000164289103495)]
#
# --- Início 49 ---
# Ponto inicial (após projeção): [ 1.76183434  1.81571431  1.65945756 -0.5193652  -1.93817353]
# Ponto ótimo x*: [0.55589987 0.55590016 0.55589933 0.55588781 0.55588031]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 36
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.3090175774947264), np.float64(2.085443598767122)]
#
# --- Início 50 ---
# Ponto inicial (após projeção): [ 1.71327425 -0.28726341  1.86661928  1.85447991  1.41203782]
# Ponto ótimo x*: [1.31183334 1.31181454 1.31183479 1.31183467 1.31183051]
# Vetor do subproblema final: [0. 0. 0. 0. 0.]
# Número de iterações: 36
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(1.7208968207904651), np.float64(0.47357854078250927)]
#
# Tempo de execução do multi-start: 7.6294 segundos
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern

# %%
#==========================================================
# Multi-start do problema STADLER-DAUER (convexa)
#=========================================================
#!pip install pygmo # Use antes de rodar
import time  # Importa o módulo para medição de tempo
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize
import pygmo as pg  # Certifique-se de instalar o PyGMO (pip install pygmo)
from matplotlib.patches import Polygon
np.random.seed(42)
# ——————————————————————————————
# 1) Use MathText sem LaTeX externo, mas com Computer Modern
plt.rcParams['text.usetex']        = False
plt.rcParams['font.family']        = 'serif'
plt.rcParams['font.serif']         = ['Computer Modern']
plt.rcParams['mathtext.fontset']   = 'cm'
# ——————————————————————————————
#=======================================
# 1° FUNÇÃO: STADLER-DAUER (convexa)
#========================================

SQ2 = np.sqrt(2)

def F(x):
    """
    Função principal (Stadler-Dauer – convexa)
    Entrada: x ∈ R⁴
    Saída  : [f1, f2]
      f1 = 2·x0 + √2·x1 + √2·x2 + x3
      f2 = 2/x0 + 2√2/x1 + 2√2/x2 + 2/x3
    """
    f1 = 2*x[0] + SQ2*x[1] + SQ2*x[2] + x[3]
    f2 = 2/x[0] + 2*SQ2/x[1] + 2*SQ2/x[2] + 2/x[3]
    return [f1, f2]

def SD_grad(x):
    """Gradientes de f1 e f2."""
    g1 = np.array([2, SQ2, SQ2, 1])
    g2 = np.array([
        -2/(x[0]**2),
        -2*SQ2/(x[1]**2),
        -2*SQ2/(x[2]**2),
        -2/(x[3]**2)
    ])
    return g1, g2

#=============================================
# FUNÇÕES AUXILIARES PARA A BUSCA
#=============================================

def Armijo_tamanho_passo(z, d, F_fun, Jd, A_k, delta):
    """Critério de Armijo não-monótono (máximo)."""
    for j in range(20):
        t_val = 1/(2**j)
        if np.all(np.array(F_fun(z + t_val*d)) <= np.array(A_k) + delta*t_val*Jd):
            return t_val
    return 1.0

def compute_A_k(f_values, k, M=10):
    """Calcula A_k para Armijo não-monótono."""
    m_k = min(k, M)
    recentes = f_values[max(0, k-m_k):k+1]
    if not recentes:
        return f_values[-1]
    A1 = max(v[0] for v in recentes)
    A2 = max(v[1] for v in recentes)
    return (A1, A2)

def projecao_caixa(x, bounds):
    """Projeta x na caixa *bounds*."""
    lo = np.array([b[0] for b in bounds])
    up = np.array([b[1] for b in bounds])
    return np.clip(x, lo, up)

# ======================================================================
# Busca da direção por função suave (sub-problema do epígrafe)
# ======================================================================

def buscadirecao(x, bounds, tol_slsqp=1e-10):
    g1, g2 = SD_grad(x)
    dt0 = np.concatenate([np.zeros_like(x), [0.0]])

    obj      = lambda dt: dt[-1] + 0.5*np.dot(dt[:-1], dt[:-1])
    obj_grad = lambda dt: np.concatenate([dt[:-1], [1.0]])

    cons = [
        {'type':'ineq', 'fun': lambda dt: dt[-1] - np.dot(g1, dt[:-1])},
        {'type':'ineq', 'fun': lambda dt: dt[-1] - np.dot(g2, dt[:-1])},
    ]
    for i,(lo,up) in enumerate(bounds):
        cons.append({'type':'ineq', 'fun': lambda dt,i=i,up=up:  up - (x[i]+dt[i])})
        cons.append({'type':'ineq', 'fun': lambda dt,i=i,lo=lo: (x[i]+dt[i]) - lo})

    res = minimize(obj, dt0, jac=obj_grad,
                   constraints=cons, method='SLSQP',
                   options={'ftol': tol_slsqp, 'maxiter': 500, 'disp': False})

    d_opt = res.x[:-1]
    t_opt = res.x[-1]
    phi   = obj(res.x)
    return d_opt, t_opt, phi

#======================================================================
# PARÂMETROS GERAIS
#======================================================================

bounds = [(1,3), (SQ2,3), (SQ2,3), (1,3)]

#=========================================================
# Algoritmo principal (PGMMOP)
#=========================================================

def PGMMOP(x0, max_iter=50, M=10, delta=0.5,
           tol_inner=1e-8, bounds=bounds):
        """
    Devolve:
      x*         – ponto final
      d_last     – direção da última iteração
      k          – nº de iterações executadas
      phi_last   – phi final
      F(x*)      – imagem final
      gamma_hist – histórico de phi(d^k)
    """
    x = x0.copy()
    f_vals, gamma_hist = [], []

    for k in range(max_iter):
        Fx = F(x)
        f_vals.append(Fx)

        d, _, phi_val = buscadirecao(x, bounds)
        gamma_hist.append(phi_val)

        if np.linalg.norm(d) <= tol_inner:
            break

        A_k = compute_A_k(f_vals, k, M)
        g1, g2 = SD_grad(x)
        Jd = np.array([np.dot(g1, d), np.dot(g2, d)])
        t  = Armijo_tamanho_passo(x, d, F, Jd, A_k, delta)
        x  = projecao_caixa(x + t*d, bounds)

    return x, d, k, phi_val, F(x), gamma_hist

#==================================
# LOOP DO MULTI-START
#==================================

num_starts = 50
solucoes, solucoes_imagens, all_details = [], [], []
initial_points = []

start_time = time.time()

for i in range(num_starts):
    x_ini = np.random.uniform([b[0] for b in bounds], [b[1] for b in bounds])
    x_ini = projecao_caixa(x_ini, bounds)
    initial_points.append(x_ini)

print("===== Resultados Multi-Start =====")
for i, x0 in enumerate(initial_points):
    x_opt, d_last, iters, phi_fin, Fx, gamma_hist = PGMMOP(x0)
    solucoes.append(x_opt)
    solucoes_imagens.append(Fx)
    all_details.append((x0, x_opt, d_last, iters, phi_fin, Fx))

    print(f"\n--- Início {i+1} ---")
    print("Ponto inicial (após projeção):", x0)
    print("Ponto ótimo x*:", x_opt)
    print("Vetor do subproblema final:", d_last)
    print("Número de iterações:", iters)
    print("Valor final de φ:", phi_fin)
    print("Imagem da solução ótima F(x*):", Fx)

end_time = time.time()
print("\nTempo de execução do multi-start: {:.4f} segundos".format(end_time - start_time))

#================================================
# GERAÇÃO DOS PONTOS PARA O ESPAÇO DOS OBJETIVOS
#================================================

num_pontos = 1_000_000
samples = np.column_stack([
    np.random.uniform(lo, up, num_pontos) for lo, up in bounds
])
objetivo_valor = np.array([F(s) for s in samples])

f1_valor = objetivo_valor[:, 0]
f2_valor = objetivo_valor[:, 1]

#=================================
# Filtro de dominância
#=================================

def domina(sol1, sol2):
    """
    Retorna True se sol1 domina sol2:
    sol1 é <= sol2 em todas as componentes e
    sol1 é < sol2 em pelo menos uma componente
    """
    sol1, sol2 = np.array(sol1), np.array(sol2)
    return np.all(sol1 <= sol2) and np.any(sol1 < sol2)


solu_dominada, solu_naodominada = [], [] # Para separar as soluções encontradas em "dominadas" e "não dominadas"
for sol in solucoes_imagens: # percorre cada solução candidata
    dominado = False                      # assume que ainda não foi dominada
     # verifica dominância entre as próprias soluções do algoritmo
    for outro in solucoes_imagens:
        if not np.array_equal(sol, outro) and domina(outro, sol):
            dominado = True           # achou alguém que domina
            break                    # pode sair do processo interno
    #Aqui se ainda não foi dominado, vamos verificar contra todos os pontos gerados
    if not dominado:
        cond_all = np.all(objetivo_valor <= sol, axis=1) # verifica se cada valor objetivo <= 'sol' em todas as componentes. Devolve um vetor
        cond_any = np.any(objetivo_valor < sol, axis=1)  # O "objetivo_valor <= sol" é uma matriz de boolerianos n°pontos x 2 (f1,f2) e axis=1 é para operar ao longo das colunas, verifica f_1_1<=f_sol,f_1_2<=f_sol_1... e depois para f
        dominado = np.any(cond_all & cond_any)           # Faz o AND entre os vetores boolerianos
    if dominado:
      #coloca a solução na lista de dominado
       solu_dominada.append(sol)
    else:
      # coloca na lista de não dominado
      solu_naodominada.append(sol)


#========================================================
# PLOT DO ESPAÇO DOS OBJETIVOS E DAS SOLUÇÕES
#========================================================

plt.figure(figsize=(8, 6))
plt.scatter(f1_valor, f2_valor, alpha=0.5, s=10, marker='o', color='blue', label='Pontos Objetivo')

for sol in solu_dominada:
    plt.scatter(sol[0], sol[1], color='yellow', s=30, marker='o', edgecolor='black',
                label='Solução Dominada' if 'Solução Dominada' not in plt.gca().get_legend_handles_labels()[1] else '')

for sol in solu_naodominada:
    plt.scatter(sol[0], sol[1], color='red', s=30, marker='o', edgecolor='black',
                label='Solução Não Dominada' if 'Solução Não Dominada' not in plt.gca().get_legend_handles_labels()[1] else '')

plt.title('Espaço dos Objetivos:\nPontos Gerados (Azul) e Soluções Multi-Start\nDominadas (Amarelo) vs. Não Dominadas (Vermelho)', fontsize=12)
plt.xlabel(r'$f_1(x)$', fontsize=12)
plt.ylabel(r'$f_2(x)$', fontsize=12)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ===== Resultados Multi-Start =====
#
# --- Início 1 ---
# Ponto inicial (após projeção): [1.81537406 1.50201228 2.66466148 1.57461037]
# Ponto ótimo x*: [1.4489279  2.04909666 2.04909767 2.04907079]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 24
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(10.74264860844464), np.float64(5.117040010652232)]
#
# --- Início 2 ---
# Ponto inicial (após projeção): [1.90070117 1.89615357 2.24897079 2.24762443]
# Ponto ótimo x*: [1.59662788 2.25796199 2.25797309 2.25800531]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 23
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(11.837757718745243), np.float64(4.643663441753217)]
#
# --- Início 3 ---
# Ponto inicial (após projeção): [2.55355092 2.50244626 2.96977311 2.20163218]
# Ponto ótimo x*: [2.01462422 2.84912724 2.84913523 2.84897083]
# Vetor do subproblema final: [-1.76513338e-06 -5.42176998e-06 -7.37348583e-06  2.16249365e-05]
# Número de iterações: 49
# Valor final de φ: -2.772593686664678e-10
# Imagem da solução ótima F(x*): [np.float64(14.936779350102313), np.float64(3.680215224791664)]
#
# --- Início 4 ---
# Ponto inicial (após projeção): [2.62793704 2.53797343 1.45787768 2.80853443]
# Ponto ótimo x*: [1.77289083 2.50724008 2.50723861 2.50728899]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 39
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(13.144614425205802), np.float64(4.181983660636631)]
#
# --- Início 5 ---
# Ponto inicial (após projeção): [1.8998097  1.60280267 2.73882125 1.40449645]
# Ponto ótimo x*: [1.47415563 2.0847747  2.08477603 2.0847432 ]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 25
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(10.929689651170277), np.float64(5.029471513354186)]
#
# --- Início 6 ---
# Ponto inicial (após projeção): [1.34840534 2.12646491 2.47636504 2.91479822]
# Ponto ótimo x*: [1.62180387 2.29357106 2.29357126 2.29361331]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 34
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(12.024419929152371), np.float64(4.57157709686066)]
#
# --- Início 7 ---
# Ponto inicial (após projeção): [2.6666665  2.22028461 2.41329636 2.67006937]
# Ponto ótimo x*: [1.94252148 2.74712388 2.74713705 2.74719598]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 37
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(14.402297259408577), np.float64(3.816791291210145)]
#
# --- Início 8 ---
# Ponto inicial (após projeção): [1.89466329 2.62304346 2.42423622 1.72459179]
# Ponto ótimo x*: [1.69163278 2.39233583 2.39233532 2.39229575]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 36
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(12.54210814413759), np.float64(4.38288062253421)]
#
# --- Início 9 ---
# Ponto inicial (após projeção): [1.0291491  2.27368585 1.91874021 1.28998069]
# Ponto ótimo x*: [1.22011546 1.72550713 1.72550693 1.72548414]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 15
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(9.046185945839381), np.float64(6.0766562923848335)]
#
# --- Início 10 ---
# Ponto inicial (após projeção): [2.09778389 1.71151882 2.04691298 1.48007641]
# Ponto ótimo x*: [1.44050082 2.03718021 2.03718062 2.03714729]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 22
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(10.680165269778952), np.float64(5.146976789405602)]
#
# --- Início 11 ---
# Ponto inicial (após projeção): [1.07330971 2.31580413 2.87752147 1.35811021]
# Ponto ótimo x*: [1.40517618 1.98722227 1.98722278 1.98719869]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 23
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(10.418265131284711), np.float64(5.276364352117081)]
#
# --- Início 12 ---
# Ponto inicial (após projeção): [2.40615534 2.55600009 1.46347446 2.16565061]
# Ponto ótimo x*: [1.64258631 2.32297707 2.32297178 2.32292716]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 29
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(12.17846365917521), np.float64(4.513751840148953)]
#
# --- Início 13 ---
# Ponto inicial (após projeção): [2.39535519 2.85704685 2.94719013 2.67145906]
# Ponto ótimo x*: [2.11046948 2.98468419 2.98469043 2.98445162]
# Vetor do subproblema final: [-2.26507866e-06 -7.49575521e-06 -8.80804616e-06  2.75863144e-05]
# Número de iterações: 49
# Valor final de φ: -4.499515885551436e-10
# Imagem da solução ótima F(x*): [np.float64(15.647361128957058), np.float64(3.5130883952116823)]
#
# --- Início 14 ---
# Ponto inicial (após projeção): [2.90224274 2.21713772 1.72264646 1.13928951]
# Ponto ótimo x*: [1.55060107 2.19288576 2.1928854  2.1928531 ]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 28
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(11.496472289189779), np.float64(4.781515700420639)]
#
# --- Início 15 ---
# Ponto inicial (após projeção): [2.85159134 2.03477379 2.06148517 1.3418101 ]
# Ponto ótimo x*: [1.64425647 2.32533482 2.32533485 2.32529868]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 33
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(12.19085174176008), np.float64(4.509165062034656)]
#
# --- Início 16 ---
# Ponto inicial (após projeção): [1.26469028 2.22293385 1.95456101 1.913839  ]
# Ponto ótimo x*: [1.39154363 1.96794327 1.96794226 1.96792198]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 19
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(10.317191936485031), np.float64(5.32805467687064)]
#
# --- Início 17 ---
# Ponto inicial (após projeção): [1.09720195 1.8211262  2.87487137 1.17670741]
# Ponto ótimo x*: [1.28285422 1.81423237 1.81423282 1.81421274]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 18
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(9.511345851992967), np.float64(5.779472600915507)]
#
# --- Início 18 ---
# Ponto inicial (após projeção): [2.22603376 2.60566094 2.1567462  2.26688554]
# Ponto ótimo x*: [1.80321473 2.55013992 2.55013611 2.55008565]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 38
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(13.369394642736488), np.float64(4.111671786253444)]
#
# --- Início 19 ---
# Ponto inicial (após projeção): [1.85741371 2.93362294 2.80947863 1.23640248]
# Ponto ótimo x*: [1.70099076 2.40557082 2.4055705  2.40552432]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 38
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(12.611487157703998), np.float64(4.358769276296769)]
#
# --- Início 20 ---
# Ponto inicial (após projeção): [1.15489882 2.83371539 1.43337325 2.49148557]
# Ponto ótimo x*: [1.41082928 1.99521145 1.99521028 1.99523264]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 22
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(10.460199725869902), np.float64(5.25521158199968)]
#
# --- Início 21 ---
# Ponto inicial (após projeção): [1.26744434 1.64851819 2.13687195 2.6476537 ]
# Ponto ótimo x*: [1.40386524 1.98536139 1.98536143 1.98538903]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 24
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(10.408569563594192), np.float64(5.281279278016923)]
#
# --- Início 22 ---
# Ponto inicial (após projeção): [1.80339282 2.45849529 2.02246769 2.86452041]
# Ponto ótimo x*: [1.71966793 2.43197086 2.43197034 2.43202159]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 38
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(12.750009064110369), np.float64(4.311413621398012)]
#
# --- Início 23 ---
# Ponto inicial (após projeção): [1.28281295 2.78834391 2.19627451 1.2661514 ]
# Ponto ótimo x*: [1.41653084 2.00328128 2.00328058 2.00325361]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 23
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(10.50244940922418), np.float64(5.2340707017991654)]
#
# --- Início 24 ---
# Ponto inicial (após projeção): [2.75262045 1.59295668 2.24556636 1.56778341]
# Ponto ótimo x*: [1.60699451 2.27263933 2.27264009 2.27259463]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 30
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(11.914579448097282), np.float64(4.6137224558411365)]
#
# --- Início 25 ---
# Ponto inicial (após projeção): [1.36249348 2.47145547 2.23825876 1.57920349]
# Ponto ótimo x*: [1.46343415 2.06961336 2.06961289 2.06957931]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 24
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(10.850197502804662), np.float64(5.066319091093028)]
#
# --- Início 26 ---
# Ponto inicial (após projeção): [2.42153751 2.94575651 1.42091251 1.43559011]
# Ponto ótimo x*: [1.57839047 2.23218795 2.23218601 2.23214556]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 30
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(11.702504713998238), np.float64(4.697333100447352)]
#
# --- Início 27 ---
# Ponto inicial (após projeção): [1.92252927 2.88281978 2.05508196 2.80894738]
# Ponto ótimo x*: [1.82933499 2.58706517 2.58705888 2.5871218 ]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 40
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(13.563108192939717), np.float64(4.052947301663258)]
#
# --- Início 28 ---
# Ponto inicial (após projeção): [2.82098275 2.13812413 2.6001572  1.49468689]
# Ponto ótimo x*: [1.80286478 2.54964278 2.54964385 2.54958957]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 42
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(13.36679944647452), np.float64(4.11247007723228)]
#
# --- Início 29 ---
# Ponto inicial (após projeção): [2.52455005 2.69488521 2.95302493 2.57946714]
# Ponto ótimo x*: [2.09948127 2.96914167 2.96915619 2.96890382]
# Vetor do subproblema final: [-2.39677958e-06 -7.05903052e-06 -1.01634559e-05  2.91488245e-05]
# Número de iterações: 49
# Valor final de φ: -5.042622400909878e-10
# Imagem da solução ótima F(x*): [np.float64(15.56588772001078), np.float64(3.5314762505890758)]
#
# --- Início 30 ---
# Ponto inicial (após projeção): [2.24156216 1.49240759 2.36408767 1.51702991]
# Ponto ótimo x*: [1.47960178 2.09247622 2.09247683 2.09245058]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 25
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(10.970071504156293), np.float64(5.010957561112167)]
#
# --- Início 31 ---
# Ponto inicial (após projeção): [1.76382397 2.35772418 1.81790529 1.00085334]
# Ponto ótimo x*: [1.3220583  1.86967608 1.86967563 1.86965372]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 19
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(9.802012212759713), np.float64(5.608089600013808)]
#
# --- Início 32 ---
# Ponto inicial (após projeção): [1.4112157  2.01095494 2.20656352 1.87445728]
# Ponto ótimo x*: [1.43609756 2.03095216 2.03095287 2.03092467]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 21
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(10.647520981513402), np.float64(5.162756931440311)]
#
# --- Início 33 ---
# Ponto inicial (após projeção): [1.84742527 1.87663249 2.48588425 2.1787759 ]
# Ponto ótimo x*: [1.61381186 2.28227584 2.28228506 2.28223856]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 26
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(11.965126204985605), np.float64(4.59423175397493)]
#
# --- Início 34 ---
# Ponto inicial (após projeção): [2.70515334 1.42349629 1.54553509 2.03372194]
# Ponto ótimo x*: [1.47041904 2.07949096 2.07949088 2.07945947]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 20
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(10.901986077279926), np.float64(5.0422521511787615)]
#
# --- Início 35 ---
# Ponto inicial (após projeção): [1.5452206  2.26277439 1.59924002 2.6264779 ]
# Ponto ótimo x*: [1.48714717 2.10313937 2.10313922 2.10317089]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 27
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(11.026041458007844), np.float64(4.9855211373560415)]
#
# --- Início 36 ---
# Ponto inicial (após projeção): [2.83875746 2.98774968 1.7975928  2.46759157]
# Ponto ótimo x*: [1.9649551  2.77888053 2.77887137 2.77880554]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 48
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(14.56856385449478), np.float64(3.7732314113222807)]
#
# --- Início 37 ---
# Ponto inicial (após projeção): [1.10141236 1.86955677 2.71125403 1.91634036]
# Ponto ótimo x*: [1.40327404 1.98453175 1.98453298 1.98450951]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 22
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(10.404162758179465), np.float64(5.283516225879142)]
#
# --- Início 38 ---
# Ponto inicial (após projeção): [1.82792639 1.83725903 1.63926207 2.41472965]
# Ponto ótimo x*: [1.45795729 2.06185923 2.0618592  2.0618862 ]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 25
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(10.809619314897661), np.float64(5.085337526555786)]
#
# --- Início 39 ---
# Ponto inicial (após projeção): [1.82889351 2.15566261 2.03540633 1.62942245]
# Ponto ótimo x*: [1.49720569 2.11737291 2.1173727  2.11734255]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 25
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(11.100588597409946), np.float64(4.9520403596362135)]
#
# --- Início 40 ---
# Ponto inicial (após projeção): [1.67146967 1.52917915 2.50919911 1.24618875]
# Ponto ótimo x*: [1.33738792 1.89135482 1.89135534 1.89133389]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 20
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(9.915669740752646), np.float64(5.543807346017786)]
#
# --- Início 41 ---
# Ponto inicial (após projeção): [2.21189441 2.77686129 1.43478444 2.32288163]
# Ponto ótimo x*: [1.64837769 2.33117079 2.33115717 2.3311217 ]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 28
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(12.221404503395362), np.float64(4.497892426034924)]
#
# --- Início 42 ---
# Ponto inicial (após projeção): [1.42492632 2.42154855 1.82521237 1.1167561 ]
# Ponto ótimo x*: [1.29644359 1.83345172 1.83345128 1.83342715]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 18
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(9.612098288302624), np.float64(5.718893117933332)]
#
# --- Início 43 ---
# Ponto inicial (após projeção): [1.58286399 2.96521578 1.93182356 1.24017405]
# Ponto ótimo x*: [1.4750003  2.08597114 2.08596965 2.08593477]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 26
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(10.935950624226358), np.float64(5.02659207595643)]
#
# --- Início 44 ---
# Ponto inicial (após projeção): [2.00522566 2.24692411 2.83025787 2.55636147]
# Ponto ótimo x*: [1.84924702 2.61522188 2.6152511  2.61519144]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 35
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(13.710691303180639), np.float64(4.009321013521539)]
#
# --- Início 45 ---
# Ponto inicial (após projeção): [1.20103196 1.77830645 2.24997374 2.50805847]
# Ponto ótimo x*: [1.41530167 2.00153577 2.00153586 2.00155738]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 24
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(10.49335890561346), np.float64(5.238605030462506)]
#
# --- Início 46 ---
# Ponto inicial (após projeção): [2.60651387 2.83231885 1.62375993 2.58926452]
# Ponto ótimo x*: [1.84838317 2.61403566 2.61398942 2.61398296]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 34
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(13.704293255722568), np.float64(4.0111928230123635)]
#
# --- Início 47 ---
# Ponto inicial (após projeção): [2.47560101 1.82921855 2.58682332 2.53465559]
# Ponto ótimo x*: [1.82133538 2.57572916 2.57577638 2.57578247]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 31
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(13.503782225026065), np.float64(4.0707530554026565)]
#
# --- Início 48 ---
# Ponto inicial (após projeção): [2.35363799 2.86141587 2.12086731 1.66851316]
# Ponto ótimo x*: [1.77514158 2.51043668 2.51043489 2.51038926]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 41
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(13.161257098143473), np.float64(4.176695458593484)]
#
# --- Início 49 ---
# Ponto inicial (após projeção): [2.46211137 1.55312562 2.53587987 1.81291699]
# Ponto ótimo x*: [1.6277711  2.30202116 2.30202295 2.30197835]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 31
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(12.068622156632964), np.float64(4.554833355282364)]
#
# --- Início 50 ---
# Ponto inicial (após projeção): [2.15372537 1.80161123 1.82068705 1.60412774]
# Ponto ótimo x*: [1.45053433 2.05136995 2.05136998 2.05133658]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 22
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(10.754555685699762), np.float64(5.111374598549455)]
#
# Tempo de execução do multi-start: 7.4006 segundos
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern

# %%
#==========================================================
# Multi-start do problema STADLER-DAUER (convexa)
#=========================================================
#!pip install pygmo # Use antes de rodar
import time  # Importa o módulo para medição de tempo
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize
import pygmo as pg  # Certifique-se de instalar o PyGMO (pip install pygmo)
from matplotlib.patches import Polygon
np.random.seed(40)
# ——————————————————————————————
# 1) Use MathText sem LaTeX externo, mas com Computer Modern
plt.rcParams['text.usetex']        = False
plt.rcParams['font.family']        = 'serif'
plt.rcParams['font.serif']         = ['Computer Modern']
plt.rcParams['mathtext.fontset']   = 'cm'
# ——————————————————————————————
#=======================================
# 1° FUNÇÃO: STADLER-DAUER (convexa)
#========================================

def F(x):
    """
    Função principal Trigonometric
    Entrada: x em R^4
    Saída: [f1, f2]
      f1 = (4 - sum(cos(x)) + 1*(1 - cos(x[0])) - sin(x[0]))^2
      f2 = (4 - sum(cos(x)) + 2*(1 - cos(x[1])) - sin(x[1]))^2
    """
    A1 = 4 - np.sum(np.cos(x)) + 1 * (1 - np.cos(x[0])) - np.sin(x[0])
    A2 = 4 - np.sum(np.cos(x)) + 2 * (1 - np.cos(x[1])) - np.sin(x[1])
    f1 = A1**2
    f2 = A2**2
    return [f1, f2]

def Trigonometricgrad(x):
    """
    Gradientes de f1 e f2.
    """
    grad_f1 = np.zeros_like(x)
    grad_f2 = np.zeros_like(x)

    A1 = 4 - np.sum(np.cos(x)) + 1 * (1 - np.cos(x[0])) - np.sin(x[0])
    A2 = 4 - np.sum(np.cos(x)) + 2 * (1 - np.cos(x[1])) - np.sin(x[1])

    for k in range(len(x)):
        if k == 0:
            grad_f1[k] = 2 * A1 * (2 * np.sin(x[0]) - np.cos(x[0]))
        else:
            grad_f1[k] = 2 * A1 * np.sin(x[k])

        if k == 1:
            grad_f2[k] = 2 * A2 * (3 * np.sin(x[1]) - np.cos(x[1]))
        else:
            grad_f2[k] = 2 * A2 * np.sin(x[k])

    return grad_f1, grad_f2

#=============================================
# FUNÇÕES AUXILIARES PARA A BUSCA
#=============================================

def Armijo_tamanho_passo(z, d, F_fun, Jd, A_k, delta):
    """Critério de Armijo não-monótono (máximo)."""
    for j in range(20):
        t_val = 1/(2**j)
        if np.all(np.array(F_fun(z + t_val*d)) <= np.array(A_k) + delta*t_val*Jd):
            return t_val
    return 1.0

def compute_A_k(f_values, k, M=10):
    """Calcula A_k para Armijo não-monótono."""
    m_k = min(k, M)
    recentes = f_values[max(0, k-m_k):k+1]
    if not recentes:
        return f_values[-1]
    A1 = max(v[0] for v in recentes)
    A2 = max(v[1] for v in recentes)
    return (A1, A2)

def projecao_caixa(x, bounds):
    """Projeta x na caixa *bounds*."""
    lo = np.array([b[0] for b in bounds])
    up = np.array([b[1] for b in bounds])
    return np.clip(x, lo, up)

# ======================================================================
# Busca da direção por função suave (sub-problema do epígrafe)
# ======================================================================

def buscadirecao(x, bounds, tol_slsqp=1e-10):
    g1, g2 = Trigonometricgrad(x)
    dt0 = np.concatenate([np.zeros_like(x), [0.0]])

    obj      = lambda dt: dt[-1] + 0.5*np.dot(dt[:-1], dt[:-1])
    obj_grad = lambda dt: np.concatenate([dt[:-1], [1.0]])

    cons = [
        {'type':'ineq', 'fun': lambda dt: dt[-1] - np.dot(g1, dt[:-1])},
        {'type':'ineq', 'fun': lambda dt: dt[-1] - np.dot(g2, dt[:-1])},
    ]
    for i,(lo,up) in enumerate(bounds):
        cons.append({'type':'ineq', 'fun': lambda dt,i=i,up=up:  up - (x[i]+dt[i])})
        cons.append({'type':'ineq', 'fun': lambda dt,i=i,lo=lo: (x[i]+dt[i]) - lo})

    res = minimize(obj, dt0, jac=obj_grad,
                   constraints=cons, method='SLSQP',
                   options={'ftol': tol_slsqp, 'maxiter': 500, 'disp': False})

    d_opt = res.x[:-1]
    t_opt = res.x[-1]
    phi   = obj(res.x)
    return d_opt, t_opt, phi

#======================================================================
# PARÂMETROS GERAIS
#======================================================================

bounds = [(-0.5, 0.5), (-0.5, 0.5), (-0.5, 0.5), (-0.5, 0.5)]
#=========================================================
# Algoritmo principal (PGMMOP)
#=========================================================

def PGMMOP(x0, max_iter=50, M=10, delta=0.5,
           tol_inner=1e-8, bounds=bounds):
        """
    Devolve:
      x*         – ponto final
      d_last     – direção da última iteração
      k          – nº de iterações executadas
      phi_last   – phi final
      F(x*)      – imagem final
      gamma_hist – histórico de phi(d^k)
    """
    x = x0.copy()
    f_vals, gamma_hist = [], []

    for k in range(max_iter):
        Fx = F(x)
        f_vals.append(Fx)

        d, _, phi_val = buscadirecao(x, bounds)
        gamma_hist.append(phi_val)

        if np.linalg.norm(d) <= tol_inner:
            break

        A_k = compute_A_k(f_vals, k, M)
        g1, g2 = SD_grad(x)
        Jd = np.array([np.dot(g1, d), np.dot(g2, d)])
        t  = Armijo_tamanho_passo(x, d, F, Jd, A_k, delta)
        x  = projecao_caixa(x + t*d, bounds)

    return x, d, k, phi_val, F(x), gamma_hist

#==================================
# LOOP DO MULTI-START
#==================================

num_starts = 50
solucoes, solucoes_imagens, all_details = [], [], []
initial_points = []

start_time = time.time()

for i in range(num_starts):
    x_ini = np.random.uniform([b[0] for b in bounds], [b[1] for b in bounds])
    x_ini = projecao_caixa(x_ini, bounds)
    initial_points.append(x_ini)

print("===== Resultados Multi-Start =====")
for i, x0 in enumerate(initial_points):
    x_opt, d_last, iters, phi_fin, Fx, gamma_hist = PGMMOP(x0)
    solucoes.append(x_opt)
    solucoes_imagens.append(Fx)
    all_details.append((x0, x_opt, d_last, iters, phi_fin, Fx))

    print(f"\n--- Início {i+1} ---")
    print("Ponto inicial (após projeção):", x0)
    print("Ponto ótimo x*:", x_opt)
    print("Vetor do subproblema final:", d_last)
    print("Número de iterações:", iters)
    print("Valor final de φ:", phi_fin)
    print("Imagem da solução ótima F(x*):", Fx)

end_time = time.time()
print("\nTempo de execução do multi-start: {:.4f} segundos".format(end_time - start_time))

#================================================
# GERAÇÃO DOS PONTOS PARA O ESPAÇO DOS OBJETIVOS
#================================================

num_pontos = 500000
samples = np.column_stack([
    np.random.uniform(lo, up, num_pontos) for lo, up in bounds
])
objetivo_valor = np.array([F(s) for s in samples])

f1_valor = objetivo_valor[:, 0]
f2_valor = objetivo_valor[:, 1]

#=================================
# Filtro de dominância
#=================================

def domina(sol1, sol2):
    """
    Retorna True se sol1 domina sol2:
    sol1 é <= sol2 em todas as componentes e
    sol1 é < sol2 em pelo menos uma componente
    """
    sol1, sol2 = np.array(sol1), np.array(sol2)
    return np.all(sol1 <= sol2) and np.any(sol1 < sol2)


solu_dominada, solu_naodominada = [], [] # Para separar as soluções encontradas em "dominadas" e "não dominadas"
for sol in solucoes_imagens: # percorre cada solução candidata
    dominado = False                      # assume que ainda não foi dominada
     # verifica dominância entre as próprias soluções do algoritmo
    for outro in solucoes_imagens:
        if not np.array_equal(sol, outro) and domina(outro, sol):
            dominado = True           # achou alguém que domina
            break                    # pode sair do processo interno
    #Aqui se ainda não foi dominado, vamos verificar contra todos os pontos gerados
    if not dominado:
        cond_all = np.all(objetivo_valor <= sol, axis=1) # verifica se cada valor objetivo <= 'sol' em todas as componentes. Devolve um vetor
        cond_any = np.any(objetivo_valor < sol, axis=1)  # O "objetivo_valor <= sol" é uma matriz de boolerianos n°pontos x 2 (f1,f2) e axis=1 é para operar ao longo das colunas, verifica f_1_1<=f_sol,f_1_2<=f_sol_1... e depois para f
        dominado = np.any(cond_all & cond_any)           # Faz o AND entre os vetores boolerianos
    if dominado:
      #coloca a solução na lista de dominado
       solu_dominada.append(sol)
    else:
      # coloca na lista de não dominado
      solu_naodominada.append(sol)


#========================================================
# PLOT DO ESPAÇO DOS OBJETIVOS E DAS SOLUÇÕES
#========================================================

plt.figure(figsize=(8, 6))
plt.scatter(f1_valor, f2_valor, alpha=0.5, s=10, marker='o', color='blue', label='Pontos Objetivo')

for sol in solu_dominada:
    plt.scatter(sol[0], sol[1], color='yellow', s=30, marker='o', edgecolor='black',
                label='Solução Dominada' if 'Solução Dominada' not in plt.gca().get_legend_handles_labels()[1] else '')

for sol in solu_naodominada:
    plt.scatter(sol[0], sol[1], color='red', s=30, marker='o', edgecolor='black',
                label='Solução Não Dominada' if 'Solução Não Dominada' not in plt.gca().get_legend_handles_labels()[1] else '')

plt.title('Espaço dos Objetivos:\nPontos Gerados (Azul) e Soluções Multi-Start\nDominadas (Amarelo) vs. Não Dominadas (Vermelho)', fontsize=12)
plt.xlabel(r'$f_1(x)$', fontsize=12)
plt.ylabel(r'$f_2(x)$', fontsize=12)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ===== Resultados Multi-Start =====
#
# --- Início 1 ---
# Ponto inicial (após projeção): [-0.09231297 -0.44463396  0.28853488 -0.21269482]
# Ponto ótimo x*: [ 0.49211489 -0.11363318  0.44090121 -0.32463652]
# Vetor do subproblema final: [-0.00631233  0.02807411  0.05144949 -0.0384543 ]
# Número de iterações: 49
# Valor final de φ: -0.0024768923187591953
# Imagem da solução ótima F(x*): [np.float64(0.006536213810335634), np.float64(0.15941411857578383)]
#
# --- Início 2 ---
# Ponto inicial (após projeção): [-0.04964941 -0.19608769  0.02639952  0.12381221]
# Ponto ótimo x*: [ 0.03090289 -0.13469077  0.02428158  0.11391903]
# Vetor do subproblema final: [-0.02629537  0.0011439   0.00059277  0.00277529]
# Número de iterações: 49
# Valor final de φ: -0.0003504043534888722
# Imagem da solução ótima F(x*): [np.float64(0.00019907581771082044), np.float64(0.028462785150902663)]
#
# --- Início 3 ---
# Ponto inicial (após projeção): [0.27677546 0.18624165 0.48093886 0.10081609]
# Ponto ótimo x*: [0.25377668 0.2120217  0.46567829 0.09749957]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 12
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.0028493288008103836), np.float64(3.224478177971467e-12)]
#
# --- Início 4 ---
# Ponto inicial (após projeção): [ 0.31396852  0.20864515 -0.47246532  0.40426722]
# Ponto ótimo x*: [ 0.31446823  0.20833733 -0.47176973  0.40366599]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 12
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(2.517140706414963e-12), np.float64(0.009347880727000038)]
#
# --- Início 5 ---
# Ponto inicial (após projeção): [-0.05009515 -0.38107535  0.33530018 -0.29775177]
# Ponto ótimo x*: [ 0.19125464 -0.17296407  0.39639576 -0.3515675 ]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 13
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(2.082862491781281e-11), np.float64(0.13973159337211477)]
#
# --- Início 6 ---
# Ponto inicial (após projeção): [-0.32579733 -0.05085292  0.16979478  0.45739911]
# Ponto ótimo x*: [-0.15368105  0.5         0.11435481  0.31483223]
# Vetor do subproblema final: [ 6.71405575e-03 -2.43812553e-16  8.20676220e-03  2.22712813e-02]
# Número de iterações: 49
# Valor final de φ: -0.000304219730128202
# Imagem da solução ótima F(x*): [np.float64(0.12584666370570602), np.float64(0.0019984894652357436)]
#
# --- Início 7 ---
# Ponto inicial (após projeção): [0.33333325 0.00830996 0.13002355 0.33503469]
# Ponto ótimo x*: [0.18912396 0.13243239 0.15292974 0.39310669]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 44
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.0030950626263859652), np.float64(2.7618562578126966e-12)]
#
# --- Início 8 ---
# Ponto inicial (após projeção): [-0.05266835  0.26229047  0.13692224 -0.13770411]
# Ponto ótimo x*: [ 0.04987114  0.07898342  0.19703511 -0.19815721]
# Vetor do subproblema final: [-0.00896479 -0.00140267  0.00255055 -0.00256488]
# Número de iterações: 49
# Valor final de φ: -4.7718577764906026e-05
# Imagem da solução ótima F(x*): [np.float64(2.8394031050063114e-05), np.float64(0.0008636327328327353)]
#
# --- Início 9 ---
# Ponto inicial (após projeção): [-0.48542545  0.04198489 -0.18184452 -0.35500965]
# Ponto ótimo x*: [-0.32609408  0.20358407 -0.19132494 -0.37440499]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 17
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.2850673679649505), np.float64(2.2502104069993073e-11)]
#
# --- Início 10 ---
# Ponto inicial (após projeção): [ 0.04889195 -0.31251873 -0.10101852 -0.25996179]
# Ponto ótimo x*: [ 0.11751026 -0.28749774 -0.09328888 -0.24026279]
# Vetor do subproblema final: [-0.04512288  0.00019544 -0.00455076 -0.01162476]
# Número de iterações: 49
# Valor final de φ: -0.0010959785191663673
# Imagem da solução ótima F(x*): [np.float64(0.0008602985919292554), np.float64(0.1994993604930849)]
#
# --- Início 11 ---
# Ponto inicial (após projeção): [-0.46334515  0.06854476  0.4227648  -0.32094489]
# Ponto ótimo x*: [-0.28150571  0.36833843  0.32228002 -0.24317924]
# Vetor do subproblema final: [ 0.00737909  0.00440394  0.01804816 -0.01372086]
# Número de iterações: 49
# Valor final de φ: -0.00029392200738579245
# Imagem da solução ótima F(x*): [np.float64(0.25452623479008857), np.float64(0.0014882510152361076)]
#
# --- Início 12 ---
# Ponto inicial (após projeção): [ 0.20307767  0.2200128  -0.46893598  0.08282531]
# Ponto ótimo x*: [ 0.20573504  0.2097677  -0.48939385  0.0865744 ]
# Vetor do subproblema final: [ 1.04050228e-04 -1.79988944e-04 -2.39433416e-04  4.40402375e-05]
# Número de iterações: 49
# Valor final de φ: -5.124519757176398e-08
# Imagem da solução ótima F(x*): [np.float64(0.00036332141794880913), np.float64(6.475535491506959e-08)]
#
# --- Início 13 ---
# Ponto inicial (após projeção): [0.1976776  0.40985347 0.46669799 0.33572953]
# Ponto ótimo x*: [0.18196241 0.38828954 0.43065082 0.30935339]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 10
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.004260989610645669), np.float64(2.3113298586809835e-11)]
#
# --- Início 14 ---
# Ponto inicial (após projeção): [ 0.45112137  0.00632553 -0.30550162 -0.43035525]
# Ponto ótimo x*: [ 0.38749012  0.08736076 -0.4359499  -0.5       ]
# Vetor do subproblema final: [-3.84546067e-03  2.70615720e-03 -7.69813301e-03 -5.20395867e-18]
# Número de iterações: 49
# Valor final de φ: -4.069267568901098e-05
# Imagem da solução ótima F(x*): [np.float64(9.652922142519935e-05), np.float64(0.04591532868820016)]
#
# --- Início 15 ---
# Ponto inicial (após projeção): [ 0.42579567 -0.10867352 -0.09182927 -0.32909495]
# Ponto ótimo x*: [ 0.24054521 -0.06152602 -0.17042444 -0.5       ]
# Vetor do subproblema final: [-4.17234188e-02 -2.90125580e-03 -1.38320919e-02  8.16894796e-18]
# Número de iterações: 49
# Valor final de φ: -0.0009702938648818678
# Imagem da solução ótima F(x*): [np.float64(0.0017515849889094004), np.float64(0.054223745331426904)]
#
# --- Início 16 ---
# Ponto inicial (após projeção): [-0.36765486  0.00998058 -0.15925585 -0.0430805 ]
# Ponto ótimo x*: [-0.31730999  0.06943088 -0.15105073 -0.04084624]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 39
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.18188994104089123), np.float64(2.151756095512704e-11)]
#
# --- Início 17 ---
# Ponto inicial (após projeção): [-0.45139903 -0.2434001   0.42109364 -0.4116463 ]
# Ponto ótimo x*: [ 0.15122637  0.49999083 -0.12645726  0.12477669]
# Vetor do subproblema final: [ 0.01516378 -0.00134485  0.00065021 -0.00064161]
# Número de iterações: 49
# Valor final de φ: -0.00011634576059448232
# Imagem da solução ótima F(x*): [np.float64(0.00010707852345364928), np.float64(0.007225994216929411)]
#
# --- Início 18 ---
# Ponto inicial (após projeção): [ 0.11301688  0.25132902 -0.03175748  0.13344277]
# Ponto ótimo x*: [ 0.07658057  0.22001775 -0.04110218  0.1725738 ]
# Vetor do subproblema final: [-0.03045235 -0.01530183 -0.00492885  0.02059777]
# Número de iterações: 49
# Valor final de φ: -0.0008050265954985301
# Imagem da solução ótima F(x*): [np.float64(0.000951049176993543), np.float64(0.016204856998721418)]
#
# --- Início 19 ---
# Ponto inicial (após projeção): [-0.07129315  0.4581425   0.37985686 -0.38179876]
# Ponto ótimo x*: [-0.06926456  0.44596321  0.3692957  -0.37118624]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 39
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.0944515442139446), np.float64(1.8864070302484893e-11)]
#
# --- Início 20 ---
# Ponto inicial (após projeção): [-0.42255059  0.3951406  -0.48791786  0.24574278]
# Ponto ótimo x*: [-0.34839527  0.35511423 -0.40310504  0.20179616]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 8
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.3898554778929961), np.float64(2.38714659210631e-11)]
#
# --- Início 21 ---
# Ponto inicial (após projeção): [-0.36627783 -0.35224705 -0.04429022  0.32382685]
# Ponto ótimo x*: [ 0.5         0.25562442  0.01416081 -0.09362974]
# Vetor do subproblema final: [ 2.56729913e-16 -2.32324549e-03  1.21627086e-03 -8.03037648e-03]
# Número de iterações: 49
# Valor final de φ: -3.5686958949193114e-05
# Imagem da solução ótima F(x*): [np.float64(0.039052058762209914), np.float64(0.0008104625480727531)]
#
# --- Início 22 ---
# Ponto inicial (após projeção): [-0.09830359  0.15852608 -0.11643377  0.43226021]
# Ponto ótimo x*: [-0.09504259  0.13837777 -0.12007242  0.44537789]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 5
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.04762734384359659), np.float64(3.007958760352896e-11)]
#
# --- Início 23 ---
# Ponto inicial (após projeção): [-0.35859352  0.36652926 -0.00683085 -0.3669243 ]
# Ponto ótimo x*: [-0.332508    0.38753417 -0.00847192 -0.45243762]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 38
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.37303921138986174), np.float64(1.6132682773632696e-10)]
#
# --- Início 24 ---
# Ponto inicial (após projeção): [ 0.37631023 -0.38728424  0.02425268 -0.21610829]
# Ponto ótimo x*: [ 0.17366234 -0.39683471  0.03706421 -0.32891284]
# Vetor do subproblema final: [-0.0143139  -0.00021741  0.00064796 -0.0056483 ]
# Número de iterações: 49
# Valor final de φ: -0.00011868537198693783
# Imagem da solução ótima F(x*): [np.float64(0.0001145785631465294), np.float64(0.4746771006074045)]
#
# --- Início 25 ---
# Ponto inicial (após projeção): [-0.31875326  0.16669879  0.0196445  -0.21039825]
# Ponto ótimo x*: [-0.32025904  0.08986208  0.02184856 -0.23381882]
# Vetor do subproblema final: [ 4.15393617e-04  9.58932921e-04 -2.88267884e-05  3.05719351e-04]
# Número de iterações: 49
# Valor final de φ: -5.932011624045174e-07
# Imagem da solução ótima F(x*): [np.float64(0.20069458423888445), np.float64(4.3497830911081166e-07)]
#
# --- Início 26 ---
# Ponto inicial (após projeção): [ 0.21076876  0.46579395 -0.49577563 -0.28220495]
# Ponto ótimo x*: [ 0.18918966  0.41825849 -0.44607615 -0.25311029]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 7
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.004037357822696475), np.float64(2.3040226452206645e-11)]
#
# --- Início 27 ---
# Ponto inicial (após projeção): [-0.03873536  0.42610593 -0.09586715  0.40447369]
# Ponto ótimo x*: [ 0.0271516   0.48907537 -0.1130229   0.47467516]
# Vetor do subproblema final: [ 0.00054975  0.00059545 -0.000121    0.00049033]
# Número de iterações: 49
# Valor final de φ: -4.559286197527389e-07
# Imagem da solução ótima F(x*): [np.float64(0.04316435142909697), np.float64(6.482247568724641e-07)]
#
# --- Início 28 ---
# Ponto inicial (após projeção): [ 0.41049137 -0.04350059  0.24785835 -0.25265655]
# Ponto ótimo x*: [ 0.21547509  0.07989412  0.4040207  -0.41173319]
# Vetor do subproblema final: [-0.00034752  0.00011486  0.00020034 -0.00020395]
# Número de iterações: 49
# Valor final de φ: -1.0784561788831826e-07
# Imagem da solução ótima F(x*): [np.float64(8.292647030082291e-08), np.float64(0.01368175476939262)]
#
# --- Início 29 ---
# Ponto inicial (após projeção): [0.26227502 0.30759402 0.47037743 0.28973357]
# Ponto ótimo x*: [0.26680119 0.3044031  0.46502575 0.28635981]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 34
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(4.489708062762742e-16), np.float64(0.0004198604153493076)]
#
# --- Início 30 ---
# Ponto inicial (após projeção): [ 0.12078108 -0.45069069  0.09899245 -0.24148504]
# Ponto ótimo x*: [ 0.14096462 -0.42716578  0.09586985 -0.23393648]
# Vetor do subproblema final: [ 0.0014605   0.00085331 -0.00019716  0.00047745]
# Número de iterações: 49
# Valor final de φ: -1.5640291806708104e-06
# Imagem da solução ótima F(x*): [np.float64(1.054476927244437e-06), np.float64(0.5265124219268155)]
#
# --- Início 31 ---
# Ponto inicial (após projeção): [-0.11808801  0.09497963 -0.24543121 -0.49957333]
# Ponto ótimo x*: [-0.09207194  0.17471431 -0.22033556 -0.45043539]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 7
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.0573866560425484), np.float64(2.882532641871455e-12)]
#
# --- Início 32 ---
# Ponto inicial (após projeção): [-0.29439215 -0.12369373 -0.00034258 -0.06277136]
# Ponto ótimo x*: [ 0.12170201  0.5        -0.00255855 -0.46184153]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 44
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.014539194581458291), np.float64(4.670674683458252e-11)]
#
# --- Início 33 ---
# Ponto inicial (após projeção): [-0.07628737 -0.20839773  0.17579761  0.08938795]
# Ponto ótimo x*: [ 0.02530078 -0.10760856  0.16159312  0.08209406]
# Vetor do subproblema final: [-4.71002147e-03  8.19040865e-05  7.21465733e-04  3.67712504e-04]
# Número de iterações: 49
# Valor final de φ: -1.142388991446121e-05
# Imagem da solução ótima F(x*): [np.float64(6.1412848093872374e-06), np.float64(0.020013565328516936)]
#
# --- Início 34 ---
# Ponto inicial (após projeção): [ 0.35257667 -0.49414629 -0.41718839  0.01686097]
# Ponto ótimo x*: [ 0.32839408 -0.49341438 -0.44058028  0.01783599]
# Vetor do subproblema final: [-5.26296508e-04  1.54036692e-05 -4.79711116e-04  2.00618551e-05]
# Número de iterações: 49
# Valor final de φ: -2.5387551844895715e-07
# Imagem da solução ótima F(x*): [np.float64(5.076220672563905e-07), np.float64(0.9615106317711662)]
#
# --- Início 35 ---
# Ponto inicial (após projeção): [-0.2273897   0.0351041  -0.38332196  0.31323895]
# Ponto ótimo x*: [-0.16096706  0.15364881 -0.35628914  0.29074563]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 7
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.09161524075690355), np.float64(1.1597093404435788e-11)]
#
# --- Início 36 ---
# Ponto inicial (após projeção): [ 0.41937873  0.49227492 -0.25824031  0.23379578]
# Ponto ótimo x*: [ 0.37792067  0.49318861 -0.26145017  0.23670771]
# Vetor do subproblema final: [-0.01370907 -0.00138049 -0.00012263  0.00011125]
# Número de iterações: 49
# Valor final de φ: -9.49720190417079e-05
# Imagem da solução ótima F(x*): [np.float64(0.002191703801165554), np.float64(0.00027273047377316333)]
#
# --- Início 37 ---
# Ponto inicial (após projeção): [-0.44929382 -0.21285969  0.31791623 -0.04182982]
# Ponto ótimo x*: [ 0.01096221  0.5         0.3848289  -0.04650819]
# Vetor do subproblema final: [ 1.11356325e-02 -3.50811816e-17  2.36782670e-02 -2.93243137e-03]
# Número de iterações: 49
# Valor final de φ: -0.00034663089514046615
# Imagem da solução ótima F(x*): [np.float64(0.03451950479024403), np.float64(0.001435993580974888)]
#
# --- Início 38 ---
# Ponto inicial (após projeção): [-0.0860368  -0.23322671 -0.35808398  0.20736482]
# Ponto ótimo x*: [ 0.25745142 -0.07617723 -0.29843068  0.17138956]
# Vetor do subproblema final: [-0.11309375  0.0347099  -0.05332032  0.03092936]
# Número de iterações: 49
# Valor final de φ: -0.008897327575056449
# Imagem da solução ótima F(x*): [np.float64(0.016115941335151585), np.float64(0.03119249981007759)]
#
# --- Início 39 ---
# Ponto inicial (após projeção): [-0.08555324 -0.0324408  -0.10827464 -0.18528877]
# Ponto ótimo x*: [ 0.00684354  0.01986031 -0.09653516 -0.1652838 ]
# Vetor do subproblema final: [ 0.00017413 -0.0017958  -0.00016802 -0.00028681]
# Número de iterações: 49
# Valor final de φ: -1.6828578456944157e-06
# Imagem da solução ótima F(x*): [np.float64(0.00013653358995503552), np.float64(9.211294930998588e-07)]
#
# --- Início 40 ---
# Ponto inicial (após projeção): [-0.16426517 -0.42750248  0.19050001 -0.37690563]
# Ponto ótimo x*: [ 0.5        -0.06206079  0.15153603 -0.31310533]
# Vetor do subproblema final: [ 4.02268090e-16  4.18166411e-02  3.89623882e-02 -7.94996454e-02]
# Número de iterações: 49
# Valor final de φ: -0.004793446392987257
# Imagem da solução ótima F(x*): [np.float64(0.02978646312051385), np.float64(0.06264599422278799)]
#
# --- Início 41 ---
# Ponto inicial (após projeção): [ 0.1059472   0.3592883  -0.48702796  0.16144082]
# Ponto ótimo x*: [ 0.13227005  0.37677048 -0.5         0.18622241]
# Vetor do subproblema final: [ 2.57368652e-03  3.04756431e-03 -3.46940047e-18  3.29853966e-03]
# Número de iterações: 49
# Valor final de φ: -1.339665502525324e-05
# Imagem da solução ótima F(x*): [np.float64(0.009107699538974617), np.float64(8.191590096013217e-05)]
#
# --- Início 42 ---
# Ponto inicial (após projeção): [-0.28753684  0.13522739 -0.24082336 -0.44162195]
# Ponto ótimo x*: [-0.25280621  0.1903004  -0.21831448 -0.40135743]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 8
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.1891818352394309), np.float64(3.6254447941982825e-11)]
#
# --- Início 43 ---
# Ponto inicial (após projeção): [-0.208568    0.478065   -0.17359413 -0.37991298]
# Ponto ótimo x*: [-0.198393    0.49553235 -0.17940695 -0.39238736]
# Vetor do subproblema final: [ 0.00136201  0.00237564 -0.00073241 -0.0015695 ]
# Número de iterações: 49
# Valor final de φ: -5.249344352546174e-06
# Imagem da solução ótima F(x*): [np.float64(0.20129650379956984), np.float64(8.881496883810214e-06)]
#
# --- Início 44 ---
# Ponto inicial (após projeção): [0.00261283 0.02510888 0.39296029 0.27818073]
# Ponto ótimo x*: [0.09288686 0.12339546 0.31722768 0.22387455]
# Vetor do subproblema final: [-0.00264913  0.00014146  0.00116893  0.00083195]
# Número de iterações: 49
# Valor final de φ: -4.548319796197999e-06
# Imagem da solução ótima F(x*): [np.float64(2.8104853360221175e-06), np.float64(0.0004456070850220033)]
#
# --- Início 45 ---
# Ponto inicial (após projeção): [-0.39948402 -0.27040232  0.02703198  0.25402924]
# Ponto ótimo x*: [ 0.21717144  0.5        -0.01081655  0.00675402]
# Vetor do subproblema final: [-2.20120871e-05 -1.38777656e-17 -1.51817583e-03  9.47983756e-04]
# Número de iterações: 49
# Valor final de φ: -1.6020180509160684e-06
# Imagem da solução ótima F(x*): [np.float64(0.0021151962541042495), np.float64(0.007850445271796075)]
#
# --- Início 46 ---
# Ponto inicial (após projeção): [ 0.30325693  0.39425994 -0.36785965  0.29463226]
# Ponto ótimo x*: [ 0.30076185  0.39390837 -0.36672911  0.29371938]
# Vetor do subproblema final: [-1.41689852e-04 -2.44463011e-05  6.97225420e-05 -5.62958802e-05]
# Número de iterações: 49
# Valor final de φ: -1.4352048038457379e-08
# Imagem da solução ótima F(x*): [np.float64(0.00042291958535874396), np.float64(2.606595108851299e-08)]
#
# --- Início 47 ---
# Ponto inicial (após projeção): [ 0.2378005  -0.23829705  0.23944998  0.26732779]
# Ponto ótimo x*: [ 0.13076608 -0.23107907  0.27795526  0.31020882]
# Vetor do subproblema final: [-9.40537425e-04  3.44082357e-05  2.90629860e-04  3.23324308e-04]
# Número de iterações: 49
# Valor final de φ: -5.37400604015604e-07
# Imagem da solução ótima F(x*): [np.float64(3.924782753650394e-07), np.float64(0.1627460292088543)]
#
# --- Início 48 ---
# Ponto inicial (após projeção): [ 0.17681899  0.41260858 -0.05438278 -0.16574342]
# Ponto ótimo x*: [ 0.14905656  0.46483765 -0.06281394 -0.19133108]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 43
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [np.float64(7.053649561841256e-12), np.float64(0.009732257332524983)]
#
# --- Início 49 ---
# Ponto inicial (após projeção): [ 0.23105568 -0.41240179  0.20732495 -0.0935415 ]
# Ponto ótimo x*: [ 0.13794553 -0.41600723  0.2347838  -0.10600647]
# Vetor do subproblema final: [-2.52638023e-04 -7.70831050e-06  6.51625150e-05 -2.96377829e-05]
# Número de iterações: 49
# Valor final de φ: -3.450497462419751e-08
# Imagem da solução ótima F(x*): [np.float64(2.9112962056350814e-08), np.float64(0.4935489348914466)]
#
# --- Início 50 ---
# Ponto inicial (após projeção): [ 0.07686269 -0.25570628 -0.24367703 -0.19793613]
# Ponto ótimo x*: [ 0.08861237 -0.24837064 -0.23979844 -0.19477455]
# Vetor do subproblema final: [-4.06457873e-03  3.18111279e-05 -9.88559167e-04 -8.05581109e-04]
# Número de iterações: 49
# Valor final de φ: -9.074340526625372e-06
# Imagem da solução ótima F(x*): [np.float64(5.957863117479985e-06), np.float64(0.15157668710461322)]
#
# Tempo de execução do multi-start: 14.0875 segundos
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# /tmp/ipython-input-47-1249479138.py:250: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern

# %%
# ==========================================================
#  Multi-start para o problema TRIDIA (convexo, 3 objetivos)
# ==========================================================

import time                      # medição de tempo total
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize

np.random.seed(4)                # reprodutibilidade

# ——————————————————————————————————————————————
# Configurações de fonte (MathText sem LaTeX externo)
plt.rcParams['text.usetex']      = False
plt.rcParams['font.family']      = 'serif'
plt.rcParams['font.serif']       = ['Computer Modern']
plt.rcParams['mathtext.fontset'] = 'cm'
# ——————————————————————————————————————————————

# ==========================================================
#  1) Definição de F e de seus gradientes
# ==========================================================

def F(x):
    """
    Função TRIDIA (convexa) com 3 componentes:
      f1(x) = (2x0 − 1)²
      f2(x) = 2·(2x0 − x1)²
      f3(x) = 3·(2x1 − x2)²
    """
    f1 = (2*x[0] - 1)**2
    f2 = 2*(2*x[0] - x[1])**2
    f3 = 3*(2*x[1] - x[2])**2
    return np.array([f1, f2, f3])


def TRIDIAgrad(x):
    """
    Retorna (∇f1, ∇f2, ∇f3), cada qual em ℝ³.
    """
    g1 = np.array([4*(2*x[0] - 1),             0,                        0])
    g2 = np.array([8*(2*x[0] - x[1]),  -4*(2*x[0] - x[1]),              0])
    g3 = np.array([          0,       12*(2*x[1] - x[2]),   -6*(2*x[1] - x[2])])
    return g1, g2, g3


# ==========================================================
# 2) Funções auxiliares: Armijo, A_k, projeção, etc.
# ==========================================================

def Armijo_tamanho_passo(z, d, F_fun, slope_vec, A_k, delta):
    """
    Critério de Armijo não-monótono (máximo) em vetor:
      F(z + αd) ≤ A_k + δ α slope_vec
    Busca α = 1/2ʲ, j = 0,…,19.
    """
    for j in range(20):
        alpha = 1 / (2**j)
        if np.all(F_fun(z + alpha*d) <= A_k + delta*alpha*slope_vec):
            return alpha
    return 1.0


def compute_A_k(valores_F, k, M=10):
    """
    A_k = máximo componente-a-componente dos últimos min(k,M) valores de F.
    """
    m_k   = min(k, M)
    recentes = valores_F[max(0, k-m_k): k+1]
    return np.max(recentes, axis=0) if recentes else valores_F[-1]


def projecao_caixa(x, bounds):
    """
    Projeta x na caixa ‘bounds’.
    """
    lo = np.array([b[0] for b in bounds])
    up = np.array([b[1] for b in bounds])
    return np.clip(x, lo, up)


# ==========================================================
# BUSCA DE DIREÇÕES
# ==========================================================

def buscadirecao(x, bounds, tol_slsqp=1e-10):
    g1, g2, g3 = TRIDIAgrad(x)
    G          = np.vstack([g1, g2, g3])       # matriz 3×3

    dt0 = np.concatenate([np.zeros_like(x), [0.0]])     # ponto inicial

    # função-objetivo e gradiente
    obj      = lambda dt: dt[-1] + 0.5*np.dot(dt[:-1], dt[:-1])
    obj_grad = lambda dt: np.concatenate([dt[:-1], [1.0]])

    # restrições t
    cons = [{'type': 'ineq',
             'fun' : (lambda dt, i=i: dt[-1] - np.dot(G[i], dt[:-1]))}
            for i in range(3)]

    # restrições da caixa x+d ∈ bounds
    for i, (lo, up) in enumerate(bounds):
        cons.append({'type': 'ineq',
                     'fun' : lambda dt, i=i, up=up:  up - (x[i] + dt[i])})
        cons.append({'type': 'ineq',
                     'fun' : lambda dt, i=i, lo=lo: (x[i] + dt[i]) - lo})

    res = minimize(obj, dt0, jac=obj_grad, constraints=cons,
                   method='SLSQP',
                   options={'ftol': tol_slsqp, 'maxiter': 500, 'disp': False})

    d_opt = res.x[:-1]
    phi   = obj(res.x)
    return d_opt, res.x[-1], phi          # d*, t*, φ(d*)


# ==========================================================
# 4) Algoritmo principal PGMMOP
# ==========================================================

def PGMMOP(x0, bounds, max_iter=50, M=10, delta=0.5, tol_inner=1e-8):
          """
    Devolve:
      x*         – ponto final
      d_last     – direção da última iteração
      k          – nº de iterações executadas
      phi_last   – phi final
      F(x*)      – imagem final
      gamma_hist – histórico de phi(d^k)
    """
    x        = x0.copy()
    hist_F   = []
    hist_phi = []

    for k in range(max_iter):
        Fx = F(x)
        hist_F.append(Fx)

        # — busca da direção —
        d, _, phi_val = buscadirecao(x, bounds)
        hist_phi.append(phi_val)

        # — critério de parada —
        if np.linalg.norm(d) <= tol_inner:
            break

        # — passo de Armijo não-monótono —
        A_k   = compute_A_k(hist_F, k, M)
        grads = TRIDIAgrad(x)
        slope = np.array([np.dot(g, d) for g in grads])
        alpha = Armijo_tamanho_passo(x, d, F, slope, A_k, delta)

        # — atualização —
        x = projecao_caixa(x + alpha*d, bounds)

    return x, d, k, phi_val, F(x), hist_phi


# ==========================================================
# 5) Loop multi-start
# ==========================================================

bounds       = [(-0.5, 0.5)] * 3         # caixa de viabilidade
num_starts   = 50
solucoes     = []
solucoes_F   = []

print("\n===== RESULTADOS DO MULTI-START (TRIDIA) =====")

t0 = time.time()

for i in range(num_starts):
    x_ini = np.random.uniform([b[0] for b in bounds],
                              [b[1] for b in bounds])
    x_ini = projecao_caixa(x_ini, bounds)

    x_opt, d_last, iters, phi_last, Fx, _ = PGMMOP(x_ini, bounds)
    solucoes    .append(x_opt)
    solucoes_F  .append(Fx)

    print(f"\n— Partida {i+1:02d} —")
    print("x inicial:",       x_ini)
    print("x* obtido:",       x_opt)
    print("Iterações:",       iters, "   φ final:", phi_last)
    print("F(x*):",           Fx)

print(f"\nTempo total do multi-start: {time.time() - t0:.2f} s")


# ==========================================================
# 6) Geração de amostras para o espaço dos objetivos
# ==========================================================

num_amostras = 600
amostras = np.random.uniform([b[0] for b in bounds],
                             [b[1] for b in bounds],
                             size=(num_amostras, 3))
val_F = np.array([F(p) for p in amostras])

# ==========================================================
# 7) Separação de soluções dominadas / não-dominadas
# ==========================================================

def domina(a, b):
    a, b = np.asarray(a), np.asarray(b)
    return np.all(a <= b) and np.any(a < b)

dom_d, dom_nd = [], []

for sol in solucoes_F:
    dominated = any(domina(other, sol) for other in solucoes_F
                    if not np.array_equal(sol, other))
    if not dominated:
        dominated = any(domina(pt, sol) for pt in val_F)
    (dom_d if dominated else dom_nd).append(sol)

# ==========================================================
# 8) PLOT 3-D (mantido sem alterações de idioma)
# ==========================================================

fig = plt.figure(figsize=(9, 6))
ax  = fig.add_subplot(111, projection='3d')

# Pontos amostrados (azul)
ax.scatter(val_F[:,0], val_F[:,1], val_F[:,2],
           s=3, alpha=0.35, color='blue', label="Pontos Objetivo")

# Soluções dominadas (amarelo)
for sol in dom_d:
    ax.scatter(*sol, s=35, color='yellow', edgecolor='black',
               label="Solução Dominada"
               if "Solução Dominada" not in ax.get_legend_handles_labels()[1] else "")

# Soluções não-dominadas (vermelho)
for sol in dom_nd:
    ax.scatter(*sol, s=35, color='red', edgecolor='black',
               label="Solução Não Dominada"
               if "Solução Não Dominada" not in ax.get_legend_handles_labels()[1] else "")

ax.set_title("Objective Space (TRIDIA)\nRandom samples vs. multi-start solutions")
ax.set_xlabel(r"$f_1(x)$")
ax.set_ylabel(r"$f_2(x)$")
ax.set_zlabel(r"$f_3(x)$")
ax.legend()
plt.tight_layout()
plt.show()
# Out:
# ===== RESULTADOS DO MULTI-START (TRIDIA) =====
#
# — Partida 01 —
# x inicial: [0.46702984 0.04723225 0.47268436]
# x* obtido: [0.5        0.11562408 0.47268436]
# Iterações: 1    φ final: 0.0
# F(x*): [1.23259516e-32 1.56424154e+00 1.74874323e-01]
#
# — Partida 02 —
# x inicial: [ 0.21481599  0.19772882 -0.2839105 ]
# x* obtido: [0.27147041 0.5        0.35051065]
# Iterações: 5    φ final: 0.0
# F(x*): [0.20890308 0.00368783 1.26550926]
#
# — Partida 03 —
# x inicial: [ 0.47627445 -0.49376974 -0.24701764]
# x* obtido: [ 0.5        -0.44573481 -0.24701764]
# Iterações: 2    φ final: 0.0
# F(x*): [0.         4.18029827 1.24595506]
#
# — Partida 04 —
# x inicial: [-0.06520847  0.27938292 -0.30231493]
# x* obtido: [0.34481497 0.45831003 0.5       ]
# Iterações: 7    φ final: 0.0
# F(x*): [0.09632958 0.1070178  0.52071682]
#
# — Partida 05 —
# x inicial: [ 0.36299324  0.48340068 -0.33615776]
# x* obtido: [ 0.36829729  0.5        -0.30221548]
# Iterações: 1    φ final: 0.0
# F(x*): [0.06938241 0.11195399 5.08729548]
#
# — Partida 06 —
# x inicial: [ 0.09733394 -0.4910139  -0.11342872]
# x* obtido: [0.39059323 0.39250411 0.5       ]
# Iterações: 6    φ final: 0.0
# F(x*): [0.04787937 0.30214793 0.24368905]
#
# — Partida 07 —
# x inicial: [-0.45583994  0.45665297 -0.06385335]
# x* obtido: [0.45883567 0.38997087 0.5       ]
# Iterações: 7    φ final: 0.0
# F(x*): [0.00677801 0.55693558 0.23510212]
#
# — Partida 08 —
# x inicial: [0.44897731 0.28630599 0.3662893 ]
# x* obtido: [0.47832851 0.34909155 0.5       ]
# Iterações: 3    φ final: 0.0
# F(x*): [0.00187861 0.73827161 0.11782962]
#
# — Partida 09 —
# x inicial: [-0.32683458 -0.42505141  0.10074272]
# x* obtido: [0.16624393 0.33248612 0.08921211]
# Iterações: 18    φ final: 0.0
# F(x*): [4.45572448e-01 6.11142183e-12 9.94499177e-01]
#
# — Partida 10 —
# x inicial: [-0.33202782  0.23338017 -0.09155614]
# x* obtido: [0.32876957 0.40292641 0.5       ]
# Iterações: 7    φ final: 0.0
# F(x*): [0.11727943 0.12965529 0.28063785]
#
# — Partida 11 —
# x inicial: [0.02790882 0.43757158 0.02169612]
# x* obtido: [0.26911322 0.5        0.45911853]
# Iterações: 6    φ final: 0.0
# F(x*): [0.21323482 0.00292252 0.8776583 ]
#
# — Partida 12 —
# x inicial: [-0.39180662 -0.34177659  0.04520265]
# x* obtido: [-0.00584114 -0.01168417 -0.08436261]
# Iterações: 10    φ final: 0.0
# F(x*): [1.02350103e+00 7.14969522e-12 1.11609026e-02]
#
# — Partida 13 —
# x inicial: [ 0.02440408  0.13761024 -0.09850456]
# x* obtido: [0.08622302 0.17244177 0.05063248]
# Iterações: 9    φ final: 0.0
# F(x*): [6.84845563e-01 3.64064079e-11 2.59751058e-01]
#
# — Partida 14 —
# x inicial: [ 0.14980511 -0.1031      0.12391611]
# x* obtido: [0.24253355 0.29280962 0.5       ]
# Iterações: 5    φ final: 0.0
# F(x*): [0.26515589 0.07392588 0.02199196]
#
# — Partida 15 —
# x inicial: [ 0.26740497 -0.32102609 -0.12442423]
# x* obtido: [0.49999521 0.22397915 0.27813911]
# Iterações: 24    φ final: 0.0
# F(x*): [9.17595403e-11 1.20438699e+00 8.65156753e-02]
#
# — Partida 16 —
# x inicial: [ 0.00253306  0.18666708 -0.24632035]
# x* obtido: [ 0.09713805  0.19427486 -0.06256325]
# Iterações: 10    φ final: 0.0
# F(x*): [6.49191000e-01 3.09652310e-12 6.10508722e-01]
#
# — Partida 17 —
# x inicial: [0.05474086 0.12493084 0.39550117]
# x* obtido: [0.09825575 0.19650818 0.38540502]
# Iterações: 19    φ final: 0.0
# F(x*): [6.45593767e-01 2.20513514e-11 1.73797523e-04]
#
# — Partida 18 —
# x inicial: [-0.13714641  0.13755707 -0.3085536 ]
# x* obtido: [0.11845266 0.23690324 0.09715517]
# Iterações: 11    φ final: 0.0
# F(x*): [5.82313483e-01 8.71298915e-12 4.25598627e-01]
#
# — Partida 19 —
# x inicial: [-0.00220589 -0.3175546   0.41838304]
# x* obtido: [0.2572075  0.5        0.41838304]
# Iterações: 4    φ final: 0.0
# F(x*): [2.35792796e-01 4.15584243e-04 1.01483487e+00]
#
# — Partida 20 —
# x inicial: [-0.06817793  0.3301881  -0.0832237 ]
# x* obtido: [0.22243824 0.40375537 0.5       ]
# Iterações: 6    φ final: 0.0
# F(x*): [0.30816213 0.00338189 0.28368858]
#
# — Partida 21 —
# x inicial: [ 0.40466759 -0.09517478 -0.1688255 ]
# x* obtido: [0.4440663  0.07534859 0.14830604]
# Iterações: 49    φ final: -2.6255143530368637e-06
# F(x*): [1.25143143e-02 1.32123570e+00 1.71526534e-05]
#
# — Partida 22 —
# x inicial: [0.07213877 0.34544365 0.36101431]
# x* obtido: [0.15162871 0.30325284 0.48398659]
# Iterações: 9    φ final: 0.0
# F(x*): [4.85450223e-01 4.20348865e-11 4.50327755e-02]
#
# — Partida 23 —
# x inicial: [ 0.09568812 -0.41533839  0.09726661]
# x* obtido: [0.35660323 0.47982127 0.5       ]
# Iterações: 5    φ final: 0.0
# F(x*): [0.08225054 0.10893729 0.6338138 ]
#
# — Partida 24 —
# x inicial: [-0.25454629  0.23259345  0.39465129]
# x* obtido: [-0.03341555  0.16557661  0.33529891]
# Iterações: 49    φ final: -0.002021790069148295
# F(x*): [1.13812859e+00 1.08026687e-01 5.15601334e-05]
#
# — Partida 25 —
# x inicial: [ 0.01473397  0.10356351 -0.43493219]
# x* obtido: [ 0.04721736  0.0944313  -0.41735417]
# Iterações: 7    φ final: 0.0
# F(x*): [8.20048469e-01 2.34948483e-11 1.10249629e+00]
#
# — Partida 26 —
# x inicial: [ 0.04007473 -0.37081322  0.11456285]
# x* obtido: [0.19146916 0.34108243 0.5       ]
# Iterações: 6    φ final: 0.0
# F(x*): [0.38076513 0.00350383 0.0995521 ]
#
# — Partida 27 —
# x inicial: [-0.13634965  0.26775803 -0.45146586]
# x* obtido: [0.19184154 0.38368127 0.29372481]
# Iterações: 13    φ final: 0.0
# F(x*): [3.79846541e-01 6.61210890e-12 6.72998077e-01]
#
# — Partida 28 —
# x inicial: [-0.39018188  0.18402322  0.0146537 ]
# x* obtido: [0.28262489 0.27652291 0.5       ]
# Iterações: 10    φ final: 0.0
# F(x*): [0.18900776 0.1667264  0.00844158]
#
# — Partida 29 —
# x inicial: [ 0.07164137  0.34370699 -0.01226236]
# x* obtido: [0.15136797 0.30273327 0.10534311]
# Iterações: 9    φ final: 0.0
# F(x*): [4.86177164e-01 1.43444433e-11 7.50370319e-01]
#
# — Partida 30 —
# x inicial: [0.31014442 0.01024363 0.42672069]
# x* obtido: [0.44303517 0.34420019 0.5       ]
# Iterações: 3    φ final: 0.0
# F(x*): [0.01297997 0.58724652 0.10648411]
#
# — Partida 31 —
# x inicial: [ 0.16692777 -0.35127316 -0.13544682]
# x* obtido: [0.44950279 0.42109555 0.5       ]
# Iterações: 9    φ final: 0.0
# F(x*): [0.01019987 0.456796   0.35128426]
#
# — Partida 32 —
# x inicial: [ 0.36577492 -0.14971479 -0.31097424]
# x* obtido: [ 0.3716644  -0.08817145 -0.17567952]
# Iterações: 49    φ final: -5.532774222174438e-05
# F(x*): [6.58801046e-02 1.38278533e+00 1.32021311e-06]
#
# — Partida 33 —
# x inicial: [-0.02737869 -0.10721883  0.11892993]
# x* obtido: [0.03942322 0.07884484 0.13070895]
# Iterações: 13    φ final: 0.0
# F(x*): [8.48523876e-01 5.14305490e-12 2.18387894e-03]
#
# — Partida 34 —
# x inicial: [-0.06323371 -0.23907784 -0.08752779]
# x* obtido: [0.0100457  0.02008786 0.0381784 ]
# Iterações: 18    φ final: 0.0
# F(x*): [9.60220884e-01 2.49119172e-11 1.19679232e-05]
#
# — Partida 35 —
# x inicial: [-0.08096597  0.40242186  0.47961626]
# x* obtido: [0.43317016 0.36641495 0.5       ]
# Iterações: 6    φ final: 0.0
# F(x*): [0.01786491 0.49985076 0.16262929]
#
# — Partida 36 —
# x inicial: [ 0.12356884 -0.41681588  0.23299872]
# x* obtido: [0.42636919 0.5        0.23299872]
# Iterações: 2    φ final: 0.0
# F(x*): [0.02168598 0.24884873 1.7648729 ]
#
# — Partida 37 —
# x inicial: [ 0.1786854   0.32602287 -0.15254866]
# x* obtido: [ 0.17983012  0.3596553  -0.08467446]
# Iterações: 6    φ final: 0.0
# F(x*): [4.10034997e-01 4.89467296e-11 1.93917596e+00]
#
# — Partida 38 —
# x inicial: [-0.44111991  0.11182182 -0.37598538]
# x* obtido: [0.28480811 0.41034617 0.5       ]
# Iterações: 9    φ final: 0.0
# F(x*): [0.18523021 0.05073389 0.30853073]
#
# — Partida 39 —
# x inicial: [ 0.25952953  0.29442332 -0.09137321]
# x* obtido: [0.30623362 0.5        0.34062462]
# Iterações: 3    φ final: 0.0
# F(x*): [0.15018164 0.02529776 1.30432768]
#
# — Partida 40 —
# x inicial: [ 0.44379751 -0.32622021  0.44258585]
# x* obtido: [ 0.5        -0.20990896  0.44258585]
# Iterações: 2    φ final: 0.0
# F(x*): [4.93038066e-32 2.92775939e+00 2.23122080e+00]
#
# — Partida 41 —
# x inicial: [-0.03451033  0.26299364  0.2528202 ]
# x* obtido: [0.19461198 0.30894983 0.5       ]
# Iterações: 7    φ final: 0.0
# F(x*): [0.37304737 0.01288787 0.04170099]
#
# — Partida 42 —
# x inicial: [ 0.48120992  0.47327799 -0.45990888]
# x* obtido: [ 0.49417607  0.5        -0.40628184]
# Iterações: 3    φ final: 0.0
# F(x*): [1.35672547e-04 4.76975633e-01 5.93288581e+00]
#
# — Partida 43 —
# x inicial: [-0.48402872  0.04329032 -0.46612238]
# x* obtido: [0.31183421 0.34056327 0.5       ]
# Iterações: 10    φ final: 0.0
# F(x*): [0.14162546 0.16029704 0.09842047]
#
# — Partida 44 —
# x inicial: [0.15748464 0.0349026  0.1665584 ]
# x* obtido: [0.20353224 0.26321186 0.5       ]
# Iterações: 9    φ final: 0.0
# F(x*): [0.35157254 0.04138715 0.00209464]
#
# — Partida 45 —
# x inicial: [-0.0586593  -0.22752854  0.44966894]
# x* obtido: [0.14411471 0.28822726 0.40646505]
# Iterações: 14    φ final: 0.0
# F(x*): [5.06617372e-01 9.20671559e-12 8.66892721e-02]
#
# — Partida 46 —
# x inicial: [ 0.22826944 -0.49367606 -0.40067224]
# x* obtido: [0.49999455 0.14824747 0.0672462 ]
# Iterações: 24    φ final: 0.0
# F(x*): [1.18897649e-10 1.45092759e+00 1.57664962e-01]
#
# — Partida 47 —
# x inicial: [ 0.13169225 -0.21196317 -0.09237832]
# x* obtido: [0.28440416 0.40009326 0.5       ]
# Iterações: 7    φ final: 0.0
# F(x*): [0.18592627 0.05692954 0.27033583]
#
# — Partida 48 —
# x inicial: [ 0.28153112 -0.14585446  0.4258086 ]
# x* obtido: [0.5        0.39560503 0.4258086 ]
# Iterações: 2    φ final: 0.0
# F(x*): [0.         0.73058655 0.4005547 ]
#
# — Partida 49 —
# x inicial: [ 0.22045212  0.05192644 -0.31903516]
# x* obtido: [0.32664866 0.41800459 0.5       ]
# Iterações: 5    φ final: 0.0
# F(x*): [0.12020274 0.11072535 0.33870649]
#
# — Partida 50 —
# x inicial: [-0.09040861  0.26288179  0.49079682]
# x* obtido: [0.0063183  0.22263773 0.4500735 ]
# Iterações: 49    φ final: -0.0002739880539795869
# F(x*): [9.74886494e-01 8.82009517e-02 6.90636312e-05]
#
# Tempo total do multi-start: 2.96 s
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern

# %%
import time  # Importa o módulo para medição de tempo
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize
import pygmo as pg  # Certifique-se de instalar o PyGMO (pip install pygmo)
from matplotlib.patches import Polygon
np.random.seed(4)
# ——————————————————————————————
# 1) Use MathText sem LaTeX externo, mas com Computer Modern
plt.rcParams['text.usetex']        = False
plt.rcParams['font.family']        = 'serif'
plt.rcParams['font.serif']         = ['Computer Modern']
plt.rcParams['mathtext.fontset']   = 'cm'
# ——————————————————————————————
##############################
# 6° FUNÇÃO: TRIDIA (Convexa)
##############################

def F(x):
    """
    Função TRIDIA – convexa:
      f1(x) = (2*x[0]-1)^2
      f2(x) = 2*(2*x[0]-x[1])^2
      f3(x) = 3*(2*x[1]-x[2])^2
    Entrada: x em R^3
    Saída: vetor com as três componentes
    """
    f1 = (2 * x[0] - 1)**2
    f2 = 2 * (2 * x[0] - x[1])**2
    f3 = 3 * (2 * x[1] - x[2])**2
    return np.array([f1, f2, f3])

def TRIDIAgrad(x):
    """
    Gradientes das funções de TRIDIA.
    """
    grad_f1 = np.array([4 * (2 * x[0] - 1), 0, 0])
    grad_f2 = np.array([8 * (2 * x[0] - x[1]), -4 * (2 * x[0] - x[1]), 0])
    grad_f3 = np.array([0, 12 * (2 * x[1] - x[2]), -6 * (2 * x[1] - x[2])])
    return grad_f1, grad_f2, grad_f3

##########################################
# FUNÇÕES AUXILIARES: φ, gradφ, gamma, etc.
##########################################


def armijo_step_size(x, d, F_fun, slope_vec, A_k, delta=0.5):
    """
    Encontra α por Armijo:  F(x+αd) ≤ A_k + δ α slope_vec   (vetorial)
    """
    for j in range(20):
        alpha = 1 / (2**j)
        if np.all(F_fun(x + alpha*d) <= A_k + delta*alpha*slope_vec):
            return alpha
    return 1.0


def compute_A_k(f_values, k, m_prev, M):
    """
    Calcula A^k a partir dos últimos valores de F(x) armazenados.
    Para TRIDIA (3 objetivos), A_k é uma tupla com os valores máximos recentes de cada
    componente de F.
    """
    m_k = min(m_prev + 1, M) if k > 0 else 0
    recent_values = f_values[max(0, k - m_k):k + 1]
    if not recent_values:
        A_1_k, A_2_k, A_3_k = f_values[-1][0], f_values[-1][1], f_values[-1][2]
    else:
        A_1_k = max(f[0] for f in recent_values)
        A_2_k = max(f[1] for f in recent_values)
        A_3_k = max(f[2] for f in recent_values)
    return (A_1_k, A_2_k, A_3_k), m_k

def jacobian_F(x):
    """
    Calcula a "jacobiana" de F, isto é, empilha os gradientes das três funções.
    """
    grad_f1, grad_f2, grad_f3 = TRIDIAgrad(x)
    return np.array([grad_f1, grad_f2, grad_f3])
# ------------------------------------------------------------------
# Sub-problema   min_{d,t}  t + ½‖d‖²
#                s.a.       t ≥ ∇f_i·d  (i=1,2,3)  e  x+d ∈ caixa
# ------------------------------------------------------------------
def solve_subproblem_epigraph(x, bounds, tol=1e-10):
    G   = np.array(TRIDIAgrad(x))          # shape (3,3)
    dt0 = np.concatenate([np.zeros_like(x), [0.]])

    obj      = lambda dt: dt[-1] + 0.5*np.dot(dt[:-1], dt[:-1])
    obj_grad = lambda dt: np.concatenate([dt[:-1], [1.]])

    cons = [{"type": "ineq",
             "fun":  (lambda dt,i=i: dt[-1] - np.dot(G[i], dt[:-1]))}
            for i in range(3)]

    # caixa:  x+d dentro dos limites
    for i, (lo, up) in enumerate(bounds):
        cons.append({"type": "ineq", "fun": lambda dt,i=i,up=up:  up - (x[i] + dt[i])})
        cons.append({"type": "ineq", "fun": lambda dt,i=i,lo=lo: (x[i] + dt[i]) - lo})

    res = minimize(obj, dt0, jac=obj_grad, constraints=cons,
                   method="SLSQP",
                   options={"ftol": tol, "maxiter": 500, "disp": False})

    return res.x[:-1], obj(res.x)          # d*, φ(d*)

# γ(x) agora vem direto do epígrafe
def gamma(x, bounds):
    _, phi_val = solve_subproblem_epigraph(x, bounds)
    return phi_val

def project_to_box(x, bounds):
    """
    Projeta o vetor x na caixa definida por bounds.
    """
    lower = np.array([b[0] for b in bounds])
    upper = np.array([b[1] for b in bounds])
    return np.clip(x, lower, upper)

#############################################
# FUNÇÃO DE OTIMIZAÇÃO: EXECUÇÃO DE UMA PARTIDA
#############################################

def optimization_run(x0, bounds, max_iter=50, M=10, delta=0.5, tol=1e-8):
    f_history, γ_history = [], []
    m_k = 0                                   # janela não-monótona

    for k in range(max_iter):
        Fx = F(x0)
        f_history.append(Fx)

        # ---------- sub-problema epígrafe ----------
        d, phi_val = solve_subproblem_epigraph(x0, bounds)
        γ_history.append(phi_val)

        # critério de parada
        if np.linalg.norm(d) <= tol:
            break

        # ---------- Armijo não-monótono ----------
        A_k, m_k = compute_A_k(f_history, k, m_k, M)
        J        = jacobian_F(x0)             # 3×3
        slope    = J @ d                      # vetor 3
        alpha_k  = armijo_step_size(x0, d, F, slope, A_k, delta)

        # ---------- atualização ----------
        x0 = project_to_box(x0 + alpha_k*d, bounds)

    return x0, d, k, phi_val, F(x0), γ_history


#############################################
# CONFIGURAÇÃO INICIAL E LOOP MULTI-START
#############################################

# Definindo a caixa de viabilidade para TRIDIA (dimensão 3)
bounds = [(-0.5, 0.5), (-0.5, 0.5), (-0.5, 0.5)]

num_starts = 50  # Número de partidas (pontos iniciais)
solutions = []           # Armazena os pontos ótimos x*
solution_images = []     # Armazena F(x*) de cada partida
all_details = []         # Guarda detalhes de cada execução (ponto inicial, x*, dk, iters, final_phi, F(x*))
initial_points = []

print("===== RESULTADOS DO MULTI-START PARA TRIDIA =====")

start_time = time.time()  # Inicia a medição do tempo

for i in range(num_starts):
    # Gera ponto inicial aleatório na caixa
    x_init = np.random.uniform([b[0] for b in bounds], [b[1] for b in bounds])
    x_init = project_to_box(x_init, bounds)
    initial_points.append(x_init)

    x_opt, subproblem_vec, iters, final_phi, Fx, gamma_history = optimization_run(x_init, bounds)
    solutions.append(x_opt)
    solution_images.append(Fx)
    all_details.append((x_init, x_opt, subproblem_vec, iters, final_phi, Fx))

    print(f"\n--- Partida {i+1} ---")
    print("Ponto inicial (após projeção):", x_init)
    print("Ponto ótimo x*:", x_opt)
    print("Vetor do subproblema final:", subproblem_vec)
    print("Número de iterações:", iters)
    print("Valor final de φ:", final_phi)
    print("Imagem da solução ótima F(x*):", Fx)

end_time = time.time()  # Termina a medição do tempo
elapsed_time = end_time - start_time
print(f"\nTempo de execução do multi-start: {elapsed_time:.4f} segundos")

#############################################
# GERAÇÃO DOS PONTOS PARA O ESPAÇO DOS OBJETIVOS
#############################################

num_points = 300  # Número de pontos para o espaço dos objetivos
samples = np.random.uniform(
    [b[0] for b in bounds],
    [b[1] for b in bounds],
    size=(num_points, len(bounds))
)
# Mapeia os pontos para o espaço dos objetivos (R^3)
objective_values = np.array([F(sample) for sample in samples])
f1_values = objective_values[:, 0]
f2_values = objective_values[:, 1]
f3_values = objective_values[:, 2]

#############################################
# VERIFICAÇÃO DE DOMINÂNCIA
#############################################

def domina(sol1, sol2):
    """
    Retorna True se sol1 domina sol2, isto é, se sol1 é menor ou igual
    que sol2 em todas as componentes e estritamente menor em pelo menos uma.
    """
    sol1 = np.array(sol1)
    sol2 = np.array(sol2)
    return np.all(sol1 <= sol2) and np.any(sol1 < sol2)

dominated_solutions = []     # soluções dominadas
nondominated_solutions = []  # soluções não dominadas

# Para cada solução ótima encontrada (imagem no espaço dos objetivos)
for sol in solution_images:
    dominated = False
    # Verifica dominância entre as soluções encontradas (multi-start)
    for other in solution_images:
        if not np.array_equal(sol, other):
            if domina(other, sol):
                dominated = True
                break
    # Se não for dominada entre as soluções, verifica dominância em relação aos pontos gerados
    if not dominated:
        # Verifica se existe algum ponto nos samples que domine a solução
        for point in objective_values:
            if domina(point, sol):
                dominated = True
                break
    if dominated:
        dominated_solutions.append(sol)
    else:
        nondominated_solutions.append(sol)

#############################################
# PLOT DO ESPAÇO DOS OBJETIVOS (3D)
#############################################

fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

# Pontos gerados (azuis)
ax.scatter(f1_values, f2_values, f3_values, alpha=0.5, s=5, marker='o', color="blue", label="Pontos Objetivo")

# Soluções dominadas (amarelo)
for sol in dominated_solutions:
    ax.scatter(sol[0], sol[1], sol[2], color="yellow", s=30, marker='o', edgecolor="black",
               label="Solução Dominada" if "Solução Dominada" not in [l.get_label() for l in ax.get_legend_handles_labels()[0]] else "")

# Soluções não dominadas (vermelho)
for sol in nondominated_solutions:
    ax.scatter(sol[0], sol[1], sol[2], color="red", s=30, marker='o', edgecolor="black",
               label="Solução Não Dominada" if "Solução Não Dominada" not in [l.get_label() for l in ax.get_legend_handles_labels()[0]] else "")

ax.set_title("Espaço dos Objetivos:\nPontos Gerados (Azul) e Soluções Multi-Start\nDominadas (Amarelo) vs. Não Dominadas (Vermelho)", fontsize=12)
ax.set_xlabel(r"$f_1(x)$", fontsize=12)
ax.set_ylabel(r"$f_2(x)$", fontsize=12)
ax.set_zlabel(r"$f_3(x)$", fontsize=12)
ax.legend()
plt.show()
# Out:
# ===== RESULTADOS DO MULTI-START PARA TRIDIA =====
#
# --- Partida 1 ---
# Ponto inicial (após projeção): [0.46702984 0.04723225 0.47268436]
# Ponto ótimo x*: [0.5        0.11562408 0.47268436]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 1
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [1.23259516e-32 1.56424154e+00 1.74874323e-01]
#
# --- Partida 2 ---
# Ponto inicial (após projeção): [ 0.21481599  0.19772882 -0.2839105 ]
# Ponto ótimo x*: [0.27147041 0.5        0.35051065]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 5
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [0.20890308 0.00368783 1.26550926]
#
# --- Partida 3 ---
# Ponto inicial (após projeção): [ 0.47627445 -0.49376974 -0.24701764]
# Ponto ótimo x*: [ 0.5        -0.44573481 -0.24701764]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 2
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [0.         4.18029827 1.24595506]
#
# --- Partida 4 ---
# Ponto inicial (após projeção): [-0.06520847  0.27938292 -0.30231493]
# Ponto ótimo x*: [0.34481497 0.45831003 0.5       ]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 7
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [0.09632958 0.1070178  0.52071682]
#
# --- Partida 5 ---
# Ponto inicial (após projeção): [ 0.36299324  0.48340068 -0.33615776]
# Ponto ótimo x*: [ 0.36829729  0.5        -0.30221548]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 1
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [0.06938241 0.11195399 5.08729548]
#
# --- Partida 6 ---
# Ponto inicial (após projeção): [ 0.09733394 -0.4910139  -0.11342872]
# Ponto ótimo x*: [0.39059323 0.39250411 0.5       ]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 6
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [0.04787937 0.30214793 0.24368905]
#
# --- Partida 7 ---
# Ponto inicial (após projeção): [-0.45583994  0.45665297 -0.06385335]
# Ponto ótimo x*: [0.45883567 0.38997087 0.5       ]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 7
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [0.00677801 0.55693558 0.23510212]
#
# --- Partida 8 ---
# Ponto inicial (após projeção): [0.44897731 0.28630599 0.3662893 ]
# Ponto ótimo x*: [0.47832851 0.34909155 0.5       ]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 3
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [0.00187861 0.73827161 0.11782962]
#
# --- Partida 9 ---
# Ponto inicial (após projeção): [-0.32683458 -0.42505141  0.10074272]
# Ponto ótimo x*: [0.16624393 0.33248612 0.08921211]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 18
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [4.45572448e-01 6.11142183e-12 9.94499177e-01]
#
# --- Partida 10 ---
# Ponto inicial (após projeção): [-0.33202782  0.23338017 -0.09155614]
# Ponto ótimo x*: [0.32876957 0.40292641 0.5       ]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 7
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [0.11727943 0.12965529 0.28063785]
#
# --- Partida 11 ---
# Ponto inicial (após projeção): [0.02790882 0.43757158 0.02169612]
# Ponto ótimo x*: [0.26911322 0.5        0.45911853]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 6
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [0.21323482 0.00292252 0.8776583 ]
#
# --- Partida 12 ---
# Ponto inicial (após projeção): [-0.39180662 -0.34177659  0.04520265]
# Ponto ótimo x*: [-0.00584114 -0.01168417 -0.08436261]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 10
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [1.02350103e+00 7.14969522e-12 1.11609026e-02]
#
# --- Partida 13 ---
# Ponto inicial (após projeção): [ 0.02440408  0.13761024 -0.09850456]
# Ponto ótimo x*: [0.08622302 0.17244177 0.05063248]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 9
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [6.84845563e-01 3.64064079e-11 2.59751058e-01]
#
# --- Partida 14 ---
# Ponto inicial (após projeção): [ 0.14980511 -0.1031      0.12391611]
# Ponto ótimo x*: [0.24253355 0.29280962 0.5       ]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 5
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [0.26515589 0.07392588 0.02199196]
#
# --- Partida 15 ---
# Ponto inicial (após projeção): [ 0.26740497 -0.32102609 -0.12442423]
# Ponto ótimo x*: [0.49999521 0.22397915 0.27813911]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 24
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [9.17595403e-11 1.20438699e+00 8.65156753e-02]
#
# --- Partida 16 ---
# Ponto inicial (após projeção): [ 0.00253306  0.18666708 -0.24632035]
# Ponto ótimo x*: [ 0.09713805  0.19427486 -0.06256325]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 10
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [6.49191000e-01 3.09652310e-12 6.10508722e-01]
#
# --- Partida 17 ---
# Ponto inicial (após projeção): [0.05474086 0.12493084 0.39550117]
# Ponto ótimo x*: [0.09825575 0.19650818 0.38540502]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 19
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [6.45593767e-01 2.20513514e-11 1.73797523e-04]
#
# --- Partida 18 ---
# Ponto inicial (após projeção): [-0.13714641  0.13755707 -0.3085536 ]
# Ponto ótimo x*: [0.11845266 0.23690324 0.09715517]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 11
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [5.82313483e-01 8.71298915e-12 4.25598627e-01]
#
# --- Partida 19 ---
# Ponto inicial (após projeção): [-0.00220589 -0.3175546   0.41838304]
# Ponto ótimo x*: [0.2572075  0.5        0.41838304]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 4
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [2.35792796e-01 4.15584243e-04 1.01483487e+00]
#
# --- Partida 20 ---
# Ponto inicial (após projeção): [-0.06817793  0.3301881  -0.0832237 ]
# Ponto ótimo x*: [0.22243824 0.40375537 0.5       ]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 6
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [0.30816213 0.00338189 0.28368858]
#
# --- Partida 21 ---
# Ponto inicial (após projeção): [ 0.40466759 -0.09517478 -0.1688255 ]
# Ponto ótimo x*: [0.4440663  0.07534859 0.14830604]
# Vetor do subproblema final: [ 1.17336476e-05  2.04955329e-03 -1.02477665e-03]
# Número de iterações: 49
# Valor final de φ: -2.6255143530368637e-06
# Imagem da solução ótima F(x*): [1.25143143e-02 1.32123570e+00 1.71526534e-05]
#
# --- Partida 22 ---
# Ponto inicial (após projeção): [0.07213877 0.34544365 0.36101431]
# Ponto ótimo x*: [0.15162871 0.30325284 0.48398659]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 9
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [4.85450223e-01 4.20348865e-11 4.50327755e-02]
#
# --- Partida 23 ---
# Ponto inicial (após projeção): [ 0.09568812 -0.41533839  0.09726661]
# Ponto ótimo x*: [0.35660323 0.47982127 0.5       ]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 5
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [0.08225054 0.10893729 0.6338138 ]
#
# --- Partida 24 ---
# Ponto inicial (após projeção): [-0.25454629  0.23259345  0.39465129]
# Ponto ótimo x*: [-0.03341555  0.16557661  0.33529891]
# Vetor do subproblema final: [ 0.00094746 -0.05686955  0.02843478]
# Número de iterações: 49
# Valor final de φ: -0.002021790069148295
# Imagem da solução ótima F(x*): [1.13812859e+00 1.08026687e-01 5.15601334e-05]
#
# --- Partida 25 ---
# Ponto inicial (após projeção): [ 0.01473397  0.10356351 -0.43493219]
# Ponto ótimo x*: [ 0.04721736  0.0944313  -0.41735417]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 7
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [8.20048469e-01 2.34948483e-11 1.10249629e+00]
#
# --- Partida 26 ---
# Ponto inicial (após projeção): [ 0.04007473 -0.37081322  0.11456285]
# Ponto ótimo x*: [0.19146916 0.34108243 0.5       ]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 6
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [0.38076513 0.00350383 0.0995521 ]
#
# --- Partida 27 ---
# Ponto inicial (após projeção): [-0.13634965  0.26775803 -0.45146586]
# Ponto ótimo x*: [0.19184154 0.38368127 0.29372481]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 13
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [3.79846541e-01 6.61210890e-12 6.72998077e-01]
#
# --- Partida 28 ---
# Ponto inicial (após projeção): [-0.39018188  0.18402322  0.0146537 ]
# Ponto ótimo x*: [0.28262489 0.27652291 0.5       ]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 10
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [0.18900776 0.1667264  0.00844158]
#
# --- Partida 29 ---
# Ponto inicial (após projeção): [ 0.07164137  0.34370699 -0.01226236]
# Ponto ótimo x*: [0.15136797 0.30273327 0.10534311]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 9
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [4.86177164e-01 1.43444433e-11 7.50370319e-01]
#
# --- Partida 30 ---
# Ponto inicial (após projeção): [0.31014442 0.01024363 0.42672069]
# Ponto ótimo x*: [0.44303517 0.34420019 0.5       ]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 3
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [0.01297997 0.58724652 0.10648411]
#
# --- Partida 31 ---
# Ponto inicial (após projeção): [ 0.16692777 -0.35127316 -0.13544682]
# Ponto ótimo x*: [0.44950279 0.42109555 0.5       ]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 9
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [0.01019987 0.456796   0.35128426]
#
# --- Partida 32 ---
# Ponto inicial (após projeção): [ 0.36577492 -0.14971479 -0.31097424]
# Ponto ótimo x*: [ 0.3716644  -0.08817145 -0.17567952]
# Vetor do subproblema final: [0.00010774 0.00024876 0.01051463]
# Número de iterações: 49
# Valor final de φ: -5.532774222174438e-05
# Imagem da solução ótima F(x*): [6.58801046e-02 1.38278533e+00 1.32021311e-06]
#
# --- Partida 33 ---
# Ponto inicial (após projeção): [-0.02737869 -0.10721883  0.11892993]
# Ponto ótimo x*: [0.03942322 0.07884484 0.13070895]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 13
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [8.48523876e-01 5.14305490e-12 2.18387894e-03]
#
# --- Partida 34 ---
# Ponto inicial (após projeção): [-0.06323371 -0.23907784 -0.08752779]
# Ponto ótimo x*: [0.0100457  0.02008786 0.0381784 ]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 18
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [9.60220884e-01 2.49119172e-11 1.19679232e-05]
#
# --- Partida 35 ---
# Ponto inicial (após projeção): [-0.08096597  0.40242186  0.47961626]
# Ponto ótimo x*: [0.43317016 0.36641495 0.5       ]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 6
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [0.01786491 0.49985076 0.16262929]
#
# --- Partida 36 ---
# Ponto inicial (após projeção): [ 0.12356884 -0.41681588  0.23299872]
# Ponto ótimo x*: [0.42636919 0.5        0.23299872]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 2
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [0.02168598 0.24884873 1.7648729 ]
#
# --- Partida 37 ---
# Ponto inicial (após projeção): [ 0.1786854   0.32602287 -0.15254866]
# Ponto ótimo x*: [ 0.17983012  0.3596553  -0.08467446]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 6
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [4.10034997e-01 4.89467296e-11 1.93917596e+00]
#
# --- Partida 38 ---
# Ponto inicial (após projeção): [-0.44111991  0.11182182 -0.37598538]
# Ponto ótimo x*: [0.28480811 0.41034617 0.5       ]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 9
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [0.18523021 0.05073389 0.30853073]
#
# --- Partida 39 ---
# Ponto inicial (após projeção): [ 0.25952953  0.29442332 -0.09137321]
# Ponto ótimo x*: [0.30623362 0.5        0.34062462]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 3
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [0.15018164 0.02529776 1.30432768]
#
# --- Partida 40 ---
# Ponto inicial (após projeção): [ 0.44379751 -0.32622021  0.44258585]
# Ponto ótimo x*: [ 0.5        -0.20990896  0.44258585]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 2
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [4.93038066e-32 2.92775939e+00 2.23122080e+00]
#
# --- Partida 41 ---
# Ponto inicial (após projeção): [-0.03451033  0.26299364  0.2528202 ]
# Ponto ótimo x*: [0.19461198 0.30894983 0.5       ]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 7
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [0.37304737 0.01288787 0.04170099]
#
# --- Partida 42 ---
# Ponto inicial (após projeção): [ 0.48120992  0.47327799 -0.45990888]
# Ponto ótimo x*: [ 0.49417607  0.5        -0.40628184]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 3
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [1.35672547e-04 4.76975633e-01 5.93288581e+00]
#
# --- Partida 43 ---
# Ponto inicial (após projeção): [-0.48402872  0.04329032 -0.46612238]
# Ponto ótimo x*: [0.31183421 0.34056327 0.5       ]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 10
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [0.14162546 0.16029704 0.09842047]
#
# --- Partida 44 ---
# Ponto inicial (após projeção): [0.15748464 0.0349026  0.1665584 ]
# Ponto ótimo x*: [0.20353224 0.26321186 0.5       ]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 9
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [0.35157254 0.04138715 0.00209464]
#
# --- Partida 45 ---
# Ponto inicial (após projeção): [-0.0586593  -0.22752854  0.44966894]
# Ponto ótimo x*: [0.14411471 0.28822726 0.40646505]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 14
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [5.06617372e-01 9.20671559e-12 8.66892721e-02]
#
# --- Partida 46 ---
# Ponto inicial (após projeção): [ 0.22826944 -0.49367606 -0.40067224]
# Ponto ótimo x*: [0.49999455 0.14824747 0.0672462 ]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 24
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [1.18897649e-10 1.45092759e+00 1.57664962e-01]
#
# --- Partida 47 ---
# Ponto inicial (após projeção): [ 0.13169225 -0.21196317 -0.09237832]
# Ponto ótimo x*: [0.28440416 0.40009326 0.5       ]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 7
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [0.18592627 0.05692954 0.27033583]
#
# --- Partida 48 ---
# Ponto inicial (após projeção): [ 0.28153112 -0.14585446  0.4258086 ]
# Ponto ótimo x*: [0.5        0.39560503 0.4258086 ]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 2
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [0.         0.73058655 0.4005547 ]
#
# --- Partida 49 ---
# Ponto inicial (após projeção): [ 0.22045212  0.05192644 -0.31903516]
# Ponto ótimo x*: [0.32664866 0.41800459 0.5       ]
# Vetor do subproblema final: [0. 0. 0.]
# Número de iterações: 5
# Valor final de φ: 0.0
# Imagem da solução ótima F(x*): [0.12020274 0.11072535 0.33870649]
#
# --- Partida 50 ---
# Ponto inicial (após projeção): [-0.09040861  0.26288179  0.49079682]
# Ponto ótimo x*: [0.0063183  0.22263773 0.4500735 ]
# Vetor do subproblema final: [ 0.00013874 -0.02093718  0.01046859]
# Número de iterações: 49
# Valor final de φ: -0.0002739880539795869
# Imagem da solução ótima F(x*): [9.74886494e-01 8.82009517e-02 6.90636312e-05]
#
# Tempo de execução do multi-start: 6.5956 segundos
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern

# %%
# ==========================================================
#  Multi-start – Brown-Dennis (não convexa)
# ==========================================================
import time
import numpy as np
import matplotlib.pyplot as plt
from  scipy.optimize import minimize
from mpl_toolkits.mplot3d import Axes3D

np.random.seed(7)   # reprodutibilidade
# 1) Configurações de fonte (MathText → Computer Modern)
plt.rcParams['text.usetex']      = False
plt.rcParams['font.family']      = 'serif'
plt.rcParams['font.serif']       = ['Computer Modern']
plt.rcParams['mathtext.fontset'] = 'cm'


# ==========================================================
#  Dados do problema Brown-Dennis
# ==========================================================
t1, t2, t3 = 1/5, 2/5, 3/5
bounds     = [(-0.1, 0.1), (-5, 5), (-5, 5), (-10, 10)]   # caixa viável
num_starts = 50
max_iter   = 50

# ==================================================
#  Função objetivo e seus gradientes
# ====================================================
def F(x):
    A = [x[0] + t1*x[1] - np.exp(t1),
         x[0] + t2*x[1] - np.exp(t2),
         x[0] + t3*x[1] - np.exp(t3)]
    B = [x[2] + x[3]*np.sin(t1),
         x[2] + x[3]*np.sin(t2),
         x[2] + x[3]*np.sin(t3)]
    return np.array([A[0]**2 + B[0]**2,
                     A[1]**2 + B[1]**2,
                     A[2]**2 + B[2]**2])

def grad_F(x):
    """Gradiente de F"""
    grads = []
    for t in (t1, t2, t3):
        A = x[0] + t*x[1] - np.exp(t)
        B = x[2] + x[3]*np.sin(t)
        grads.append([ 2*A,
                       2*t*A,
                       2*B,
                       2*np.sin(t)*B ])
    return np.array(grads)

# ==========================================================
#  Busca de direção por SLSQP
# ==========================================================
def buscasolucao(x, bounds, tol=1e-10):
    G   = grad_F(x)                       # matriz de gradientes
    dt0 = np.concatenate([np.zeros_like(x), [0.0]])

    fun_obj      = lambda dt: dt[-1] + 0.5*np.dot(dt[:-1], dt[:-1])
    fun_obj_grad = lambda dt: np.concatenate([dt[:-1], [1.0]])

    # restrições de t
    cons = [{'type': 'ineq',
             'fun' : lambda dt, i=i: dt[-1] - np.dot(G[i], dt[:-1])}
            for i in range(3)]

    # restrições de caixa para x+d
    for i, (lo, up) in enumerate(bounds):
        cons.append({'type':'ineq', 'fun': lambda dt,i=i,up=up:  up - (x[i] + dt[i])})
        cons.append({'type':'ineq', 'fun': lambda dt,i=i,lo=lo: (x[i] + dt[i]) - lo})

    res = minimize(fun_obj, dt0, jac=fun_obj_grad, constraints=cons,
                   method='SLSQP',
                   options={'ftol': tol, 'maxiter': 500, 'disp': False})

    d_opt = res.x[:-1]       # direção ótima
    phi   = fun_obj(res.x)   # phi(d*)
    return d_opt, phi


# ==============================================
#  Armijo não-monótono
# ============================================
def Armijo_tamanho_passo(z, d, F_fun, JF_vec, A_k, delta):
    """
    Critério de Armijo não-monótono (máximo) em vetor:
      F(z + αd) ≤ A_k + delta t JF_vec
    Busca α = 1/2^j, j = 0,…,19.
    """
    for j in range(20):
        alpha = 1 / (2**j)
        if np.all(F_fun(z + alpha*d) <= A_k + delta*alpha*JF_vec):
            return alpha
    return 1.0


def compute_A_k(valores_F, k, M=10):
    """
    A_k = máximo componente-a-componente dos últimos min(k,M) valores de F.
    """
    m_k   = min(k, M)
    recentes = valores_F[max(0, k-m_k): k+1]
    return np.max(recentes, axis=0) if recentes else valores_F[-1]


# ==========================================================
#  Projeção na caixa
# =======================================================
def proj_caixa(x, bounds):
    lo = np.array([lo for lo, _ in bounds])
    up = np.array([up for _,  up in bounds])
    return np.clip(x, lo, up)

# ==========================================================
#  Execução do PGMMOP
# ==========================================================
def PGMMOP(x0, bounds, max_iter=50, M=10, delta=0.5, tol=1e-8):
          """
    Devolve:
      x*         – ponto final
      d_last     – direção da última iteração
      k          – nº de iterações executadas
      phi_last   – phi final
      F(x*)      – imagem final
      phi_hist – histórico de phi(d^k)
    """
    x       = x0.copy()
    f_hist  = []
    phi_hist  = []

    for k in range(max_iter):
        Fx = F(x); f_hist.append(Fx)

        d, phi = solve_epigraph(x, bounds)
        phi_hist.append(phi)

        if np.linalg.norm(d) <= tol:
            break

        A_k   = compute_A_k(f_hist, k, M)
        JFd   = grad_F(x) @ d                    # vetor 3
        t     = Armijo_tamanho_passo(x, d, F, JFd, A_k, delta)
        x     = proj_caixa(x + t*d, bounds)

    return x, d, k, phi, F(x), phi_hist

# ==========================================================
#  Loop multi-start
# ==========================================================
sol_dec, sol_obj = [], []
t_total = time.time()

print("\n===== RESULTADOS DO MULTI-START (Brown-Dennis) =====")

for run in range(num_starts):
    x0 = np.array([np.random.uniform(lo, up) for lo, up in bounds])
    x_opt, d_last, iters, φ_fin, F_opt, γ_hist = executa_PGMMOP(
        x0, bounds, max_iter=max_iter)

    sol_dec.append(x_opt)
    sol_obj.append(F_opt)
    print(f"Partida {run+1:2d}: iter={iters:2d}  φ={φ_fin:.2e}  F(x*)={F_opt}")

print(f"\nTempo total: {time.time() - t_total:.2f} s")

# ==========================================================
#  Amostragem adicional no espaço de decisão (para visualização)
# ============================================
x_ref   = np.mean(sol_dec, axis=0)
sigma   = np.array([(up - lo) * 0.15 for lo, up in bounds])
amostras= np.array([proj_caixa(x_ref + np.random.uniform(-sigma, sigma),
                               bounds)
                    for _ in range(300)])
obj_am  = np.array([F(s) for s in amostras])

# ==========================================================
#  Verificação de dominância
def domina(a, b):
    a, b = np.asarray(a), np.asarray(b)
    return np.all(a <= b) and np.any(a < b)

dom, nao_dom = [], []
for i, sol in enumerate(sol_obj):
    se_dom = any(domina(o, sol) for j, o in enumerate(sol_obj) if j != i)
    if not se_dom:
        se_dom = any(domina(p, sol) for p in obj_am)
    (dom if se_dom else nao_dom).append(sol)

# ==========================================================
#  Plot 3-D no espaço dos objetivos
# ==========================================================
fig = plt.figure(figsize=(9, 6))
ax  = fig.add_subplot(111, projection='3d')
ax.view_init(elev=22, azim=-105)

# Amostras geradas em azul
ax.scatter(obj_am[:,0], obj_am[:,1], obj_am[:,2],
           s=5, alpha=0.4, color="blue", label="Sampled points")

# Soluções dominadas em amarelo
for p in dom:
    ax.scatter(*p, s=40, color="yellow", edgecolor="black",
               label="Dominated"
               if "Dominated" not in ax.get_legend_handles_labels()[1] else "")

# Soluções não dominadas em vermelho
for p in nao_dom:
    ax.scatter(*p, s=40, color="red", edgecolor="black",
               label="Non-dominated"
               if "Non-dominated" not in ax.get_legend_handles_labels()[1] else "")

ax.set_xlabel("$f_1$")
ax.set_ylabel("$f_2$")
ax.set_zlabel("$f_3$")
ax.legend()
plt.tight_layout()
plt.show()
# Out:
# ===== RESULTADOS DO MULTI-START (Brown-Dennis) =====
# Partida  1: iter=49  φ=-3.02e-04  F(x*)=[0.03885524 0.42628289 2.01999935]
# Partida  2: iter=49  φ=-2.03e-03  F(x*)=[0.20852036 0.17681429 1.44829875]
# Partida  3: iter=49  φ=-2.39e-05  F(x*)=[1.00902948e+00 7.14133204e-04 7.42051678e-01]
# Partida  4: iter=49  φ=-1.56e-04  F(x*)=[0.01708688 2.15863677 8.44796042]
# Partida  5: iter=49  φ=-1.17e-06  F(x*)=[3.17443592e+00 1.49265268e-05 2.68385390e+00]
# Partida  6: iter=49  φ=-3.11e-05  F(x*)=[0.2388791  0.00089008 0.23461833]
# Partida  7: iter=49  φ=-4.74e-04  F(x*)=[0.04112931 0.56376026 2.598704  ]
# Partida  8: iter=49  φ=-1.64e-06  F(x*)=[0.29928461 0.05408635 0.00049852]
# Partida  9: iter=49  φ=-1.73e-04  F(x*)=[0.01742103 1.38540653 5.55745052]
# Partida 10: iter=49  φ=-4.23e-04  F(x*)=[0.04462112 0.45470426 2.17010274]
# Partida 11: iter=49  φ=-2.86e-04  F(x*)=[0.09694856 0.10010558 0.76360869]
# Partida 12: iter=49  φ=-4.37e-05  F(x*)=[0.01537248 1.98730782 7.70025093]
# Partida 13: iter=49  φ=-1.01e-05  F(x*)=[0.22994661 0.00476896 0.07937658]
# Partida 14: iter=49  φ=-7.68e-05  F(x*)=[1.69820421e+00 1.05832282e-03 1.56603771e+00]
# Partida 15: iter=49  φ=-3.05e-04  F(x*)=[0.05917117 0.24573212 1.34426175]
# Partida 16: iter=49  φ=-2.97e-05  F(x*)=[0.23826084 0.00085176 0.2328284 ]
# Partida 17: iter=49  φ=-9.51e-04  F(x*)=[0.06382658 0.59658081 2.87044491]
# Partida 18: iter=49  φ=-5.10e-06  F(x*)=[1.72147122e+00 6.70360754e-05 1.47137158e+00]
# Partida 19: iter=49  φ=-1.31e-05  F(x*)=[0.24461049 0.01359329 0.04073802]
# Partida 20: iter=49  φ=-3.75e-04  F(x*)=[0.05987142 0.27357251 1.46977513]
# Partida 21: iter=49  φ=-3.88e-04  F(x*)=[0.02834336 0.78504132 3.39371993]
# Partida 22: iter=49  φ=-3.56e-04  F(x*)=[0.02620417 0.80245173 3.4435849 ]
# Partida 23: iter=49  φ=-1.49e-03  F(x*)=[0.12156829 0.31399448 1.88255616]
# Partida 24: iter=49  φ=-1.05e-07  F(x*)=[0.07337112 0.09565083 0.68814159]
# Partida 25: iter=49  φ=-1.10e-05  F(x*)=[5.63935019e-01 1.68448842e-04 4.90924091e-01]
# Partida 26: iter=49  φ=-2.31e-04  F(x*)=[0.1055412  0.07360608 0.63889241]
# Partida 27: iter=49  φ=-7.26e-04  F(x*)=[0.19526574 0.04530317 0.62562045]
# Partida 28: iter=49  φ=-8.05e-05  F(x*)=[0.01591942 2.31993148 8.98140376]
# Partida 29: iter=49  φ=-1.77e-03  F(x*)=[0.23412538 0.11726411 1.16476017]
# Partida 30: iter=49  φ=-1.90e-04  F(x*)=[0.01766687 1.67649618 6.66323986]
# Partida 31: iter=49  φ=-3.57e-04  F(x*)=[1.80298127 0.34212678 0.0096575 ]
# Partida 32: iter=49  φ=-4.75e-04  F(x*)=[0.03030193 0.88523562 3.80773447]
# Partida 33: iter=49  φ=-1.18e-03  F(x*)=[0.07953771 0.52820627 2.66382568]
# Partida 34: iter=49  φ=-4.43e-04  F(x*)=[0.04874435 0.41655041 2.03276405]
# Partida 35: iter=49  φ=-4.05e-04  F(x*)=[0.02634174 0.90925006 3.86586042]
# Partida 36: iter=49  φ=-3.65e-04  F(x*)=[0.08539333 0.14880078 0.97989117]
# Partida 37: iter=49  φ=-2.95e-05  F(x*)=[0.18849371 0.0017632  0.20764086]
# Partida 38: iter=49  φ=-1.08e-05  F(x*)=[0.19563651 0.00056668 0.18342114]
# Partida 39: iter=49  φ=-1.02e-06  F(x*)=[1.55943850e+00 3.45528021e-01 1.95927891e-05]
# Partida 40: iter=49  φ=-4.72e-06  F(x*)=[1.55809181e+00 1.19535980e-04 1.24870427e+00]
# Partida 41: iter=49  φ=-6.47e-05  F(x*)=[0.27453189 0.00159193 0.28874568]
# Partida 42: iter=49  φ=-1.90e-05  F(x*)=[1.75215384e+00 2.44716751e-05 1.47556864e+00]
# Partida 43: iter=49  φ=-2.62e-04  F(x*)=[0.01890454 1.41755808 5.72595281]
# Partida 44: iter=49  φ=-1.48e-04  F(x*)=[0.0169497  2.38032199 9.27044526]
# Partida 45: iter=49  φ=-1.28e-05  F(x*)=[0.19549382 0.00066672 0.1866399 ]
# Partida 46: iter=49  φ=-1.95e-04  F(x*)=[0.01778897 1.39830647 5.61870114]
# Partida 47: iter=49  φ=-8.05e-04  F(x*)=[0.09637596 0.22774726 1.3904327 ]
# Partida 48: iter=49  φ=-3.66e-04  F(x*)=[0.07790575 0.17604969 1.08899393]
# Partida 49: iter=49  φ=-4.80e-06  F(x*)=[0.288547   0.04573663 0.00248426]
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# Partida 50: iter=49  φ=-3.88e-06  F(x*)=[2.11999523e-01 1.43679312e-04 1.78819902e-01]
#
# Tempo total: 18.24 s
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern

# %%
# ==========================================================
#  Multi-start – Exemplo do trabalho (convexo)
# ==========================================================
import time  # Importa o módulo para medição de tempo
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize
import pygmo as pg  # Certifique-se de instalar o PyGMO (pip install pygmo)
from matplotlib.patches import Polygon

# ——————————————————————————————
# 1) Use MathText sem LaTeX externo, mas com Computer Modern
plt.rcParams['text.usetex']        = False
plt.rcParams['font.family']        = 'serif'
plt.rcParams['font.serif']         = ['Computer Modern']
plt.rcParams['mathtext.fontset']   = 'cm'
# ——————————————————————————————
#=================================================================
# FUNÇÃO: PROBLEMA 4 NO TRABALHO
#================================================================
def proj_hyperplane(x, w, cte):
    """
    Projeta o ponto x no hiperplano definido por <w,x> = cte.
    """
    w_dot_x = np.dot(w, x)
    w_dot_w = np.dot(w, w)
    return x + (cte - w_dot_x) / w_dot_w * w

def proj_halfspace(x, idx, cte=0):
    """
    Projeta o ponto x no semiespaço definido por x[idx] >= cte.
    """
    if x[idx] < cte:
        x_new = x.copy()
        x_new[idx] = cte
        return x_new
    else:
        return x

def dykstra(z, maxcycles=500):
    """
    Projeta z (em R^4) sobre a interseção dos conjuntos:
    Hiperplano 1: 2x1 + x2 - x3 = 3
  Hiperplano 2: x1 + x2 + x4 = 6
    Semiespaços: x1 >= 0, x2 >= 0, x3 >= 0, x4 >= 0
    """
    x = z.copy()
    # Inicializa os vetores de correção para cada restrição
    d1 = np.zeros(4)  # para hiperplano 1
    d2 = np.zeros(4)  # para hiperplano 2
    d3 = np.zeros(4)  # para x1 >= 0
    d4 = np.zeros(4)  # para x2 >= 0
    d5 = np.zeros(4)  # para x3 >= 0
    d6 = np.zeros(4)  # para x4 >= 0
    errors = []

    for k in range(maxcycles):
        err = 0

        # Projeção no Hiperplano 1: 2x1 + x2 - x3 = 3
        temp = x.copy()
        x = proj_hyperplane(x - d1, np.array([2, 1, -1, 0]), 3)
        d1 = x - (temp - d1)
        err += np.linalg.norm(x - temp)**2

        # Projeção no Hiperplano 2: x1 + x2 + x4 = 6
        temp = x.copy()
        x = proj_hyperplane(x - d2, np.array([1, 1, 0, 1]), 6)
        d2 = x - (temp - d2)
        err += np.linalg.norm(x - temp)**2

        # Projeção no Semiespaço: x1 >= 0 (índice 0)
        temp = x.copy()
        x = proj_halfspace(x - d3, 0, 0)
        d3 = x - (temp - d3)
        err += np.linalg.norm(x - temp)**2

        # Projeção no Semiespaço: x2 >= 0 (índice 1)
        temp = x.copy()
        x = proj_halfspace(x - d4, 1, 0)
        d4 = x - (temp - d4)
        err += np.linalg.norm(x - temp)**2

        # Projeção no Semiespaço: x3 >= 0 (índice 2)
        temp = x.copy()
        x = proj_halfspace(x - d5, 2, 0)
        d5 = x - (temp - d5)
        err += np.linalg.norm(x - temp)**2

        # Projeção no Semiespaço: x4 >= 0 (índice 3)
        temp = x.copy()
        x = proj_halfspace(x - d6, 3, 0)
        d6 = x - (temp - d6)
        err += np.linalg.norm(x - temp)**2

        errors.append(np.sqrt(err))
        if np.sqrt(err) < 1e-12:
            break
    return x, errors

def proj(z):
    """
    Função wrapper para projeção via Dykstra.
    """
    x, _ = dykstra(z)
    return x

#===========================================
# FUNÇÃO OBJETIVO E SEUS GRADIENTES
#=========================================
def F(x):
    """
    Função objetivo F: R^4 -> R^2
      f1(x)= x1 - x2
      f2(x)= 2x1 + x2
    Obs.: x é um vetor de dimensão 4.
    """
    f1 = x[0] - x[1]
    f2 = 2 * x[0] + x[1]
    return [f1, f2]

def funcaogradF(x):
    """
    Gradiente da função objetivo F.
      grad f1, grad f2
    """
    grad_f1 = np.array([1, -1, 0, 0])
    grad_f2 = np.array([2,  1, 0, 0])
    return grad_f1, grad_f2

#============================================
# Busca de dreção por SLSQP
#=========================================================

def buscadirecao(x, tol_eps=1e-10):
    """
    Resolve o sub-problema epígrafe via SLSQP e devolve (d*, phi).
    """
    G   = np.array(funcaogradF(x))
    dt0 = np.concatenate([np.zeros_like(x), [0.0]])

    # fun-objetivo
    obj      = lambda dt: dt[-1] + 0.5*np.dot(dt[:-1], dt[:-1])
    obj_grad = lambda dt: np.concatenate([dt[:-1], [1.0]])

    # restrição de t
    cons = [{'type': 'ineq',
             'fun' : lambda dt, i=i: dt[-1] - np.dot(G[i], dt[:-1])}
            for i in range(2)]

    # hiperplanos
    cons += [
        {'type': 'eq',
         'fun' : lambda dt: np.dot([2,1,-1,0], x+dt[:-1]) - 3},
        {'type': 'eq',
         'fun' : lambda dt: np.dot([1,1,0,1], x+dt[:-1]) - 6},
    ]
    # semiespaços xj>= 0
    for j in range(4):
        cons.append({'type': 'ineq',
                     'fun': lambda dt, j=j: (x+dt[:-1])[j]})

    res = minimize(obj, dt0, jac=obj_grad,
                   constraints=cons, method='SLSQP',
                   options={'ftol': tol_eps, 'maxiter': 500, 'disp': False})

    d_opt = res.x[:-1]
    phi   = obj(res.x)
    return d_opt, phi




def Armijo_tamanho_passo(z, d, F, J, A_k, delta):
    """
    Seleciona tamanho de passo t através do critério de Armijo não-monótono do tipo máximo..
    Parâmetros:
    z : Ponto atual (x,y)
    d : Direção de busca obtida pelo SLSQP
    F : Função objetivo.
    J : Avaliação do gradiente em z na direção d
    A_k : Par (A₁, A₂) acumulado nas últimas iterações.
    delta : Parâmetro usado apenas em Armijo.

    Retorna: O maior tamanho de passo t=1/2^j (j = 0, 1, ...,19) que satisfaz a cond. de Armijo
        F(z + td) ≤ A_k + δ t J;
        retorna 1.0 se nenhum j satisfizer.
    """
    for j in range(30):
        t_val = 1/(2**j)
        z_next = z + t_val*d
        F_next = np.array(F(z_next))
        rhs = np.array(A_k) + delta*t_val*J
        if np.all(F_next <= rhs):
            return t_val
    return 1


def compute_A_k(f_values, k, M=10):
    """
    Calcula o valor de A_k para Armijo não-monótono.

    Parâmetros usados:
    f_values : Histórico de valores de F(z) (cada um sendo um vetor de dimensão 2).
    k : índice da iteração atual.
    M : Número máximo de iterações consideradas em A_k (M=10).

    Retorna:
    A_k : Par (A₁, A₂), onde cada componente é o máximo de F_j nas últimas min(k, M) iterações.
    """
    m_k = min(k, M)
    recentes = f_values[max(0, k-m_k) : k+1] #Seleciona o conjunto de valores F(z^j) desde j = k–m_k até j = k
    if not recentes:  # Caso k=0 e f_values tem só um elemento
        return f_values[-1]
    A1 = max(f[0] for f in recentes)
    A2 = max(f[1] for f in recentes)
    return (A1, A2)

def jacobian_F(x):
    """
    Calcula a Jacobiana de F usando os gradientes.
    """
    grad_f1, grad_f2 = funcaogradF(x)
    return np.array([grad_f1, grad_f2])

#=========================================================
# ALGORITMO DE OTIMIZAÇÃO COM MULTI-START
#========================================================
def PGMMOP(x0, max_iter=50, M=10, delta=0.5, tol=1e-8):
    """
      Devolve:
        x*          ponto final
        d_last      direção da última iteração
        k           nº de iterações executadas
        phi_last    phi final
        F(x*)       imagem final
        phi_hist   histórico de phi(d^k)
      """
    x = x0.copy()
    f_history  = []
    phi_history  = []

    for k in range(max_iter):
        Fx = F(x);               f_history.append(Fx)

        d, phi_val = buscadirecao(x) #busca a direção por SLSQP
        phi_history.append(phi_val) # Guarda valores de phi na lista


        if np.linalg.norm(d) <= tol: #critério de parada
            break

        A_k = compute_A_k(f_history, k, M)   # Armijo não-monótono
        J         = jacobian_F(x)          # 2x4
        JF_d = J @ d                  # vetor 2
        t         = Armijo_tamanho_passo(x, d, F, JF_d, A_k, delta)
        x = proj(x + t*d)                  # usa a projeção de Dykstra

    return x, d, k, phi_val, F(x),phi_hist

# Número de pontos de início no multi‑start (pode ser modificado)
n_starts = 50
solucoes = []         # Armazena os pontos ótimos x*
imagens_sol = []   # Armazena as imagens F(x*) correspondentes

# Gerar pontos iniciais aleatórios em R^4 e projeção para a região viável
np.random.seed(0)
initial_points = []
for i in range(n_starts):
    x_rand = np.random.uniform(-6,5, 4)#2 a 7
    x0_proj = proj(x_rand)
    initial_points.append(x0_proj)

print("===== Resultados Multi-Start =====")
start_time = time.perf_counter()  # Inicia a medição do tempo

for i, x0 in enumerate(initial_points):
    x_opt, subproblem_vec, iters, final_phi, Fx = PGMMOP(x0)
    solucoes.append(x_opt)
    imagens_sol.append(Fx)
    print(f"\n--- Início {i+1} ---")
    print("Ponto inicial (após projeção):", x0)
    print("Ponto ótimo x*:", x_opt)
    print("Vetor do subproblema final:", subproblem_vec)
    print("Número de iterações:", iters)
    print("Valor final de phi:", final_phi)
    print("Imagem da solução ótima F(x*):", Fx)

end_time = time.perf_counter()  # Finaliza a medição do tempo
print(f"\nTempo de execução do multi‑start: {end_time - start_time:.4f} segundos")

#==================================
# GERAÇÃO DO ESPAÇO DOS OBJETIVOS
#==================================
# Gerar pontos que satisfaçam:
#   x1 >= 0, x2 >= 0,
#   x4 = 6 - x1 - x2 >= 0   (implica x1+x2 <= 6)
#   x3 = 2*x1 + x2 - 3 >= 0  (implica 2*x1+x2 >= 3)
num_points = 4000000
obj_samples = []
for _ in range(num_points):
    x1 = np.random.uniform(0, 6)      # x1 em [0,6]
    x2 = np.random.uniform(0, 6 - x1)   # para garantir x1+x2 <= 6
    x4 = 6 - x1 - x2
    x3 = 2*x1 + x2 - 3
    if x4 >= 0 and x3 >= 0:
        obj_samples.append([x1, x2, x3, x4])
obj_samples = np.array(obj_samples)
objective_values = np.array([F(x) for x in obj_samples])
f1_values = objective_values[:, 0]
f2_values = objective_values[:, 1]

#======================================
# VERIFICAÇÃO DE DOMINÂNCIA ENTRE OS PONTOS ÓTIMOS
#======================================
def domina(sol1, sol2):
    """
    Retorna True se sol1 domina sol2, ou seja, se sol1 é
    menor ou igual a sol2 em todas as componentes e estritamente
    menor em pelo menos uma.
    """
    sol1 = np.array(sol1)
    sol2 = np.array(sol2)
    return np.all(sol1 <= sol2) and np.any(sol1 < sol2)

# ===== PASSO 1 =====
# Verifica dominância entre as imagens dos pontos ótimos obtidos pelo multi‑start.
print("\n===== Verificação de Dominância ENTRE os Pontos Ótimos (Passo 1) =====")
nao_dominadas_otimas = []     # imagens que sobrevivem à Etapa 1
dominadas_otimas     = []     # imagens dominadas por outra ótima

for i, sol in enumerate(solution_images):
    dominado = False
    for j, outra_sol in enumerate(solution_images):
        if i != j and domina(outra_sol, sol):
            dominado = True
            break
    if dominado:
        dominadas_otimas.append(sol)
        print(f"Solução {i+1} com imagem F(x*) = {sol} é DOMINADA entre os pontos ótimos.")
    else:
        nao_dominadas_otimas.append(sol)
        print(f"Solução {i+1} com imagem F(x*) = {sol} NÃO é dominada entre os pontos ótimos.")

# ===== PASSO 2 =====
# Para cada ponto que não foi dominado no Passo 1, verifica-se se ele é dominado por algum ponto do espaço dos objetivos.
print("\n===== Verificação de Dominância DAS SOLUÇÕES NÃO DOMINADAS (Passo 2) em relação ao Espaço dos Objetivos =====")
nao_dominadas_finais = []      # permaneceram não-dominadas
dominadas_pelo_espaco = []     # dominadas por algum ponto gerado
for sol in nao_dominadas_otimas:
    dominada = any(domina(pt, sol) for pt in objective_values)
    if dominada:
        dominadas_pelo_espaco.append(sol)
        print(f"Solução F(x*) = {sol} foi DOMINADA pelo espaço de amostras.")
    else:
        nao_dominadas_finais.append(sol)
        print(f"Solução F(x*) = {sol} NÃO foi dominada pelo espaço de amostras.")


# Vai unificar as soluções dominadas (seja por outros ótimos ou pelo espaço dos objetivos)
dominadas_finais = dominadas_otimas + dominadas_pelo_espaco

#===================================================================
# PLOT DO ESPAÇO DOS OBJETIVOS COM A CLASSIFICAÇÃO DOS PONTOS ÓTIMOS
#===================================================================
plt.figure(figsize=(8,6))
# Pontos gerados para o espaço dos objetivos (azul)
plt.scatter(f1_values, f2_values, alpha=0.5, s=10, marker='o', color="blue", label="Espaço dos Objetivos")

# Espaço amostrado (azul)
plt.scatter(f1_values, f2_values, s=10, alpha=0.5, color="blue",
            label="Espaço dos Objetivos")

# Soluções dominadas (amarelo)
for sol in dominadas_finais:
    plt.scatter(sol[0], sol[1], s=30, color="yellow", edgecolor="black",
                label="Solução Dominada"
                if "Solução Dominada" not in plt.gca().get_legend_handles_labels()[1] else "")

# Soluções não-dominadas (vermelho)
for sol in nao_dominadas_finais:
    plt.scatter(sol[0], sol[1], s=30, color="red", edgecolor="black",
                label="Solução Não Dominada"
                if "Solução Não Dominada" not in plt.gca().get_legend_handles_labels()[1] else "")

plt.title("Espaço dos Objetivos", fontsize=12)
plt.xlabel(r"$f_1(x)$", fontsize=12)
plt.ylabel(r"$f_2(x)$", fontsize=12)
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ===== Resultados Multi-Start =====
#
# --- Início 1 ---
# Ponto inicial (após projeção): [0.60008755 3.23450083 1.43467593 2.16541162]
# Ponto ótimo x*: [0.         3.53454461 0.53454461 2.46545539]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 2
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-3.5345446096577278), np.float64(3.5345446096577278)]
#
# --- Início 2 ---
# Ponto inicial (após projeção): [0.54333922 1.91332156 0.         3.54333922]
# Ponto ótimo x*: [0.54333922 1.91332156 0.         3.54333922]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 0
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-1.3699823430683438), np.float64(2.9999999999989173)]
#
# --- Início 3 ---
# Ponto inicial (após projeção): [3.70006618 0.         4.40013236 2.29993382]
# Ponto ótimo x*: [7.66644606e-01 1.46671079e+00 2.22044605e-16 3.76664461e+00]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 8
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-0.7000661808679263), np.float64(3.0)]
#
# --- Início 4 ---
# Ponto inicial (após projeção): [0.         4.33484579 1.33484579 1.66515421]
# Ponto ótimo x*: [0.         4.33484579 1.33484579 1.66515421]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 0
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-4.334845788226803), np.float64(4.334845788226803)]
#
# --- Início 5 ---
# Ponto inicial (após projeção): [0.         3.71613631 0.71613631 2.28386369]
# Ponto ótimo x*: [0.         3.71613631 0.71613631 2.28386369]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 0
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-3.7161363102529785), np.float64(3.7161363102529785)]
#
# --- Início 6 ---
# Ponto inicial (após projeção): [1.35011018 1.41028857 1.11050893 3.23960125]
# Ponto ótimo x*: [0.60977089 1.78045821 0.         3.60977089]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 2
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-1.1706873203370467), np.float64(2.9999999999989058)]
#
# --- Início 7 ---
# Ponto inicial (após projeção): [0.10235238 2.79529523 0.         3.10235238]
# Ponto ótimo x*: [0.10235238 2.79529523 0.         3.10235238]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 0
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-2.6929428485515468), np.float64(2.9999999999987477)]
#
# --- Início 8 ---
# Ponto inicial (após projeção): [1.35572324 0.28855352 0.         4.35572324]
# Ponto ótimo x*: [1.35572324 0.28855352 0.         4.35572324]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 0
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(1.067169721618276), np.float64(3.0000000000008984)]
#
# --- Início 9 ---
# Ponto inicial (após projeção): [0.38434954 2.23130092 0.         3.38434954]
# Ponto ótimo x*: [0.38434954 2.23130092 0.         3.38434954]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 0
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-1.8469513764463352), np.float64(3.000000000000916)]
#
# --- Início 10 ---
# Ponto inicial (após projeção): [2.44266928 1.7798239  3.66516246 1.77750682]
# Ponto ótimo x*: [3.46944695e-17 3.00115854e+00 1.15853834e-03 2.99884146e+00]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 7
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-3.001158538337474), np.float64(3.001158538337474)]
#
# --- Início 11 ---
# Ponto inicial (após projeção): [1.27372619 3.66587863 3.21333101 1.06039518]
# Ponto ótimo x*: [7.40148683e-17 4.30274172e+00 1.30274172e+00 1.69725828e+00]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 4
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-4.302741724713836), np.float64(4.302741724713836)]
#
# --- Início 12 ---
# Ponto inicial (após projeção): [0.         3.75767849 0.75767849 2.24232151]
# Ponto ótimo x*: [0.         3.75767849 0.75767849 2.24232151]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 0
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-3.7576784878034575), np.float64(3.7576784878034575)]
#
# --- Início 13 ---
# Ponto inicial (após projeção): [0.91368595 1.90243615 0.72980805 3.1838779 ]
# Ponto ótimo x*: [4.27147249e-01 2.14570550e+00 2.12792746e-16 3.42714725e+00]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 2
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-1.7185582531222265), np.float64(3.0)]
#
# --- Início 14 ---
# Ponto inicial (após projeção): [2.28216603 0.         1.56433205 3.71783397]
# Ponto ótimo x*: [1.23927799e+00 5.21444017e-01 3.33066907e-16 4.23927799e+00]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 3
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.7178339740460183), np.float64(3.0000000000000004)]
#
# --- Início 15 ---
# Ponto inicial (após projeção): [2.17580082 0.56651405 1.91811569 3.25768513]
# Ponto ótimo x*: [8.97057024e-01 1.20588595e+00 1.66533454e-16 3.89705702e+00]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 4
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-0.30882892702605813), np.float64(3.0)]
#
# --- Início 16 ---
# Ponto inicial (após projeção): [1.58472145 1.71985841 1.88930131 2.69542014]
# Ponto ótimo x*: [3.25187245e-01 2.34962551e+00 3.00685403e-16 3.32518725e+00]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 4
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-2.0244382643036465), np.float64(3.0000000000000004)]
#
# --- Início 17 ---
# Ponto inicial (após projeção): [1.37911821 3.62714458 3.385381   0.99373721]
# Ponto ótimo x*: [1.75785312e-16 4.31670369e+00 1.31670369e+00 1.68329631e+00]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 4
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-4.316703685701959), np.float64(4.316703685701959)]
#
# --- Início 18 ---
# Ponto inicial (após projeção): [4.25738983 0.         5.51477966 1.74261017]
# Ponto ótimo x*: [5.80870056e-01 1.83825989e+00 2.17418676e-16 3.58087006e+00]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 10
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-1.2573898322088177), np.float64(3.0000000000000004)]
#
# --- Início 19 ---
# Ponto inicial (após projeção): [3.07432354 2.71038792 5.859035   0.21528854]
# Ponto ótimo x*: [2.36218452e-13 4.24754969e+00 1.24754969e+00 1.75245031e+00]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 8
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-4.247549687503401), np.float64(4.24754968750411)]
#
# --- Início 20 ---
# Ponto inicial (após projeção): [0.79542619 1.40914762 0.         3.79542619]
# Ponto ótimo x*: [0.79542619 1.40914762 0.         3.79542619]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 0
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-0.6137214249256582), np.float64(3.000000000001208)]
#
# --- Início 21 ---
# Ponto inicial (após projeção): [0.83353707 1.33292586 0.         3.83353707]
# Ponto ótimo x*: [0.83353707 1.33292586 0.         3.83353707]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 0
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-0.49938879645891765), np.float64(3.0000000000009486)]
#
# --- Início 22 ---
# Ponto inicial (após projeção): [2.02302006 1.5242024  2.57024252 2.45277754]
# Ponto ótimo x*: [3.09525049e-01 2.38094990e+00 1.38777878e-16 3.30952505e+00]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 5
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-2.071424852059404), np.float64(3.0)]
#
# --- Início 23 ---
# Ponto inicial (após projeção): [0.         3.12833416 0.12833416 2.87166584]
# Ponto ótimo x*: [0.         3.12833416 0.12833416 2.87166584]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 0
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-3.1283341569013263), np.float64(3.1283341569013263)]
#
# --- Início 24 ---
# Ponto inicial (após projeção): [0.        4.0159871 1.0159871 1.9840129]
# Ponto ótimo x*: [0.        4.0159871 1.0159871 1.9840129]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 0
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-4.015987095215569), np.float64(4.015987095215569)]
#
# --- Início 25 ---
# Ponto inicial (após projeção): [4.10611211 0.         5.21222423 1.89388789]
# Ponto ótimo x*: [0.63129596 1.73740808 0.         3.63129596]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 9
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-1.1061121144972923), np.float64(2.999999999998985)]
#
# --- Início 26 ---
# Ponto inicial (após projeção): [2.17436273 0.         1.34872547 3.82563727]
# Ponto ótimo x*: [1.27521242e+00 4.49575155e-01 4.44089210e-16 4.27521242e+00]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 3
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.8256372675196636), np.float64(3.0000000000000004)]
#
# --- Início 27 ---
# Ponto inicial (após projeção): [0.         3.18514032 0.18514032 2.81485968]
# Ponto ótimo x*: [0.         3.18514032 0.18514032 2.81485968]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 0
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-3.1851403196293666), np.float64(3.1851403196293666)]
#
# --- Início 28 ---
# Ponto inicial (após projeção): [0.        3.0293743 0.0293743 2.9706257]
# Ponto ótimo x*: [0.        3.0293743 0.0293743 2.9706257]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 0
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-3.0293742980999223), np.float64(3.0293742980999223)]
#
# --- Início 29 ---
# Ponto inicial (após projeção): [3.45808053 0.16259258 4.07875364 2.37932689]
# Ponto ótimo x*: [0.73891144 1.52217713 0.         3.73891144]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 7
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-0.7832656892114912), np.float64(2.9999999999987423)]
#
# --- Início 30 ---
# Ponto inicial (após projeção): [3.33240752 0.49267351 4.15748855 2.17491897]
# Ponto ótimo x*: [5.60748486e-01 1.87850303e+00 1.85890562e-11 3.56074849e+00]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 7
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-1.3177545423629629), np.float64(3.0000000000194746)]
#
# --- Início 31 ---
# Ponto inicial (após projeção): [3.32671629 0.65581571 4.30924828 2.017468  ]
# Ponto ótimo x*: [4.53884097e-01 2.09223181e+00 2.08166817e-16 3.45388410e+00]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 8
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-1.6383477082498974), np.float64(3.0)]
#
# --- Início 32 ---
# Ponto inicial (após projeção): [0. 3. 0. 3.]
# Ponto ótimo x*: [0. 3. 0. 3.]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 0
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-3.0000000000015903), np.float64(3.0000000000015903)]
#
# --- Início 33 ---
# Ponto inicial (após projeção): [2.62307498 0.13444758 2.38059755 3.24247744]
# Ponto ótimo x*: [1.03600995 0.92798009 0.         4.03600995]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 4
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.10802985884267846), np.float64(2.999999999998893)]
#
# --- Início 34 ---
# Ponto inicial (após projeção): [0.73793398 1.52413203 0.         3.73793398]
# Ponto ótimo x*: [0.73793398 1.52413203 0.         3.73793398]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 0
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-0.7861980454274391), np.float64(3.0000000000009424)]
#
# --- Início 35 ---
# Ponto inicial (após projeção): [1.1018349 3.1024125 2.3060823 1.7957526]
# Ponto ótimo x*: [0.         3.65332995 0.65332995 2.34667005]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 3
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-3.6533299513933413), np.float64(3.6533299513933413)]
#
# --- Início 36 ---
# Ponto inicial (após projeção): [1.60664733 0.         0.21329467 4.39335267]
# Ponto ótimo x*: [1.46445089 0.07109822 0.         4.46445089]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 1
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(1.3933526658280284), np.float64(3.0)]
#
# --- Início 37 ---
# Ponto inicial (após projeção): [1.08281563 0.83436874 0.         4.08281563]
# Ponto ótimo x*: [1.08281563 0.83436874 0.         4.08281563]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 0
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.24844689640466167), np.float64(2.999999999999029)]
#
# --- Início 38 ---
# Ponto inicial (após projeção): [0. 3. 0. 3.]
# Ponto ótimo x*: [0. 3. 0. 3.]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 0
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-2.99999999999842), np.float64(2.99999999999842)]
#
# --- Início 39 ---
# Ponto inicial (após projeção): [0.09553373 2.80893254 0.         3.09553373]
# Ponto ótimo x*: [0.09553373 2.80893254 0.         3.09553373]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 0
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-2.7133988051303595), np.float64(2.999999999999152)]
#
# --- Início 40 ---
# Ponto inicial (após projeção): [1.36647223 2.95962358 2.69256804 1.67390419]
# Ponto ótimo x*: [1.85037171e-17 3.64285970e+00 6.42859700e-01 2.35714030e+00]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 4
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-3.642859699653362), np.float64(3.642859699653362)]
#
# --- Início 41 ---
# Ponto inicial (após projeção): [2.33778902 0.         1.67557804 3.66221098]
# Ponto ótimo x*: [1.22073699 0.55852601 0.         4.22073699]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 3
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.6622109820613985), np.float64(2.999999999998782)]
#
# --- Início 42 ---
# Ponto inicial (após projeção): [0. 3. 0. 3.]
# Ponto ótimo x*: [0. 3. 0. 3.]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 0
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-3.00000000000158), np.float64(3.00000000000158)]
#
# --- Início 43 ---
# Ponto inicial (após projeção): [2.9577908  0.38274628 3.29832788 2.65946292]
# Ponto ótimo x*: [7.58905546e-01 1.48218891e+00 1.11022302e-16 3.75890555e+00]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 6
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-0.723283362675377), np.float64(3.0)]
#
# --- Início 44 ---
# Ponto inicial (após projeção): [2.57563226 0.58144871 2.73271323 2.84291903]
# Ponto ótimo x*: [7.53823440e-01 1.49235312e+00 1.11022302e-16 3.75382344e+00]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 5
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-0.7385296808877485), np.float64(3.0)]
#
# --- Início 45 ---
# Ponto inicial (após projeção): [0. 6. 3. 0.]
# Ponto ótimo x*: [0. 6. 3. 0.]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 0
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-6.0), np.float64(6.0)]
#
# --- Início 46 ---
# Ponto inicial (após projeção): [0.         4.52298529 1.52298529 1.47701471]
# Ponto ótimo x*: [0.         4.52298529 1.52298529 1.47701471]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 0
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-4.522985285341728), np.float64(4.522985285341728)]
#
# --- Início 47 ---
# Ponto inicial (após projeção): [2.13822976 0.91396244 2.19042197 2.9478078 ]
# Ponto ótimo x*: [0.67794845 1.64410309 0.         3.67794845]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 4
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-0.9661546410102181), np.float64(2.9999999999990545)]
#
# --- Início 48 ---
# Ponto inicial (após projeção): [1.99345969 0.84105545 1.82797482 3.16548487]
# Ponto ótimo x*: [0.77480981 1.45038039 0.         3.77480981]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 4
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-0.6755705776423996), np.float64(3.0)]
#
# --- Início 49 ---
# Ponto inicial (após projeção): [0.         5.37603605 2.37603605 0.62396395]
# Ponto ótimo x*: [0.         5.37603605 2.37603605 0.62396395]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 0
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-5.37603604685788), np.float64(5.37603604685788)]
#
# --- Início 50 ---
# Ponto inicial (após projeção): [0.78071686 1.43856627 0.         3.78071686]
# Ponto ótimo x*: [0.78071686 1.43856627 0.         3.78071686]
# Vetor do subproblema final: [0. 0. 0. 0.]
# Número de iterações: 0
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(-0.6578494050508557), np.float64(3.000000000001049)]
#
# Tempo de execução do multi‑start: 2.7316 segundos
#
# ===== Verificação de Dominância ENTRE os Pontos Ótimos (Passo 1) =====
# Solução 1 com imagem F(x*) = [np.float64(-3.5345446096577278), np.float64(3.5345446096577278)] NÃO é dominada entre os pontos ótimos.
# Solução 2 com imagem F(x*) = [np.float64(-1.3699823430683438), np.float64(2.9999999999989173)] é DOMINADA entre os pontos ótimos.
# Solução 3 com imagem F(x*) = [np.float64(-0.7000661808679263), np.float64(3.0)] é DOMINADA entre os pontos ótimos.
# Solução 4 com imagem F(x*) = [np.float64(-4.334845788226803), np.float64(4.334845788226803)] NÃO é dominada entre os pontos ótimos.
# Solução 5 com imagem F(x*) = [np.float64(-3.7161363102529785), np.float64(3.7161363102529785)] NÃO é dominada entre os pontos ótimos.
# Solução 6 com imagem F(x*) = [np.float64(-1.1706873203370467), np.float64(2.9999999999989058)] é DOMINADA entre os pontos ótimos.
# Solução 7 com imagem F(x*) = [np.float64(-2.6929428485515468), np.float64(2.9999999999987477)] é DOMINADA entre os pontos ótimos.
# Solução 8 com imagem F(x*) = [np.float64(1.067169721618276), np.float64(3.0000000000008984)] é DOMINADA entre os pontos ótimos.
# Solução 9 com imagem F(x*) = [np.float64(-1.8469513764463352), np.float64(3.000000000000916)] é DOMINADA entre os pontos ótimos.
# Solução 10 com imagem F(x*) = [np.float64(-3.001158538337474), np.float64(3.001158538337474)] NÃO é dominada entre os pontos ótimos.
# Solução 11 com imagem F(x*) = [np.float64(-4.302741724713836), np.float64(4.302741724713836)] NÃO é dominada entre os pontos ótimos.
# Solução 12 com imagem F(x*) = [np.float64(-3.7576784878034575), np.float64(3.7576784878034575)] NÃO é dominada entre os pontos ótimos.
# Solução 13 com imagem F(x*) = [np.float64(-1.7185582531222265), np.float64(3.0)] é DOMINADA entre os pontos ótimos.
# Solução 14 com imagem F(x*) = [np.float64(0.7178339740460183), np.float64(3.0000000000000004)] é DOMINADA entre os pontos ótimos.
# Solução 15 com imagem F(x*) = [np.float64(-0.30882892702605813), np.float64(3.0)] é DOMINADA entre os pontos ótimos.
# Solução 16 com imagem F(x*) = [np.float64(-2.0244382643036465), np.float64(3.0000000000000004)] é DOMINADA entre os pontos ótimos.
# Solução 17 com imagem F(x*) = [np.float64(-4.316703685701959), np.float64(4.316703685701959)] NÃO é dominada entre os pontos ótimos.
# Solução 18 com imagem F(x*) = [np.float64(-1.2573898322088177), np.float64(3.0000000000000004)] é DOMINADA entre os pontos ótimos.
# Solução 19 com imagem F(x*) = [np.float64(-4.247549687503401), np.float64(4.24754968750411)] NÃO é dominada entre os pontos ótimos.
# Solução 20 com imagem F(x*) = [np.float64(-0.6137214249256582), np.float64(3.000000000001208)] é DOMINADA entre os pontos ótimos.
# Solução 21 com imagem F(x*) = [np.float64(-0.49938879645891765), np.float64(3.0000000000009486)] é DOMINADA entre os pontos ótimos.
# Solução 22 com imagem F(x*) = [np.float64(-2.071424852059404), np.float64(3.0)] é DOMINADA entre os pontos ótimos.
# Solução 23 com imagem F(x*) = [np.float64(-3.1283341569013263), np.float64(3.1283341569013263)] NÃO é dominada entre os pontos ótimos.
# Solução 24 com imagem F(x*) = [np.float64(-4.015987095215569), np.float64(4.015987095215569)] NÃO é dominada entre os pontos ótimos.
# Solução 25 com imagem F(x*) = [np.float64(-1.1061121144972923), np.float64(2.999999999998985)] é DOMINADA entre os pontos ótimos.
# Solução 26 com imagem F(x*) = [np.float64(0.8256372675196636), np.float64(3.0000000000000004)] é DOMINADA entre os pontos ótimos.
# Solução 27 com imagem F(x*) = [np.float64(-3.1851403196293666), np.float64(3.1851403196293666)] NÃO é dominada entre os pontos ótimos.
# Solução 28 com imagem F(x*) = [np.float64(-3.0293742980999223), np.float64(3.0293742980999223)] NÃO é dominada entre os pontos ótimos.
# Solução 29 com imagem F(x*) = [np.float64(-0.7832656892114912), np.float64(2.9999999999987423)] é DOMINADA entre os pontos ótimos.
# Solução 30 com imagem F(x*) = [np.float64(-1.3177545423629629), np.float64(3.0000000000194746)] é DOMINADA entre os pontos ótimos.
# Solução 31 com imagem F(x*) = [np.float64(-1.6383477082498974), np.float64(3.0)] é DOMINADA entre os pontos ótimos.
# Solução 32 com imagem F(x*) = [np.float64(-3.0000000000015903), np.float64(3.0000000000015903)] NÃO é dominada entre os pontos ótimos.
# Solução 33 com imagem F(x*) = [np.float64(0.10802985884267846), np.float64(2.999999999998893)] é DOMINADA entre os pontos ótimos.
# Solução 34 com imagem F(x*) = [np.float64(-0.7861980454274391), np.float64(3.0000000000009424)] é DOMINADA entre os pontos ótimos.
# Solução 35 com imagem F(x*) = [np.float64(-3.6533299513933413), np.float64(3.6533299513933413)] NÃO é dominada entre os pontos ótimos.
# Solução 36 com imagem F(x*) = [np.float64(1.3933526658280284), np.float64(3.0)] é DOMINADA entre os pontos ótimos.
# Solução 37 com imagem F(x*) = [np.float64(0.24844689640466167), np.float64(2.999999999999029)] é DOMINADA entre os pontos ótimos.
# Solução 38 com imagem F(x*) = [np.float64(-2.99999999999842), np.float64(2.99999999999842)] NÃO é dominada entre os pontos ótimos.
# Solução 39 com imagem F(x*) = [np.float64(-2.7133988051303595), np.float64(2.999999999999152)] é DOMINADA entre os pontos ótimos.
# Solução 40 com imagem F(x*) = [np.float64(-3.642859699653362), np.float64(3.642859699653362)] NÃO é dominada entre os pontos ótimos.
# Solução 41 com imagem F(x*) = [np.float64(0.6622109820613985), np.float64(2.999999999998782)] é DOMINADA entre os pontos ótimos.
# Solução 42 com imagem F(x*) = [np.float64(-3.00000000000158), np.float64(3.00000000000158)] NÃO é dominada entre os pontos ótimos.
# Solução 43 com imagem F(x*) = [np.float64(-0.723283362675377), np.float64(3.0)] é DOMINADA entre os pontos ótimos.
# Solução 44 com imagem F(x*) = [np.float64(-0.7385296808877485), np.float64(3.0)] é DOMINADA entre os pontos ótimos.
# Solução 45 com imagem F(x*) = [np.float64(-6.0), np.float64(6.0)] NÃO é dominada entre os pontos ótimos.
# Solução 46 com imagem F(x*) = [np.float64(-4.522985285341728), np.float64(4.522985285341728)] NÃO é dominada entre os pontos ótimos.
# Solução 47 com imagem F(x*) = [np.float64(-0.9661546410102181), np.float64(2.9999999999990545)] é DOMINADA entre os pontos ótimos.
# Solução 48 com imagem F(x*) = [np.float64(-0.6755705776423996), np.float64(3.0)] é DOMINADA entre os pontos ótimos.
# Solução 49 com imagem F(x*) = [np.float64(-5.37603604685788), np.float64(5.37603604685788)] NÃO é dominada entre os pontos ótimos.
# Solução 50 com imagem F(x*) = [np.float64(-0.6578494050508557), np.float64(3.000000000001049)] é DOMINADA entre os pontos ótimos.
#
# ===== Verificação de Dominância DAS SOLUÇÕES NÃO DOMINADAS (Passo 2) em relação ao Espaço dos Objetivos =====
# Solução F(x*) = [np.float64(-3.5345446096577278), np.float64(3.5345446096577278)] NÃO foi dominada pelo espaço de amostras.
# Solução F(x*) = [np.float64(-4.334845788226803), np.float64(4.334845788226803)] NÃO foi dominada pelo espaço de amostras.
# Solução F(x*) = [np.float64(-3.7161363102529785), np.float64(3.7161363102529785)] NÃO foi dominada pelo espaço de amostras.
# Solução F(x*) = [np.float64(-3.001158538337474), np.float64(3.001158538337474)] NÃO foi dominada pelo espaço de amostras.
# Solução F(x*) = [np.float64(-4.302741724713836), np.float64(4.302741724713836)] NÃO foi dominada pelo espaço de amostras.
# Solução F(x*) = [np.float64(-3.7576784878034575), np.float64(3.7576784878034575)] NÃO foi dominada pelo espaço de amostras.
# Solução F(x*) = [np.float64(-4.316703685701959), np.float64(4.316703685701959)] NÃO foi dominada pelo espaço de amostras.
# Solução F(x*) = [np.float64(-4.247549687503401), np.float64(4.24754968750411)] NÃO foi dominada pelo espaço de amostras.
# Solução F(x*) = [np.float64(-3.1283341569013263), np.float64(3.1283341569013263)] NÃO foi dominada pelo espaço de amostras.
# Solução F(x*) = [np.float64(-4.015987095215569), np.float64(4.015987095215569)] NÃO foi dominada pelo espaço de amostras.
# Solução F(x*) = [np.float64(-3.1851403196293666), np.float64(3.1851403196293666)] NÃO foi dominada pelo espaço de amostras.
# Solução F(x*) = [np.float64(-3.0293742980999223), np.float64(3.0293742980999223)] NÃO foi dominada pelo espaço de amostras.
# Solução F(x*) = [np.float64(-3.0000000000015903), np.float64(3.0000000000015903)] NÃO foi dominada pelo espaço de amostras.
# Solução F(x*) = [np.float64(-3.6533299513933413), np.float64(3.6533299513933413)] NÃO foi dominada pelo espaço de amostras.
# Solução F(x*) = [np.float64(-2.99999999999842), np.float64(2.99999999999842)] NÃO foi dominada pelo espaço de amostras.
# Solução F(x*) = [np.float64(-3.642859699653362), np.float64(3.642859699653362)] NÃO foi dominada pelo espaço de amostras.
# Solução F(x*) = [np.float64(-3.00000000000158), np.float64(3.00000000000158)] NÃO foi dominada pelo espaço de amostras.
# Solução F(x*) = [np.float64(-6.0), np.float64(6.0)] NÃO foi dominada pelo espaço de amostras.
# Solução F(x*) = [np.float64(-4.522985285341728), np.float64(4.522985285341728)] NÃO foi dominada pelo espaço de amostras.
# Solução F(x*) = [np.float64(-5.37603604685788), np.float64(5.37603604685788)] NÃO foi dominada pelo espaço de amostras.
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern

# %%
# !pip install pygmo
import time  # Importa o módulo para medição de tempo
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize
import pygmo as pg  # Certifique-se de instalar o PyGMO )
from matplotlib.patches import Polygon

# ——————————————————————————————
# 1) Use MathText sem LaTeX externo, mas com Computer Modern
plt.rcParams['text.usetex']        = False
plt.rcParams['font.family']        = 'serif'
plt.rcParams['font.serif']         = ['Computer Modern']
plt.rcParams['mathtext.fontset']   = 'cm'
# ——————————————————————————————
###########################
# FUNÇÃO: FONSECA-FLEMING (não convexa) em R^2
###########################
def F(x):
    """
    Função Fonseca-Fleming para x em R^2:
      f1(x)= 1 - exp(-[(x1 - 1/sqrt(2))^2 + (x2 - 1/sqrt(2))^2])
      f2(x)= 1 - exp(-[(x1 + 1/sqrt(2))^2 + (x2 + 1/sqrt(2))^2])
    """
    n = 2
    term1 = (x[0] - 1/np.sqrt(n))**2 + (x[1] - 1/np.sqrt(n))**2
    term2 = (x[0] + 1/np.sqrt(n))**2 + (x[1] + 1/np.sqrt(n))**2
    f1 = 1 - np.exp(-term1)
    f2 = 1 - np.exp(-term2)
    return [f1, f2]

def gradF(x):
    """
    Gradiente da função Fonseca-Fleming.
    Retorna uma tupla (grad f1, grad f2) para x em R^2.
    """
    n = 2
    term1 = (x[0] - 1/np.sqrt(n))**2 + (x[1] - 1/np.sqrt(n))**2
    term2 = (x[0] + 1/np.sqrt(n))**2 + (x[1] + 1/np.sqrt(n))**2
    grad_f1 = np.array([2*(x[0] - 1/np.sqrt(n))*np.exp(-term1),
                         2*(x[1] - 1/np.sqrt(n))*np.exp(-term1)])
    grad_f2 = np.array([2*(x[0] + 1/np.sqrt(n))*np.exp(-term2),
                         2*(x[1] + 1/np.sqrt(n))*np.exp(-term2)])
    return grad_f1, grad_f2

###########################
# PROJEÇÃO VIA DIKSTRA PARA A REGIÃO VIÁVEL EM R^2:
# Restrições:
#   - Caixa: -1 <= x[i] <= 1, para i = 0,1
#   - Disco: x[0]^2 + x[1]^2 <= 1
###########################
def proj_box(x):
    """Projeta o ponto x no conjunto caixa [-1,1]^2."""
    return np.clip(x, -1, 1)

def proj_disk(x):
    """Projeta o ponto x no disco unitário: ||x|| <= 1."""
    norm_x = np.linalg.norm(x)
    if norm_x <= 1:
        return x
    else:
        return x / norm_x

def dykstra_projection(z, maxcycles=500):
    """
    Projeta z (em R^2) sobre a interseção dos conjuntos:
      - Caixa: -1 <= x_i <= 1, para i = 0,1
      - Disco: (x[0])^2+(x[1])^2 <= 1
    """
    x = z.copy()
    d_box = np.zeros_like(x)
    d_disk = np.zeros_like(x)
    errors = []

    for k in range(maxcycles):
        err = 0
        # Projeção no Caixa
        temp = x.copy()
        x = proj_box(x - d_box)
        d_box = x - (temp - d_box)
        err += np.linalg.norm(x - temp)**2

        # Projeção no Disco
        temp = x.copy()
        x = proj_disk(x - d_disk)
        d_disk = x - (temp - d_disk)
        err += np.linalg.norm(x - temp)**2

        errors.append(np.sqrt(err))
        if np.sqrt(err) < 1e-12:
            break
    return x, errors

def proj(z):
    """
    Função wrapper para projeção via Dykstra.
    """
    x, _ = dykstra_projection(z)
    return x

###########################
# OUTRAS FUNÇÕES: phi, phi_grad, gamma, armijo_step_size, compute_A_k, jacobian_F
###########################

def gamma(x):                   # substitui a versão antiga
    _, phi_val = solve_subproblem_epigraph(x)
    return phi_val

def solve_subproblem_epigraph(x, tol=1e-10):
    g1, g2 = gradF(x)                       # gradientes f1,f2  (shape (2,))
    dt0    = np.concatenate([np.zeros_like(x), [0.0]])

    obj      = lambda dt: dt[-1] + 0.5*np.dot(dt[:-1], dt[:-1])
    obj_grad = lambda dt: np.concatenate([dt[:-1], [1.0]])

    # epígrafe:  t – g·d ≥ 0
    cons = [
        {'type':'ineq', 'fun':lambda dt: dt[-1] - np.dot(g1, dt[:-1])},
        {'type':'ineq', 'fun':lambda dt: dt[-1] - np.dot(g2, dt[:-1])},
    ]
    # caixa [-1,1]²
    for i in range(2):
        cons.append({'type':'ineq', 'fun':lambda dt,i=i: (x[i]+dt[i]) + 1})
        cons.append({'type':'ineq', 'fun':lambda dt,i=i: 1 - (x[i]+dt[i])})
    # disco ‖x+d‖² ≤ 1
    cons.append({'type':'ineq', 'fun':lambda dt: 1 - np.dot(x+dt[:-1], x+dt[:-1])})

    res = minimize(obj, dt0, jac=obj_grad, constraints=cons,
                   method='SLSQP',
                   options={'ftol':tol, 'maxiter':500, 'disp':False})

    return res.x[:-1], obj(res.x)           # d*, φ(d*)

def armijo_step_size(x, d, F_fun, slope_vec, A_k, δ=0.5):
    for j in range(20):
        α = 1/(2**j)
        if np.all(F_fun(x + α*d) <= A_k + δ*α*slope_vec):
            return α
    return 1.0


def compute_A_k(f_values, k, m_prev, M):

    m_k = min(m_prev + 1, M) if k > 0 else 0
    recent = f_values[max(0, k-m_k): k+1]
    if not recent:
        recent = [f_values[-1]]
    A1 = max(f[0] for f in recent)
    A2 = max(f[1] for f in recent)
    return np.array([A1, A2]), m_k


def jacobian_F(x):
    """
    Calcula a Jacobiana de F usando os gradientes.
    """
    grad_f1, grad_f2 = gradF(x)
    return np.array([grad_f1, grad_f2])

###########################
# ALGORITMO DE OTIMIZAÇÃO COM MULTI-START
###########################
def optimization_run(x0, max_iter=50, M=10, δ=0.5, tol=1e-8):
    x        = x0.copy()
    f_hist   = []          # F(x^k)
    γ_hist   = []
    m_k      = 0           # janela não-monótona

    for k in range(max_iter):
        Fx = F(x)
        f_hist.append(Fx)

        # ================ sub-problema epígrafe=============
        d, φ_val = solve_subproblem_epigraph(x)
        γ_hist.append(φ_val)

        if np.linalg.norm(d) <= tol:        # parada
            break

        # ============ Armijo vetorial não-monótono ===============
        A_k, m_k = compute_A_k(f_hist, k, m_k, M)   # (A1,A2)
        J        = jacobian_F(x)                    # 2×2
        slope    = J @ d                            # [∇f1·d, ∇f2·d]
        α        = armijo_step_size(x, d, F, slope, A_k, δ)

        # ==================atualização =======================
        x = proj(x + α*d)

    return x, d, k, φ_val, F(x)


# Número de pontos de início no multi-start
n_starts = 50
solutions = []         # Armazena os pontos ótimos x*
solution_images = []   # Armazena as imagens F(x*) correspondentes

# Gerar pontos iniciais aleatórios em R^2 e projetá-los para a região viável
np.random.seed(0)
initial_points = []
for i in range(n_starts):
    # Gerar pontos aleatórios no quadrado [-1,1]^2
    x_rand = np.random.uniform(-1, 1, 2)
    # Projetar para a região viável (interseção do caixa e disco)
    x0_proj = proj(x_rand)
    initial_points.append(x0_proj)

# Inicia a medição do tempo
start_time = time.time()

print("===== Resultados Multi-Start =====")
for i, x0 in enumerate(initial_points):
    x_opt, subproblem_vec, iters, final_phi, Fx = optimization_run(x0)
    solutions.append(x_opt)
    solution_images.append(Fx)
    print(f"\n--- Início {i+1} ---")
    print("Ponto inicial (após projeção):", x0)
    print("Ponto ótimo x*:", x_opt)
    print("Vetor do subproblema final:", subproblem_vec)
    print("Número de iterações:", iters)
    print("Valor final de phi:", final_phi)
    print("Imagem da solução ótima F(x*):", Fx)

# Finaliza a medição do tempo
end_time = time.time()
elapsed_time = end_time - start_time
print("\nTempo de execução do multi-start:", elapsed_time, "segundos")

###########################
# GERAÇÃO DO ESPAÇO DOS OBJETIVOS
###########################
# Gerar pontos aleatórios no quadrado [-1,1]^2 e filtrar os que satisfazem (x1)^2+(x2)^2 <= 1
num_points = 1000000
obj_samples = []
for _ in range(num_points):
    x_candidate = np.random.uniform(-1, 1, 2)
    if np.dot(x_candidate, x_candidate) <= 1:
        obj_samples.append(x_candidate)
obj_samples = np.array(obj_samples)
objective_values = np.array([F(x) for x in obj_samples])
f1_values = objective_values[:, 0]
f2_values = objective_values[:, 1]

###########################
# VERIFICAÇÃO DE DOMINÂNCIA ENTRE OS PONTOS ÓTIMOS
###########################
def domina(sol1, sol2):
    """
    Retorna True se sol1 domina sol2, isto é, se sol1 é menor ou igual a sol2 em todas as componentes
    e estritamente menor em pelo menos uma.
    """
    sol1 = np.array(sol1)
    sol2 = np.array(sol2)
    return np.all(sol1 <= sol2) and np.any(sol1 < sol2)

print("\n===== Verificação de Dominância ENTRE os Pontos Ótimos (Passo 1) =====")
nondominated_among_optimal = []
dominated_among_optimal = []
for i, sol in enumerate(solution_images):
    dominated = False
    for j, other_sol in enumerate(solution_images):
        if i != j and domina(other_sol, sol):
            dominated = True
            break
    if dominated:
        dominated_among_optimal.append(sol)
        print(f"Solução {i+1} com imagem F(x*) = {sol} é DOMINADA entre os pontos ótimos.")
    else:
        nondominated_among_optimal.append(sol)
        print(f"Solução {i+1} com imagem F(x*) = {sol} NÃO é dominada entre os pontos ótimos.")

print("\n===== Verificação de Dominância DAS SOLUÇÕES NÃO DOMINADAS (Passo 2) em relação ao Espaço dos Objetivos =====")
nondominated_final = []
dominated_by_objectives = []
for sol in nondominated_among_optimal:
    dominated = False
    for pt in objective_values:
        if domina(pt, sol):
            dominated = True
            break
    if dominated:
        dominated_by_objectives.append(sol)
        print(f"Solução com imagem F(x*) = {sol} é DOMINADA pelo espaço dos objetivos.")
    else:
        nondominated_final.append(sol)
        print(f"Solução com imagem F(x*) = {sol} NÃO é dominada pelo espaço dos objetivos.")

final_dominated = dominated_among_optimal + dominated_by_objectives

###########################
# PLOT DO ESPAÇO DOS OBJETIVOS COM A CLASSIFICAÇÃO DOS PONTOS ÓTIMOS
###########################
plt.figure(figsize=(8,6))
plt.scatter(f1_values, f2_values, alpha=0.5, s=10, marker='o', color="blue", label="Espaço dos Objetivos")
for sol in final_dominated:
    plt.scatter(sol[0], sol[1], color="yellow", s=30, marker='o', edgecolor="black",
                label="Solução Dominada" if "Solução Dominada" not in plt.gca().get_legend_handles_labels()[1] else "")
for sol in nondominated_final:
    plt.scatter(sol[0], sol[1], color="red", s=30, marker='o', edgecolor="black",
                label="Solução Não Dominada" if "Solução Não Dominada" not in plt.gca().get_legend_handles_labels()[1] else "")
plt.title("Espaço dos Objetivos", fontsize=12)
plt.xlabel(r"$f_1(x)$", fontsize=12)
plt.ylabel(r"$f_2(x)$", fontsize=12)
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Requirement already satisfied: pygmo in /usr/local/lib/python3.11/dist-packages (2.19.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pygmo) (2.0.2)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from pygmo) (3.1.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from pygmo) (1.15.3)
# ===== Resultados Multi-Start =====
#
# --- Início 1 ---
# Ponto inicial (após projeção): [0.09762701 0.43037873]
# Ponto ótimo x*: [0.2432398  0.24325574]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 10
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.34970577361112287), np.float64(0.8357470317736092)]
#
# --- Início 2 ---
# Ponto inicial (após projeção): [0.20552675 0.08976637]
# Ponto ótimo x*: [0.14627931 0.14626481]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 8
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.4669132846062045), np.float64(0.7669520107705057)]
#
# --- Início 3 ---
# Ponto inicial (após projeção): [-0.1526904   0.29178823]
# Ponto ótimo x*: [0.05934617 0.05936239]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 8
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.5679295416310235), np.float64(0.691157893992443)]
#
# --- Início 4 ---
# Ponto inicial (após projeção): [-0.12482558  0.783546  ]
# Ponto ótimo x*: [0.1697287  0.16973829]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 11
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.43872264611126366), np.float64(0.7851247667564345)]
#
# --- Início 5 ---
# Ponto inicial (após projeção): [ 0.92732552 -0.23311696]
# Ponto ótimo x*: [0.11999484 0.11997827]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 11
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.498133092368536), np.float64(0.7454267781450024)]
#
# --- Início 6 ---
# Ponto inicial (após projeção): [0.58345008 0.05778984]
# Ponto ótimo x*: [0.2590618  0.25904666]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 11
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.33068613828983173), np.float64(0.8454031003594022)]
#
# --- Início 7 ---
# Ponto inicial (após projeção): [0.13608912 0.85119328]
# Ponto ótimo x*: [0.31215094 0.31217121]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 13
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.26799228329227676), np.float64(0.8747963819147998)]
#
# --- Início 8 ---
# Ponto inicial (após projeção): [-0.72049281 -0.69346241]
# Ponto ótimo x*: [-0.70085514 -0.70086072]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 16
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.9810268272973001), np.float64(7.809322761676007e-05)]
#
# --- Início 9 ---
# Ponto inicial (após projeção): [-0.82182058  0.56974638]
# Ponto ótimo x*: [-0.02600019 -0.02599353]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 11
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.6586619322972411), np.float64(0.604585799508038)]
#
# --- Início 10 ---
# Ponto inicial (após projeção): [0.5563135 0.7400243]
# Ponto ótimo x*: [0.60343032 0.6034524 ]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 11
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.021263709621821336), np.float64(0.9677769377762141)]
#
# --- Início 11 ---
# Ponto inicial (após projeção): [0.84798071 0.5300271 ]
# Ponto ótimo x*: [0.55367439 0.55366064]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 15
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.04599581007922082), np.float64(0.9583770533974557)]
#
# --- Início 12 ---
# Ponto inicial (após projeção): [-0.07704128  0.56105835]
# Ponto ótimo x*: [0.17884854 0.17886665]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 10
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.42770140900045095), np.float64(0.791926884009208)]
#
# --- Início 13 ---
# Ponto inicial (após projeção): [-0.76345115  0.27984204]
# Ponto ótimo x*: [-0.1013998  -0.10138347]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 10
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.7294610979559071), np.float64(0.5199099932270517)]
#
# --- Início 14 ---
# Ponto inicial (após projeção): [-0.62566968  0.78008811]
# Ponto ótimo x*: [0.01505262 0.01505865]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 11
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.6162905219274637), np.float64(0.6476171696864231)]
#
# --- Início 15 ---
# Ponto inicial (após projeção): [ 0.04369664 -0.17067612]
# Ponto ótimo x*: [-0.06121155 -0.06121798]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 8
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.692916623928243), np.float64(0.5658447122566485)]
#
# --- Início 16 ---
# Ponto inicial (após projeção): [-0.47088878  0.54846738]
# Ponto ótimo x*: [0.01623543 0.01624106]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 10
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.615033391518497), np.float64(0.6488198861440515)]
#
# --- Início 17 ---
# Ponto inicial (após projeção): [-0.08769934  0.1368679 ]
# Ponto ótimo x*: [0.02361644 0.02362233]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 8
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.6071431724556726), np.float64(0.6562777847181382)]
#
# --- Início 18 ---
# Ponto inicial (após projeção): [-0.9624204   0.23527099]
# Ponto ótimo x*: [-0.1174887  -0.11748245]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 12
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.7433148684595836), np.float64(0.5010784095339089)]
#
# --- Início 19 ---
# Ponto inicial (após projeção): [0.22419145 0.23386799]
# Ponto ótimo x*: [0.22900993 0.22901864]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 7
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.366911387265332), np.float64(0.826685130695165)]
#
# --- Início 20 ---
# Ponto inicial (após projeção): [0.88749616 0.3636406 ]
# Ponto ótimo x*: [0.44340593 0.44339213]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 16
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.1298446793491257), np.float64(0.9291597015909321)]
#
# --- Início 21 ---
# Ponto inicial (após projeção): [-0.2809842  -0.12593609]
# Ponto ótimo x*: [-0.20001059 -0.19999962]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 9
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.8071232576250632), np.float64(0.40208353630864835)]
#
# --- Início 22 ---
# Ponto inicial (após projeção): [ 0.39526239 -0.87954906]
# Ponto ótimo x*: [-0.06689426 -0.06690271]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 11
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.6982535872789872), np.float64(0.5594508766048862)]
#
# --- Início 23 ---
# Ponto inicial (após projeção): [0.33353343 0.34127574]
# Ponto ótimo x*: [0.33737899 0.33739845]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 7
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.23919857119205357), np.float64(0.8871777496170811)]
#
# --- Início 24 ---
# Ponto inicial (após projeção): [-0.57923488 -0.7421474 ]
# Ponto ótimo x*: [-0.61903391 -0.61904179]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 11
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.9703211072351965), np.float64(0.01539257762042312)]
#
# --- Início 25 ---
# Ponto inicial (após projeção): [-0.3691433  -0.27257846]
# Ponto ótimo x*: [-0.31856833 -0.31855673]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 10
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.8780318176780427), np.float64(0.2606125985132596)]
#
# --- Início 26 ---
# Ponto inicial (após projeção): [ 0.14039354 -0.12279697]
# Ponto ótimo x*: [0.00833032 0.00832339]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 8
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.6234056916934483), np.float64(0.6407334079093825)]
#
# --- Início 27 ---
# Ponto inicial (após projeção): [ 0.7752187  -0.63169294]
# Ponto ótimo x*: [0.01392651 0.01392052]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 11
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.6174921373985863), np.float64(0.6464637975561012)]
#
# --- Início 28 ---
# Ponto inicial (após projeção): [-0.58224649 -0.67738096]
# Ponto ótimo x*: [-0.61770149 -0.61771723]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 9
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.970111324891639), np.float64(0.015856734060358257)]
#
# --- Início 29 ---
# Ponto inicial (após projeção): [ 0.30621665 -0.49341679]
# Ponto ótimo x*: [-0.05536981 -0.05538292]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 9
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.6873781897045697), np.float64(0.5723734769427581)]
#
# --- Início 30 ---
# Ponto inicial (após projeção): [-0.06737845 -0.51114882]
# Ponto ótimo x*: [-0.24934252 -0.24935176]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 11
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.8395235707253728), np.float64(0.34235353477237496)]
#
# --- Início 31 ---
# Ponto inicial (após projeção): [-0.65862346 -0.75247268]
# Ponto ótimo x*: [-0.6697653  -0.66976661]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 6
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.9774395540627724), np.float64(0.002784789251371822)]
#
# --- Início 32 ---
# Ponto inicial (após projeção): [ 0.31265918 -0.7236341 ]
# Ponto ótimo x*: [-0.08662229 -0.08663445]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 10
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.7163547587613461), np.float64(0.5369808773193174)]
#
# --- Início 33 ---
# Ponto inicial (após projeção): [-0.60683528 -0.26254966]
# Ponto ótimo x*: [-0.39126736 -0.39124401]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 12
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.9104358556480313), np.float64(0.1808792994137033)]
#
# --- Início 34 ---
# Ponto inicial (após projeção): [ 0.62312452 -0.78212265]
# Ponto ótimo x*: [-0.01553321 -0.01553927]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 11
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.6481062070996513), np.float64(0.6157798661778331)]
#
# --- Início 35 ---
# Ponto inicial (após projeção): [ 0.64170748 -0.76694948]
# Ponto ótimo x*: [-0.012053   -0.01205892]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 11
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.6445568980234716), np.float64(0.6194703920212348)]
#
# --- Início 36 ---
# Ponto inicial (após projeção): [ 0.95291893 -0.0626976 ]
# Ponto ótimo x*: [0.19269656 0.19268863]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 13
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.4109498235019583), np.float64(0.8019583338411984)]
#
# --- Início 37 ---
# Ponto inicial (após projeção): [0.95352218 0.20969104]
# Ponto ótimo x*: [0.33410773 0.33409665]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 15
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.24290372673106309), np.float64(0.8856203644000229)]
#
# --- Início 38 ---
# Ponto inicial (após projeção): [ 0.46080875 -0.88749946]
# Ponto ótimo x*: [-0.05031167 -0.05032061]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 11
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.6825322240163529), np.float64(0.5779991271209476)]
#
# --- Início 39 ---
# Ponto inicial (após projeção): [-0.43438607 -0.75960688]
# Ponto ótimo x*: [-0.51784595 -0.51786676]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 14
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.9502661440453629), np.float64(0.06912609163752848)]
#
# --- Início 40 ---
# Ponto inicial (após projeção): [-0.4077196  -0.76254456]
# Ponto ótimo x*: [-0.49955371 -0.49957812]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 14
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.9456395266499773), np.float64(0.08254011698183727)]
#
# --- Início 41 ---
# Ponto inicial (após projeção): [-0.36403364 -0.17147401]
# Ponto ótimo x*: [-0.26052563 -0.26051499]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 10
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.8462772109951653), np.float64(0.3289280736315555)]
#
# --- Início 42 ---
# Ponto inicial (após projeção): [-0.87170501  0.38494424]
# Ponto ótimo x*: [-0.06969183 -0.0696838 ]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 11
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.7008528510176655), np.float64(0.5562996699576089)]
#
# --- Início 43 ---
# Ponto inicial (após projeção): [ 0.13320291 -0.46922102]
# Ponto ótimo x*: [-0.12535976 -0.12537339]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 9
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.7499323442167889), np.float64(0.4917812618588552)]
#
# --- Início 44 ---
# Ponto inicial (após projeção): [ 0.04649611 -0.81211898]
# Ponto ótimo x*: [-0.21281957 -0.21283026]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 12
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.8159501513254122), np.float64(0.386533199930591)]
#
# --- Início 45 ---
# Ponto inicial (após projeção): [0.15189299 0.8585924 ]
# Ponto ótimo x*: [0.32046053 0.32046975]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 14
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.2584283661966208), np.float64(0.878981047296395)]
#
# --- Início 46 ---
# Ponto inicial (após projeção): [-0.3628621   0.33482076]
# Ponto ótimo x*: [-0.00941248 -0.00940449]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 9
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.6418445802111101), np.float64(0.6222662985374017)]
#
# --- Início 47 ---
# Ponto inicial (após projeção): [-0.73640428  0.43265441]
# Ponto ótimo x*: [-0.04989408 -0.04988131]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 10
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.6821199829504252), np.float64(0.578474015648395)]
#
# --- Início 48 ---
# Ponto inicial (após projeção): [-0.42118781 -0.63361728]
# Ponto ótimo x*: [-0.50088933 -0.500902  ]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 13
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.9459875012086674), np.float64(0.08153001428844298)]
#
# --- Início 49 ---
# Ponto inicial (após projeção): [ 0.17302587 -0.95978491]
# Ponto ótimo x*: [-0.14174399 -0.14175199]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 12
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.7633348105453895), np.float64(0.47231783113598313)]
#
# --- Início 50 ---
# Ponto inicial (após projeção): [ 0.55322876 -0.83302938]
# Ponto ótimo x*: [-0.02940345 -0.02941036]
# Vetor do subproblema final: [0. 0.]
# Número de iterações: 11
# Valor final de phi: 0.0
# Imagem da solução ótima F(x*): [np.float64(0.6620660500850609), np.float64(0.6009043821302702)]
#
# Tempo de execução do multi-start: 2.2451469898223877 segundos
#
# ===== Verificação de Dominância ENTRE os Pontos Ótimos (Passo 1) =====
# Solução 1 com imagem F(x*) = [np.float64(0.34970577361112287), np.float64(0.8357470317736092)] NÃO é dominada entre os pontos ótimos.
# Solução 2 com imagem F(x*) = [np.float64(0.4669132846062045), np.float64(0.7669520107705057)] NÃO é dominada entre os pontos ótimos.
# Solução 3 com imagem F(x*) = [np.float64(0.5679295416310235), np.float64(0.691157893992443)] NÃO é dominada entre os pontos ótimos.
# Solução 4 com imagem F(x*) = [np.float64(0.43872264611126366), np.float64(0.7851247667564345)] NÃO é dominada entre os pontos ótimos.
# Solução 5 com imagem F(x*) = [np.float64(0.498133092368536), np.float64(0.7454267781450024)] NÃO é dominada entre os pontos ótimos.
# Solução 6 com imagem F(x*) = [np.float64(0.33068613828983173), np.float64(0.8454031003594022)] NÃO é dominada entre os pontos ótimos.
# Solução 7 com imagem F(x*) = [np.float64(0.26799228329227676), np.float64(0.8747963819147998)] NÃO é dominada entre os pontos ótimos.
# Solução 8 com imagem F(x*) = [np.float64(0.9810268272973001), np.float64(7.809322761676007e-05)] NÃO é dominada entre os pontos ótimos.
# Solução 9 com imagem F(x*) = [np.float64(0.6586619322972411), np.float64(0.604585799508038)] NÃO é dominada entre os pontos ótimos.
# Solução 10 com imagem F(x*) = [np.float64(0.021263709621821336), np.float64(0.9677769377762141)] NÃO é dominada entre os pontos ótimos.
# Solução 11 com imagem F(x*) = [np.float64(0.04599581007922082), np.float64(0.9583770533974557)] NÃO é dominada entre os pontos ótimos.
# Solução 12 com imagem F(x*) = [np.float64(0.42770140900045095), np.float64(0.791926884009208)] NÃO é dominada entre os pontos ótimos.
# Solução 13 com imagem F(x*) = [np.float64(0.7294610979559071), np.float64(0.5199099932270517)] NÃO é dominada entre os pontos ótimos.
# Solução 14 com imagem F(x*) = [np.float64(0.6162905219274637), np.float64(0.6476171696864231)] NÃO é dominada entre os pontos ótimos.
# Solução 15 com imagem F(x*) = [np.float64(0.692916623928243), np.float64(0.5658447122566485)] NÃO é dominada entre os pontos ótimos.
# Solução 16 com imagem F(x*) = [np.float64(0.615033391518497), np.float64(0.6488198861440515)] NÃO é dominada entre os pontos ótimos.
# Solução 17 com imagem F(x*) = [np.float64(0.6071431724556726), np.float64(0.6562777847181382)] NÃO é dominada entre os pontos ótimos.
# Solução 18 com imagem F(x*) = [np.float64(0.7433148684595836), np.float64(0.5010784095339089)] NÃO é dominada entre os pontos ótimos.
# Solução 19 com imagem F(x*) = [np.float64(0.366911387265332), np.float64(0.826685130695165)] NÃO é dominada entre os pontos ótimos.
# Solução 20 com imagem F(x*) = [np.float64(0.1298446793491257), np.float64(0.9291597015909321)] NÃO é dominada entre os pontos ótimos.
# Solução 21 com imagem F(x*) = [np.float64(0.8071232576250632), np.float64(0.40208353630864835)] NÃO é dominada entre os pontos ótimos.
# Solução 22 com imagem F(x*) = [np.float64(0.6982535872789872), np.float64(0.5594508766048862)] NÃO é dominada entre os pontos ótimos.
# Solução 23 com imagem F(x*) = [np.float64(0.23919857119205357), np.float64(0.8871777496170811)] NÃO é dominada entre os pontos ótimos.
# Solução 24 com imagem F(x*) = [np.float64(0.9703211072351965), np.float64(0.01539257762042312)] NÃO é dominada entre os pontos ótimos.
# Solução 25 com imagem F(x*) = [np.float64(0.8780318176780427), np.float64(0.2606125985132596)] NÃO é dominada entre os pontos ótimos.
# Solução 26 com imagem F(x*) = [np.float64(0.6234056916934483), np.float64(0.6407334079093825)] NÃO é dominada entre os pontos ótimos.
# Solução 27 com imagem F(x*) = [np.float64(0.6174921373985863), np.float64(0.6464637975561012)] NÃO é dominada entre os pontos ótimos.
# Solução 28 com imagem F(x*) = [np.float64(0.970111324891639), np.float64(0.015856734060358257)] NÃO é dominada entre os pontos ótimos.
# Solução 29 com imagem F(x*) = [np.float64(0.6873781897045697), np.float64(0.5723734769427581)] NÃO é dominada entre os pontos ótimos.
# Solução 30 com imagem F(x*) = [np.float64(0.8395235707253728), np.float64(0.34235353477237496)] NÃO é dominada entre os pontos ótimos.
# Solução 31 com imagem F(x*) = [np.float64(0.9774395540627724), np.float64(0.002784789251371822)] NÃO é dominada entre os pontos ótimos.
# Solução 32 com imagem F(x*) = [np.float64(0.7163547587613461), np.float64(0.5369808773193174)] NÃO é dominada entre os pontos ótimos.
# Solução 33 com imagem F(x*) = [np.float64(0.9104358556480313), np.float64(0.1808792994137033)] NÃO é dominada entre os pontos ótimos.
# Solução 34 com imagem F(x*) = [np.float64(0.6481062070996513), np.float64(0.6157798661778331)] NÃO é dominada entre os pontos ótimos.
# Solução 35 com imagem F(x*) = [np.float64(0.6445568980234716), np.float64(0.6194703920212348)] NÃO é dominada entre os pontos ótimos.
# Solução 36 com imagem F(x*) = [np.float64(0.4109498235019583), np.float64(0.8019583338411984)] NÃO é dominada entre os pontos ótimos.
# Solução 37 com imagem F(x*) = [np.float64(0.24290372673106309), np.float64(0.8856203644000229)] NÃO é dominada entre os pontos ótimos.
# Solução 38 com imagem F(x*) = [np.float64(0.6825322240163529), np.float64(0.5779991271209476)] NÃO é dominada entre os pontos ótimos.
# Solução 39 com imagem F(x*) = [np.float64(0.9502661440453629), np.float64(0.06912609163752848)] NÃO é dominada entre os pontos ótimos.
# Solução 40 com imagem F(x*) = [np.float64(0.9456395266499773), np.float64(0.08254011698183727)] NÃO é dominada entre os pontos ótimos.
# Solução 41 com imagem F(x*) = [np.float64(0.8462772109951653), np.float64(0.3289280736315555)] NÃO é dominada entre os pontos ótimos.
# Solução 42 com imagem F(x*) = [np.float64(0.7008528510176655), np.float64(0.5562996699576089)] NÃO é dominada entre os pontos ótimos.
# Solução 43 com imagem F(x*) = [np.float64(0.7499323442167889), np.float64(0.4917812618588552)] NÃO é dominada entre os pontos ótimos.
# Solução 44 com imagem F(x*) = [np.float64(0.8159501513254122), np.float64(0.386533199930591)] NÃO é dominada entre os pontos ótimos.
# Solução 45 com imagem F(x*) = [np.float64(0.2584283661966208), np.float64(0.878981047296395)] NÃO é dominada entre os pontos ótimos.
# Solução 46 com imagem F(x*) = [np.float64(0.6418445802111101), np.float64(0.6222662985374017)] NÃO é dominada entre os pontos ótimos.
# Solução 47 com imagem F(x*) = [np.float64(0.6821199829504252), np.float64(0.578474015648395)] NÃO é dominada entre os pontos ótimos.
# Solução 48 com imagem F(x*) = [np.float64(0.9459875012086674), np.float64(0.08153001428844298)] NÃO é dominada entre os pontos ótimos.
# Solução 49 com imagem F(x*) = [np.float64(0.7633348105453895), np.float64(0.47231783113598313)] NÃO é dominada entre os pontos ótimos.
# Solução 50 com imagem F(x*) = [np.float64(0.6620660500850609), np.float64(0.6009043821302702)] NÃO é dominada entre os pontos ótimos.
#
# ===== Verificação de Dominância DAS SOLUÇÕES NÃO DOMINADAS (Passo 2) em relação ao Espaço dos Objetivos =====
# Solução com imagem F(x*) = [np.float64(0.34970577361112287), np.float64(0.8357470317736092)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.4669132846062045), np.float64(0.7669520107705057)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.5679295416310235), np.float64(0.691157893992443)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.43872264611126366), np.float64(0.7851247667564345)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.498133092368536), np.float64(0.7454267781450024)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.33068613828983173), np.float64(0.8454031003594022)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.26799228329227676), np.float64(0.8747963819147998)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.9810268272973001), np.float64(7.809322761676007e-05)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.6586619322972411), np.float64(0.604585799508038)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.021263709621821336), np.float64(0.9677769377762141)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.04599581007922082), np.float64(0.9583770533974557)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.42770140900045095), np.float64(0.791926884009208)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.7294610979559071), np.float64(0.5199099932270517)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.6162905219274637), np.float64(0.6476171696864231)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.692916623928243), np.float64(0.5658447122566485)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.615033391518497), np.float64(0.6488198861440515)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.6071431724556726), np.float64(0.6562777847181382)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.7433148684595836), np.float64(0.5010784095339089)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.366911387265332), np.float64(0.826685130695165)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.1298446793491257), np.float64(0.9291597015909321)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.8071232576250632), np.float64(0.40208353630864835)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.6982535872789872), np.float64(0.5594508766048862)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.23919857119205357), np.float64(0.8871777496170811)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.9703211072351965), np.float64(0.01539257762042312)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.8780318176780427), np.float64(0.2606125985132596)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.6234056916934483), np.float64(0.6407334079093825)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.6174921373985863), np.float64(0.6464637975561012)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.970111324891639), np.float64(0.015856734060358257)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.6873781897045697), np.float64(0.5723734769427581)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.8395235707253728), np.float64(0.34235353477237496)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.9774395540627724), np.float64(0.002784789251371822)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.7163547587613461), np.float64(0.5369808773193174)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.9104358556480313), np.float64(0.1808792994137033)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.6481062070996513), np.float64(0.6157798661778331)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.6445568980234716), np.float64(0.6194703920212348)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.4109498235019583), np.float64(0.8019583338411984)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.24290372673106309), np.float64(0.8856203644000229)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.6825322240163529), np.float64(0.5779991271209476)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.9502661440453629), np.float64(0.06912609163752848)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.9456395266499773), np.float64(0.08254011698183727)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.8462772109951653), np.float64(0.3289280736315555)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.7008528510176655), np.float64(0.5562996699576089)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.7499323442167889), np.float64(0.4917812618588552)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.8159501513254122), np.float64(0.386533199930591)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.2584283661966208), np.float64(0.878981047296395)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.6418445802111101), np.float64(0.6222662985374017)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.6821199829504252), np.float64(0.578474015648395)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.9459875012086674), np.float64(0.08153001428844298)] NÃO é dominada pelo espaço dos objetivos.
# Solução com imagem F(x*) = [np.float64(0.7633348105453895), np.float64(0.47231783113598313)] NÃO é dominada pelo espaço dos objetivos.
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# Solução com imagem F(x*) = [np.float64(0.6620660500850609), np.float64(0.6009043821302702)] NÃO é dominada pelo espaço dos objetivos.
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern

# %%
# ==========================================================
#  Multi-start – Função Fonseca-Fleming (não-convexa)
# ==========================================================
# !pip install pygmo

import time
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize

np.random.seed(0)                             # semente para reprodução

# ————————————————————————————————————————————————
#  Fonte Computer Modern (sem LaTeX externo)
plt.rcParams['text.usetex']      = False
plt.rcParams['font.family']      = 'serif'
plt.rcParams['font.serif']       = ['Computer Modern']
plt.rcParams['mathtext.fontset'] = 'cm'
# ————————————————————————————————————————————————

# ==========================================================
#  Função objetivo – Fonseca-Fleming
# ==========================================================

def F(x):
    """
    f₁(x) = 1 − exp(−[(x₁−1/√2)² + (x₂−1/√2)²])
    f₂(x) = 1 − exp(−[(x₁+1/√2)² + (x₂+1/√2)²])
    """
    s = 1/np.sqrt(2)
    t1 = (x[0] - s)**2 + (x[1] - s)**2
    t2 = (x[0] + s)**2 + (x[1] + s)**2
    return np.array([1 - np.exp(-t1),
                     1 - np.exp(-t2)])


def grad_F(x):
    """
    Gradientes de f₁ e f₂ (R² → R²).
    """
    s = 1/np.sqrt(2)
    t1 = (x[0] - s)**2 + (x[1] - s)**2
    t2 = (x[0] + s)**2 + (x[1] + s)**2
    g1 = 2*np.exp(-t1) * np.array([x[0] - s, x[1] - s])
    g2 = 2*np.exp(-t2) * np.array([x[0] + s, x[1] + s])
    return g1, g2

# ==========================================================
#  Projeção (caixa + disco)
# ==========================================================

def proj_caixa(x):                       # −1 <= x_i x_i 1
    return np.clip(x, -1.0, 1.0)

def proj_disco(x):                       # ||X|| ≤ 1
    n = np.linalg.norm(x)
    return x if n <= 1 else x / n

def dykstra(z, max_ciclos=500, tol=1e-12):
    """
    Projeta z na interseção caixa∩disco usando Dykstra.
    """
    x      = z.copy()
    d_box  = np.zeros_like(x)
    d_disk = np.zeros_like(x)

    for _ in range(max_ciclos):
        err  = 0.0
        temp = x.copy()
        x    = proj_caixa(x - d_box);  d_box  = x - (temp - d_box)
        err += np.linalg.norm(x - temp)**2

        temp = x.copy()
        x    = proj_disco(x - d_disk); d_disk = x - (temp - d_disk)
        err += np.linalg.norm(x - temp)**2

        if np.sqrt(err) < tol:
            break
    return x

def proj(x):
    """Chama a projeção por Dykstra"""
    return dykstra(x)

# ==========================================================
#  Busca da direção por SLSQP
# ==========================================================

def buscadirecao(x, tol=1e-10):
    g1, g2 = grad_F(x)
    dt0    = np.concatenate([np.zeros_like(x), [0.0]])

    obj      = lambda dt: dt[-1] + 0.5*np.dot(dt[:-1], dt[:-1])
    obj_grad = lambda dt: np.concatenate([dt[:-1], [1.0]])

    # restrição sobre t
    cons = [{'type':'ineq', 'fun':lambda dt: dt[-1] - np.dot(g1, dt[:-1])},
            {'type':'ineq', 'fun':lambda dt: dt[-1] - np.dot(g2, dt[:-1])}]

    # restrição de caixa
    for i in range(2):
        cons.append({'type':'ineq', 'fun':lambda dt,i=i:  (x[i]+dt[i]) + 1})
        cons.append({'type':'ineq', 'fun':lambda dt,i=i:  1 - (x[i]+dt[i])})
    #restricao do disco
    cons.append({'type':'ineq',
                 'fun':lambda dt: 1 - np.dot(x+dt[:-1], x+dt[:-1])})

    res = minimize(obj, dt0, jac=obj_grad,
                   constraints=cons, method='SLSQP',
                   options={'ftol': tol, 'maxiter': 500, 'disp': False})

    return res.x[:-1], obj(res.x)           # devolve d* e phi(d*)

# ==========================================================
#  5) Armijo vetorial e utilitários
# ==========================================================

def Armijo_tamanho_passo(z, d, F, J, A_k, delta):
    """
    Seleciona tamanho de passo t através do critério de Armijo não-monótono do tipo máximo..
    Parâmetros:
    z : Ponto atual (x,y)
    d : Direção de busca obtida pelo SLSQP
    F : Função objetivo.
    J : Avaliação do gradiente em z na direção d.
    A_k : Par (A₁, A₂) acumulado nas últimas iterações.
    delta : Parâmetro usado apenas em Armijo.

    Retorna: O maior tamanho de passo t=1/2^j (j = 0, 1, ...,19) que satisfaz a cond. de Armijo
        F(z + td) <= A_k + delta t J;
        retorna 1.0 se nenhum j satisfizer.
    """
    for j in range(30):
        t_val = 1/(2**j)
        z_next = z + t_val*d
        F_next = np.array(F(z_next))
        rhs = np.array(A_k) + delta*t_val*J
        if np.all(F_next <= rhs):
            return t_val
    return 1


def compute_A_k(f_values, k, M=10):
    """
    Calcula o valor de A_k para Armijo não-monótono.

    Parâmetros usados:
    f_values : Histórico de valores de F(z) (cada um sendo um vetor de dimensão 2).
    k : índice da iteração atual.
    M : Número máximo de iterações consideradas em A_k (M=10).

    Retorna:
    A_k : Par (A₁, A₂), onde cada componente é o máximo de F_j nas últimas min(k, M) iterações.
    """
    m_k = min(k, M)
    recentes = f_values[max(0, k-m_k) : k+1] #Seleciona o conjunto de valores F(z^j) desde j = k–m_k até j = k
    if not recentes:  # Caso k=0 e f_values tem só um elemento
        return f_values[-1]
    A1 = max(f[0] for f in recentes)
    A2 = max(f[1] for f in recentes)
    return (A1, A2)

def jacobiana_F(x):
    g1, g2 = grad_F(x)
    return np.array([g1, g2])

# ==========================================================
#  Função de otimização
# ==========================================================

def PGMMOP(x0, max_iter=50, M=10, δ=0.5, tol=1e-8):
    """
    Devolve:
      x*         – ponto final
      d_last     – direção da última iteração
      k          – nº de iterações executadas
      phi_last   – phi final
      F(x*)      – imagem final
      phi_hist – histórico de phi(d^k)
    """
    x       = x0.copy()
    hist_F  = []
    hist_phi = []


    for k in range(max_iter):
        Fx = F(x)
        hist_F.append(Fx)
        d, phi_final = buscadirecao(x)
        hist_phi.append(phi_final)
        if np.linalg.norm(d) <= tol:
            break

        A_k       = compute_A_k(hist_F, k, M)
        slope       = jacobiana_F(x) @ d
        t           = Armijo_tamanho_passo(x, d, F, slope, A_k, δ)

        x = proj(x + t*d)

    return x, d, k, phi_final, F(x),hist_phi

# ==========================================================
#  7) Loop multi-start
# ==========================================================

n_starts    = 50
solucoes_F  = []

print("\n===== RESULTADOS DO MULTI-START (Fonseca-Fleming) =====")
t0 = time.perf_counter()

for i in range(n_starts):
    x_ini = proj(np.random.uniform(-1, 1, 2))           # ponto viável
    x_opt, d_last, iters, phi_final, Fx,_ = PGMMOP(x_ini)
    solucoes_F.append(Fx)

    print(f"\n— Partida {i+1}")
    print("Ponto inicial:", x_ini)
    print("Ponto ótimo:", x_opt)
    print("Iterações:", iters, " φ final:", phi_final, " F(x*):", Fx)

print(f"\nTempo total: {time.perf_counter() - t0:.2f} s")

# ==========================================================
# Amostragem do espaço dos objetivos
# ==========================================================

N = 300_000
amostras  = []
while len(amostras) < N:
    cand = np.random.uniform(-1, 1, 2)
    if np.dot(cand, cand) <= 1:
        amostras.append(cand)
amostras       = np.array(amostras)
valores_obj    = np.array([F(p) for p in amostras])

# ==========================================================
#  filtro de dominância
# ==========================================================

def domina(a, b):
    a, b = np.asarray(a), np.asarray(b)
    return np.all(a <= b) and np.any(a < b)

dom_d, dom_nd = [], []

for sol in solucoes_F:
    dominated = any(domina(outro, sol) for outro in solucoes_F
                    if not np.array_equal(sol, outro))
    if not dominated:
        dominated = any(domina(pt, sol) for pt in valores_obj)
    (dom_d if dominated else dom_nd).append(sol)

# ==========================================================
# Plot do espaço dos objetivos
# ==================================================

plt.figure(figsize=(8,6))
plt.scatter(valores_obj[:,0], valores_obj[:,1],
            s=8, alpha=0.35, color='blue', label="Espaço dos Objetivos")

for sol in dom_d:
    plt.scatter(*sol, s=30, color='yellow', edgecolor='black',
                label="Solução Dominada"
                if "Solução Dominada" not in plt.gca().get_legend_handles_labels()[1] else "")

for sol in dom_nd:
    plt.scatter(*sol, s=30, color='red', edgecolor='black',
                label="Solução Não Dominada"
                if "Solução Não Dominada" not in plt.gca().get_legend_handles_labels()[1] else "")

plt.title("Espaço dos Objetivos – Fonseca-Fleming")
plt.xlabel(r"$f_1(x)$")
plt.ylabel(r"$f_2(x)$")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ===== RESULTADOS DO MULTI-START (Fonseca-Fleming) =====
#
# — Partida 1
# Ponto inicial: [0.09762701 0.43037873]
# Ponto ótimo: [0.2432398  0.24325574]
# Iterações: 10  φ final: 0.0  F(x*): [0.34970577 0.83574703]
#
# — Partida 2
# Ponto inicial: [0.20552675 0.08976637]
# Ponto ótimo: [0.14627931 0.14626481]
# Iterações: 8  φ final: 0.0  F(x*): [0.46691328 0.76695201]
#
# — Partida 3
# Ponto inicial: [-0.1526904   0.29178823]
# Ponto ótimo: [0.05934617 0.05936239]
# Iterações: 8  φ final: 0.0  F(x*): [0.56792954 0.69115789]
#
# — Partida 4
# Ponto inicial: [-0.12482558  0.783546  ]
# Ponto ótimo: [0.1697287  0.16973829]
# Iterações: 11  φ final: 0.0  F(x*): [0.43872265 0.78512477]
#
# — Partida 5
# Ponto inicial: [ 0.92732552 -0.23311696]
# Ponto ótimo: [0.11999484 0.11997827]
# Iterações: 11  φ final: 0.0  F(x*): [0.49813309 0.74542678]
#
# — Partida 6
# Ponto inicial: [0.58345008 0.05778984]
# Ponto ótimo: [0.2590618  0.25904666]
# Iterações: 11  φ final: 0.0  F(x*): [0.33068614 0.8454031 ]
#
# — Partida 7
# Ponto inicial: [0.13608912 0.85119328]
# Ponto ótimo: [0.31215094 0.31217121]
# Iterações: 13  φ final: 0.0  F(x*): [0.26799228 0.87479638]
#
# — Partida 8
# Ponto inicial: [-0.72049281 -0.69346241]
# Ponto ótimo: [-0.70085514 -0.70086072]
# Iterações: 16  φ final: 0.0  F(x*): [9.81026827e-01 7.80932276e-05]
#
# — Partida 9
# Ponto inicial: [-0.82182058  0.56974638]
# Ponto ótimo: [-0.02600019 -0.02599353]
# Iterações: 11  φ final: 0.0  F(x*): [0.65866193 0.6045858 ]
#
# — Partida 10
# Ponto inicial: [0.5563135 0.7400243]
# Ponto ótimo: [0.60343032 0.6034524 ]
# Iterações: 11  φ final: 0.0  F(x*): [0.02126371 0.96777694]
#
# — Partida 11
# Ponto inicial: [0.84798071 0.5300271 ]
# Ponto ótimo: [0.55367439 0.55366064]
# Iterações: 15  φ final: 0.0  F(x*): [0.04599581 0.95837705]
#
# — Partida 12
# Ponto inicial: [-0.07704128  0.56105835]
# Ponto ótimo: [0.17884854 0.17886665]
# Iterações: 10  φ final: 0.0  F(x*): [0.42770141 0.79192688]
#
# — Partida 13
# Ponto inicial: [-0.76345115  0.27984204]
# Ponto ótimo: [-0.1013998  -0.10138347]
# Iterações: 10  φ final: 0.0  F(x*): [0.7294611  0.51990999]
#
# — Partida 14
# Ponto inicial: [-0.62566968  0.78008811]
# Ponto ótimo: [0.01505262 0.01505865]
# Iterações: 11  φ final: 0.0  F(x*): [0.61629052 0.64761717]
#
# — Partida 15
# Ponto inicial: [ 0.04369664 -0.17067612]
# Ponto ótimo: [-0.06121155 -0.06121798]
# Iterações: 8  φ final: 0.0  F(x*): [0.69291662 0.56584471]
#
# — Partida 16
# Ponto inicial: [-0.47088878  0.54846738]
# Ponto ótimo: [0.01623543 0.01624106]
# Iterações: 10  φ final: 0.0  F(x*): [0.61503339 0.64881989]
#
# — Partida 17
# Ponto inicial: [-0.08769934  0.1368679 ]
# Ponto ótimo: [0.02361644 0.02362233]
# Iterações: 8  φ final: 0.0  F(x*): [0.60714317 0.65627778]
#
# — Partida 18
# Ponto inicial: [-0.9624204   0.23527099]
# Ponto ótimo: [-0.1174887  -0.11748245]
# Iterações: 12  φ final: 0.0  F(x*): [0.74331487 0.50107841]
#
# — Partida 19
# Ponto inicial: [0.22419145 0.23386799]
# Ponto ótimo: [0.22900993 0.22901864]
# Iterações: 7  φ final: 0.0  F(x*): [0.36691139 0.82668513]
#
# — Partida 20
# Ponto inicial: [0.88749616 0.3636406 ]
# Ponto ótimo: [0.44340593 0.44339213]
# Iterações: 16  φ final: 0.0  F(x*): [0.12984468 0.9291597 ]
#
# — Partida 21
# Ponto inicial: [-0.2809842  -0.12593609]
# Ponto ótimo: [-0.20001059 -0.19999962]
# Iterações: 9  φ final: 0.0  F(x*): [0.80712326 0.40208354]
#
# — Partida 22
# Ponto inicial: [ 0.39526239 -0.87954906]
# Ponto ótimo: [-0.06689426 -0.06690271]
# Iterações: 11  φ final: 0.0  F(x*): [0.69825359 0.55945088]
#
# — Partida 23
# Ponto inicial: [0.33353343 0.34127574]
# Ponto ótimo: [0.33737899 0.33739845]
# Iterações: 7  φ final: 0.0  F(x*): [0.23919857 0.88717775]
#
# — Partida 24
# Ponto inicial: [-0.57923488 -0.7421474 ]
# Ponto ótimo: [-0.61903391 -0.61904179]
# Iterações: 11  φ final: 0.0  F(x*): [0.97032111 0.01539258]
#
# — Partida 25
# Ponto inicial: [-0.3691433  -0.27257846]
# Ponto ótimo: [-0.31856833 -0.31855673]
# Iterações: 10  φ final: 0.0  F(x*): [0.87803182 0.2606126 ]
#
# — Partida 26
# Ponto inicial: [ 0.14039354 -0.12279697]
# Ponto ótimo: [0.00833032 0.00832339]
# Iterações: 8  φ final: 0.0  F(x*): [0.62340569 0.64073341]
#
# — Partida 27
# Ponto inicial: [ 0.7752187  -0.63169294]
# Ponto ótimo: [0.01392651 0.01392052]
# Iterações: 11  φ final: 0.0  F(x*): [0.61749214 0.6464638 ]
#
# — Partida 28
# Ponto inicial: [-0.58224649 -0.67738096]
# Ponto ótimo: [-0.61770149 -0.61771723]
# Iterações: 9  φ final: 0.0  F(x*): [0.97011132 0.01585673]
#
# — Partida 29
# Ponto inicial: [ 0.30621665 -0.49341679]
# Ponto ótimo: [-0.05536981 -0.05538292]
# Iterações: 9  φ final: 0.0  F(x*): [0.68737819 0.57237348]
#
# — Partida 30
# Ponto inicial: [-0.06737845 -0.51114882]
# Ponto ótimo: [-0.24934252 -0.24935176]
# Iterações: 11  φ final: 0.0  F(x*): [0.83952357 0.34235353]
#
# — Partida 31
# Ponto inicial: [-0.65862346 -0.75247268]
# Ponto ótimo: [-0.6697653  -0.66976661]
# Iterações: 6  φ final: 0.0  F(x*): [0.97743955 0.00278479]
#
# — Partida 32
# Ponto inicial: [ 0.31265918 -0.7236341 ]
# Ponto ótimo: [-0.08662229 -0.08663445]
# Iterações: 10  φ final: 0.0  F(x*): [0.71635476 0.53698088]
#
# — Partida 33
# Ponto inicial: [-0.60683528 -0.26254966]
# Ponto ótimo: [-0.39126736 -0.39124401]
# Iterações: 12  φ final: 0.0  F(x*): [0.91043586 0.1808793 ]
#
# — Partida 34
# Ponto inicial: [ 0.62312452 -0.78212265]
# Ponto ótimo: [-0.01553321 -0.01553927]
# Iterações: 11  φ final: 0.0  F(x*): [0.64810621 0.61577987]
#
# — Partida 35
# Ponto inicial: [ 0.64170748 -0.76694948]
# Ponto ótimo: [-0.012053   -0.01205892]
# Iterações: 11  φ final: 0.0  F(x*): [0.6445569  0.61947039]
#
# — Partida 36
# Ponto inicial: [ 0.95291893 -0.0626976 ]
# Ponto ótimo: [0.19269656 0.19268863]
# Iterações: 13  φ final: 0.0  F(x*): [0.41094982 0.80195833]
#
# — Partida 37
# Ponto inicial: [0.95352218 0.20969104]
# Ponto ótimo: [0.33410773 0.33409665]
# Iterações: 15  φ final: 0.0  F(x*): [0.24290373 0.88562036]
#
# — Partida 38
# Ponto inicial: [ 0.46080875 -0.88749946]
# Ponto ótimo: [-0.05031167 -0.05032061]
# Iterações: 11  φ final: 0.0  F(x*): [0.68253222 0.57799913]
#
# — Partida 39
# Ponto inicial: [-0.43438607 -0.75960688]
# Ponto ótimo: [-0.51784595 -0.51786676]
# Iterações: 14  φ final: 0.0  F(x*): [0.95026614 0.06912609]
#
# — Partida 40
# Ponto inicial: [-0.4077196  -0.76254456]
# Ponto ótimo: [-0.49955371 -0.49957812]
# Iterações: 14  φ final: 0.0  F(x*): [0.94563953 0.08254012]
#
# — Partida 41
# Ponto inicial: [-0.36403364 -0.17147401]
# Ponto ótimo: [-0.26052563 -0.26051499]
# Iterações: 10  φ final: 0.0  F(x*): [0.84627721 0.32892807]
#
# — Partida 42
# Ponto inicial: [-0.87170501  0.38494424]
# Ponto ótimo: [-0.06969183 -0.0696838 ]
# Iterações: 11  φ final: 0.0  F(x*): [0.70085285 0.55629967]
#
# — Partida 43
# Ponto inicial: [ 0.13320291 -0.46922102]
# Ponto ótimo: [-0.12535976 -0.12537339]
# Iterações: 9  φ final: 0.0  F(x*): [0.74993234 0.49178126]
#
# — Partida 44
# Ponto inicial: [ 0.04649611 -0.81211898]
# Ponto ótimo: [-0.21281957 -0.21283026]
# Iterações: 12  φ final: 0.0  F(x*): [0.81595015 0.3865332 ]
#
# — Partida 45
# Ponto inicial: [0.15189299 0.8585924 ]
# Ponto ótimo: [0.32046053 0.32046975]
# Iterações: 14  φ final: 0.0  F(x*): [0.25842837 0.87898105]
#
# — Partida 46
# Ponto inicial: [-0.3628621   0.33482076]
# Ponto ótimo: [-0.00941248 -0.00940449]
# Iterações: 9  φ final: 0.0  F(x*): [0.64184458 0.6222663 ]
#
# — Partida 47
# Ponto inicial: [-0.73640428  0.43265441]
# Ponto ótimo: [-0.04989408 -0.04988131]
# Iterações: 10  φ final: 0.0  F(x*): [0.68211998 0.57847402]
#
# — Partida 48
# Ponto inicial: [-0.42118781 -0.63361728]
# Ponto ótimo: [-0.50088933 -0.500902  ]
# Iterações: 13  φ final: 0.0  F(x*): [0.9459875  0.08153001]
#
# — Partida 49
# Ponto inicial: [ 0.17302587 -0.95978491]
# Ponto ótimo: [-0.14174399 -0.14175199]
# Iterações: 12  φ final: 0.0  F(x*): [0.76333481 0.47231783]
#
# — Partida 50
# Ponto inicial: [ 0.55322876 -0.83302938]
# Ponto ótimo: [-0.02940345 -0.02941036]
# Iterações: 11  φ final: 0.0  F(x*): [0.66206605 0.60090438]
#
# Tempo total: 4.20 s
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern

# %%
# ============================================================
# Instalação / pacotes
# ============================================================
# !pip install pygmo               # <-- deixe ativo se precisar

import time
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize
import pygmo as pg
from matplotlib.patches import Polygon

# ------------------------------------------------------------------
#  Configuração de fontes (MathText + Computer Modern)
# ------------------------------------------------------------------
plt.rcParams['text.usetex']      = False
plt.rcParams['font.family']      = 'serif'
plt.rcParams['font.serif']       = ['Computer Modern']
plt.rcParams['mathtext.fontset'] = 'cm'

# ============================================================
# DADOS BÁSICOS
# ============================================================
n            = 3                  # dimensão x e y
dim          = 2 * n
alpha        = 2                  # cardinalidade
tol_stop     = 1e-5
max_outer    = 50                 # iterações externas (τ,λ)
M_hist       = 10                 # janela não-monótona

# ============================================================
# Função original e penalizada
# ============================================================
def F_mobj(z):
    x = z[:n]
    return np.array([(x[2] - 1) ** 2, -x[2]])          # f₁, f₂


def F_pen(z, tau, lam):
    x, y = z[:n], z[n:]
    base = F_mobj(z)
    # termo: (tau/2)*||x0y + lam/tau||² multiplicado pelo vetor e
    term = (tau / 2) * np.linalg.norm(x * y + lam / tau)**2
    return base + term * np.ones_like(base)
# Jacobiana de F_pen  (2 × 2n)
def jacobiano_F_pen(z, tau, lam):
    x, y   = z[:n], z[n:]
    had    = x * y
    dp_dx  = lam * y + tau * (had * y)
    dp_dy  = lam * x + tau * (had * x)

    g1x = np.array([0.0, 0.0, 2 * (x[2] - 1)]) + dp_dx
    g2x = np.array([0.0, 0.0,         -1.0   ]) + dp_dx

    row1 = np.concatenate([g1x, dp_dy])
    row2 = np.concatenate([g2x, dp_dy])
    return np.vstack([row1, row2])

# ============================================================
#  PROJEÇÃO VIA DYKSTRA (conj. viável para x,y)
# ============================================================
def dykstra(z, maxcycles=500, tol=1e-12):
    z = z.copy()
    d1 = np.zeros(dim); d2 = np.zeros(dim); d3 = np.zeros(dim)

    for _ in range(maxcycles):
        err = 0.0

        # restrição  x0 <= 0
        tmp = z.copy()
        z[0]  = min(tmp[0] - d1[0], 0.0)
        d1[0] = z[0] - (tmp[0] - d1[0])
        err  += (z[0] - tmp[0])**2

        #  caixa para y pertence [0,1]³
        tmp = z.copy()
        ypr        = np.clip(tmp[n:] - d2[n:], 0.0, 1.0)
        d2[n:]     = ypr - (tmp[n:] - d2[n:])
        z[n:]      = ypr
        err       += np.linalg.norm(ypr - tmp[n:])**2

        #  sum(y) >= n-alpha
        tmp = z.copy()
        s   = np.sum(tmp[n:] - d3[n:])
        if s < (n - alpha):
            corr = ((n - alpha) - s) / n
            yhp  = (tmp[n:] - d3[n:]) + corr
        else:
            yhp  = tmp[n:] - d3[n:]
        d3[n:] = yhp - (tmp[n:] - d3[n:])
        z[n:]  = yhp
        err   += np.linalg.norm(yhp - tmp[n:])**2

        if np.sqrt(err) < tol:
            break
    return z

# Chamando Dykstra com outro nome
proj = dykstra

# ============================================================
# SUB-PROBLEMA
# ============================================================
def SLSQP(z, tau, lam, tol=1e-10):
    """
    Resolve o sub-problema epígrafe via SLSQP e devolve (d*, phi).
    """
    J  = jacobiano_F_pen(z, tau, lam)          # shape (2,6)
    dt0 = np.concatenate([np.zeros(dim), [0.0]])

    # objetivo + gradiente
    obj      = lambda dt: dt[-1] + 0.5 * np.dot(dt[:-1], dt[:-1])
    obj_grad = lambda dt: np.concatenate([dt[:-1], [1.0]])

    cons = [
        {'type':'ineq', 'fun':lambda dt, i=i: dt[-1] - (J[i] @ dt[:-1])}
        for i in range(2)
    ]

    # x0 <= 0   – variável x corresponde a índices 0..2
    cons.append({'type':'ineq', 'fun':lambda dt: 0.0 - (z[0] + dt[0])})

    #  y pertence a [0,1]³   (índices 3..5 em z+dt)
    for j in range(n, dim):
        cons.append({'type':'ineq', 'fun':lambda dt, j=j: (z[j] + dt[j])     }) # >=0
        cons.append({'type':'ineq', 'fun':lambda dt, j=j: 1.0 - (z[j] + dt[j])})

    # soma(y)>= n-alpha
        cons.append({'type':'ineq',
             'fun': lambda dt: np.sum(z[n:] + dt[n:-1]) - (n - alpha)})

        res = minimize(obj, dt0, jac=obj_grad, constraints=cons,
                   method='SLSQP',
                   options={'ftol': tol, 'maxiter': 500, 'disp': False})

    return res.x[:-1], obj(res.x)             # d*, phi(d*)



# ============================================================
# Armijo vetorial (não-monótono)
# ============================================================
def Armijo_tamanho_passo(z, d, F, J, A_k, delta=0.5):
    """
    Seleciona tamanho de passo t através do critério de Armijo não-monótono do tipo máximo..
    Parâmetros:
    z : Ponto atual (x,y)
    d : Direção de busca obtida pelo SLSQP
    F : Função objetivo penalizada (na prática "lagrangiano_penalizado"), que retorna vetor de dimensão 2.
    J : Avaliação do gradiente em z na direção d, isto é [nabla L1.d, nabla L2.d].
    A_k : Par (A1, A2) acumulado nas últimas iterações.
    delta : Parâmetro usado apenas em Armijo.

    Retorna: O maior tamanho de passo t=1/2^j (j = 0, 1, ...,20) que satisfaz a cond. de Armijo
        F(z + td) ≤ A_k + δ t J;
        retorna 1.0 se nenhum j satisfizer.
    """
    for j in range(20):
        t_val = 1/(2**j)
        z_next = z + t_val*d
        F_next = np.array(F(z_next))
        rhs = np.array(A_k) + delta*t_val*J
        if np.all(F_next <= rhs):
            return t_val
    return 1

def compute_A_k(f_values, k, M=10):
    """
    Calcula o valor de A_k para Armijo não-monótono.

    Parâmetros usados:
    f_values : Histórico de valores de F(z) (cada um sendo um vetor de dimensão 2).
    k : índice da iteração atual.
    M : Número máximo de iterações consideradas em A_k (M=10).

    Retorna:
    A_k : Par (A₁, A₂), onde cada componente é o máximo de F_j nas últimas min(k, M) iterações.
    """
    m_k = min(k, M)
    recentes = f_values[max(0, k-m_k) : k+1] #Seleciona o conjunto de valores F(z^j) desde j = k–m_k até j = k
    if not recentes:  # Caso k=0 e f_values tem só um elemento
        return f_values[-1]
    A1 = max(f[0] for f in recentes)
    A2 = max(f[1] for f in recentes)
    return (A1, A2)



# ============================================================
# Aplicação do PGMMOP
# ============================================================
def PGMMOP(z, tau, lam, max_iter=50, tol=1e-8):
    f_hist = []

    for k in range(max_iter):
        f_pen = F_pen(z, tau, lam)
        f_hist.append(f_pen)

        d, phi_val = SLSQP(z, tau, lam)      # busca de direção

        if np.linalg.norm(d) <= tol:
            break

        A_k   = compute_A_k(f_hist, k)       # janela não-monótona
        J_vec = jacobiano_F_pen(z, tau, lam) @ d
        t     = Armijo_tamanho_passo(
                    z, d,
                    lambda zz: F_pen(zz, tau, lam),    # função F_pen(·)
                    J_vec,
                    A_k)
        z = proj(z + t * d)                   # passo de projeção

    return z, d


# ============================================================
#  Otimização externa  (tau, lamb)
# ============================================================
def optimization_run_extended_outer(z0):
    z      = proj(z0)
    lam    = np.ones(n)
    tau    = 1.0
    lam_lo, lam_hi = -1e-4, 1e4
    tau_max        = 1e5
    delta_tau      = 10.0

    F_prev = F_pen(z, tau, lam)

    for k in range(max_outer):
        z_new, d = PGMMOP(z, tau, lam)

        x_new, y_new = z_new[:n], z_new[n:]
        norm_had     = np.linalg.norm(x_new * y_new)
        diff_F       = np.linalg.norm(F_pen(z_new, tau, lam) - F_prev)

        print(f"Iter ex {k:2d}: ||d||={np.linalg.norm(d):.2e}  "
              f"tau={tau:.2e}  ‖x∘y‖={norm_had:.2e}  ΔF={diff_F:.2e}")

        # critério de parada externo
        if (norm_had**2 <= tol_stop * np.linalg.norm(x_new)**2 * np.linalg.norm(y_new)**2
                and diff_F <= tol_stop):
            print("· Critério externo satisfeito ·")
            break

        # atualização LAMB, TAU        lam = np.clip(lam + tau * (x_new * y_new), lam_lo, lam_hi)
        tau = min(tau * delta_tau, tau_max)

        z, F_prev = z_new, F_pen(z_new, tau, lam)

    return z_new

# ============================================================
#  MULTI-START
# ============================================================
np.random.seed(0)
solution_images = []

for i in range(30):
    x0 = np.random.uniform(0.5, 4, n)
    y0 = np.random.uniform(0,   1, n)
    z0 = proj(np.hstack([x0, y0]))

    print(f"\n=== Início {i+1} ===")
    z_opt = optimization_run_extended_outer(z0)
    sol   = F(z_opt)
    solution_images.append(sol)
    print("F(z*) =", sol)

# ============================================================
#  Conjunto de pontos aleatórios (espaço de objetivos)
# ============================================================
num_points = 30_000
xs         = np.random.uniform(-4, 4, (num_points, n))
xs[:,0]    = np.minimum(xs[:,0], 0.0)          # impõe x₀ ≤ 0
objective_values = np.column_stack([(xs[:,2]-1)**2, -xs[:,2]])
f1_vals, f2_vals = objective_values.T

# ============================================================
#  Dominância
# ============================================================
def domina(a, b):
    return np.all(a <= b) and np.any(a < b)

dominated, nondominated = [], []
for s in solution_images:
    if any(domina(o, s) for o in solution_images if not np.array_equal(o, s)):
        dominated.append(s)
    elif any(domina(p, s) for p in objective_values):
        dominated.append(s)
    else:
        nondominated.append(s)

# ============================================================
#  Plot final
# ============================================================
fig, ax = plt.subplots(figsize=(8,6))
ax.scatter(f1_vals, f2_vals, s=10, alpha=0.5, color='blue', label='Pontos Objetivo')
ax.scatter(1.0, 0.0, color='yellow', s=40, marker='o', edgecolor='black',
           label=r'$F(x^*)=(1,0)$')
for s in dominated:
    ax.scatter(s[0], s[1], color='yellow', s=30, edgecolor='black',
               label='Dominada' if 'Dominada' not in ax.get_legend_handles_labels()[1] else '')
for s in nondominated:
    ax.scatter(s[0], s[1], color='red', s=30, edgecolor='black',
               label='Não Dominada' if 'Não Dominada' not in ax.get_legend_handles_labels()[1] else '')

#ax.set_title("Espaço dos Objetivos – Dominadas × Não Dominadas")
ax.set_xlabel(r'$f_1(x)$',fontsize=18); ax.set_ylabel(r'$f_2(x)$',fontsize=18)
ax.legend(loc='upper right'); ax.grid(True)
plt.tight_layout(); plt.show()
# Out:
# === Início 1 ===
# Iter ex  0: ||d||=0.00e+00  tau=1.00e+00  ‖x∘y‖=1.00e+00  ΔF=9.00e+00
# Iter ex  1: ||d||=0.00e+00  tau=1.00e+01  ‖x∘y‖=2.00e-14  ΔF=7.07e+00
# Iter ex  2: ||d||=0.00e+00  tau=1.00e+02  ‖x∘y‖=2.00e-14  ΔF=0.00e+00
# · Critério externo satisfeito ·
# F(z*) = [ 0.76575975 -1.87507699]
#
# === Início 2 ===
# Iter ex  0: ||d||=0.00e+00  tau=1.00e+00  ‖x∘y‖=1.00e+00  ΔF=1.75e+01
# Iter ex  1: ||d||=0.00e+00  tau=1.00e+01  ‖x∘y‖=2.15e-14  ΔF=7.07e+00
# Iter ex  2: ||d||=0.00e+00  tau=1.00e+02  ‖x∘y‖=2.15e-14  ΔF=0.00e+00
# · Critério externo satisfeito ·
# F(z*) = [ 6.58795124 -3.56670046]
#
# === Início 3 ===
# Iter ex  0: ||d||=0.00e+00  tau=1.00e+00  ‖x∘y‖=1.00e+00  ΔF=2.40e+00
# Iter ex  1: ||d||=0.00e+00  tau=1.00e+01  ‖x∘y‖=4.16e-15  ΔF=7.07e+00
# Iter ex  2: ||d||=0.00e+00  tau=1.00e+02  ‖x∘y‖=4.16e-15  ΔF=0.00e+00
# · Critério externo satisfeito ·
# F(z*) = [ 0.00519493 -1.07207583]
#
# === Início 4 ===
# Iter ex  0: ||d||=0.00e+00  tau=1.00e+00  ‖x∘y‖=1.00e+00  ΔF=1.93e+01
# Iter ex  1: ||d||=0.00e+00  tau=1.00e+01  ‖x∘y‖=1.34e-15  ΔF=7.07e+00
# Iter ex  2: ||d||=0.00e+00  tau=1.00e+02  ‖x∘y‖=1.34e-15  ΔF=0.00e+00
# · Critério externo satisfeito ·
# F(z*) = [ 3.38281843 -2.83924398]
#
# === Início 5 ===
# Iter ex  0: ||d||=0.00e+00  tau=1.00e+00  ‖x∘y‖=1.00e+00  ΔF=4.88e+00
# Iter ex  1: ||d||=0.00e+00  tau=1.00e+01  ‖x∘y‖=4.62e-14  ΔF=7.14e+00
# Iter ex  2: ||d||=0.00e+00  tau=1.00e+02  ‖x∘y‖=4.62e-14  ΔF=0.00e+00
# · Critério externo satisfeito ·
# F(z*) = [ 0.01408092 -1.11866306]
#
# === Início 6 ===
# Iter ex  0: ||d||=0.00e+00  tau=1.00e+00  ‖x∘y‖=1.00e+00  ΔF=4.12e+00
# Iter ex  1: ||d||=0.00e+00  tau=1.00e+01  ‖x∘y‖=3.25e-16  ΔF=7.07e+00
# Iter ex  2: ||d||=0.00e+00  tau=1.00e+02  ‖x∘y‖=3.25e-16  ΔF=0.00e+00
# · Critério externo satisfeito ·
# F(z*) = [ 0.4612057  -1.67912127]
#
# === Início 7 ===
# Iter ex  0: ||d||=0.00e+00  tau=1.00e+00  ‖x∘y‖=1.00e+00  ΔF=7.56e+00
# Iter ex  1: ||d||=0.00e+00  tau=1.00e+01  ‖x∘y‖=8.21e-15  ΔF=7.07e+00
# Iter ex  2: ||d||=0.00e+00  tau=1.00e+02  ‖x∘y‖=8.21e-15  ΔF=0.00e+00
# · Critério externo satisfeito ·
# F(z*) = [ 6.96802858 -3.63970237]
#
# === Início 8 ===
# Iter ex  0: ||d||=0.00e+00  tau=1.00e+00  ‖x∘y‖=1.00e+00  ΔF=1.55e+00
# Iter ex  1: ||d||=0.00e+00  tau=1.00e+01  ‖x∘y‖=1.00e-01  ΔF=7.14e+00
# Iter ex  2: ||d||=0.00e+00  tau=1.00e+02  ‖x∘y‖=1.47e-06  ΔF=7.07e-01
# Iter ex  3: ||d||=0.00e+00  tau=1.00e+03  ‖x∘y‖=5.00e-08  ΔF=1.73e-09
# · Critério externo satisfeito ·
# F(z*) = [ 3.36239519 -2.8336835 ]
#
# === Início 9 ===
# Iter ex  0: ||d||=0.00e+00  tau=1.00e+00  ‖x∘y‖=1.41e+00  ΔF=6.47e+00
# Iter ex  1: ||d||=0.00e+00  tau=1.00e+01  ‖x∘y‖=2.26e-15  ΔF=1.41e+01
# Iter ex  2: ||d||=0.00e+00  tau=1.00e+02  ‖x∘y‖=2.26e-15  ΔF=0.00e+00
# · Critério externo satisfeito ·
# F(z*) = [ 2.23708468 -2.4956887 ]
#
# === Início 10 ===
# Iter ex  0: ||d||=0.00e+00  tau=1.00e+00  ‖x∘y‖=1.00e+00  ΔF=2.98e+00
# Iter ex  1: ||d||=1.18e-05  tau=1.00e+01  ‖x∘y‖=1.00e-01  ΔF=7.14e+00
# Iter ex  2: ||d||=0.00e+00  tau=1.00e+02  ‖x∘y‖=2.12e-16  ΔF=7.07e-01
# Iter ex  3: ||d||=0.00e+00  tau=1.00e+03  ‖x∘y‖=2.12e-16  ΔF=0.00e+00
# · Critério externo satisfeito ·
# F(z*) = [ 3.1893643  -2.78587914]
#
# === Início 11 ===
# Iter ex  0: ||d||=0.00e+00  tau=1.00e+00  ‖x∘y‖=1.00e+00  ΔF=4.33e+00
# Iter ex  1: ||d||=0.00e+00  tau=1.00e+01  ‖x∘y‖=3.75e-15  ΔF=7.07e+00
# Iter ex  2: ||d||=0.00e+00  tau=1.00e+02  ‖x∘y‖=3.75e-15  ΔF=0.00e+00
# · Critério externo satisfeito ·
# F(z*) = [ 2.95185107 -2.71809519]
#
# === Início 12 ===
# Iter ex  0: ||d||=0.00e+00  tau=1.00e+00  ‖x∘y‖=1.41e+00  ΔF=7.46e+00
# Iter ex  1: ||d||=0.00e+00  tau=1.00e+01  ‖x∘y‖=2.79e-14  ΔF=1.41e+01
# Iter ex  2: ||d||=0.00e+00  tau=1.00e+02  ‖x∘y‖=2.79e-14  ΔF=0.00e+00
# · Critério externo satisfeito ·
# F(z*) = [ 5.3893671  -3.32150105]
#
# === Início 13 ===
# Iter ex  0: ||d||=0.00e+00  tau=1.00e+00  ‖x∘y‖=1.00e+00  ΔF=5.47e+00
# Iter ex  1: ||d||=0.00e+00  tau=1.00e+01  ‖x∘y‖=2.00e-11  ΔF=7.07e+00
# Iter ex  2: ||d||=0.00e+00  tau=1.00e+02  ‖x∘y‖=2.00e-11  ΔF=0.00e+00
# · Critério externo satisfeito ·
# F(z*) = [ 4.35733281 -3.08742253]
#
# === Início 14 ===
# Iter ex  0: ||d||=0.00e+00  tau=1.00e+00  ‖x∘y‖=1.00e+00  ΔF=3.23e+00
# Iter ex  1: ||d||=0.00e+00  tau=1.00e+01  ‖x∘y‖=1.00e-01  ΔF=7.12e+00
# Iter ex  2: ||d||=0.00e+00  tau=1.00e+02  ‖x∘y‖=1.47e-06  ΔF=7.07e-01
# Iter ex  3: ||d||=0.00e+00  tau=1.00e+03  ‖x∘y‖=5.00e-08  ΔF=1.73e-09
# · Critério externo satisfeito ·
# F(z*) = [ 0.01027241 -1.10135289]
#
# === Início 15 ===
# Iter ex  0: ||d||=0.00e+00  tau=1.00e+00  ‖x∘y‖=1.00e+00  ΔF=9.39e+00
# Iter ex  1: ||d||=0.00e+00  tau=1.00e+01  ‖x∘y‖=1.00e-01  ΔF=7.14e+00
# Iter ex  2: ||d||=0.00e+00  tau=1.00e+02  ‖x∘y‖=1.63e-06  ΔF=7.07e-01
# Iter ex  3: ||d||=0.00e+00  tau=1.00e+03  ‖x∘y‖=6.46e-08  ΔF=2.09e-09
# · Critério externo satisfeito ·
# F(z*) = [ 0.12963261 -1.36004529]
#
# === Início 16 ===
# Iter ex  0: ||d||=0.00e+00  tau=1.00e+00  ‖x∘y‖=1.00e+00  ΔF=2.67e+00
# Iter ex  1: ||d||=0.00e+00  tau=1.00e+01  ‖x∘y‖=0.00e+00  ΔF=7.07e+00
# Iter ex  2: ||d||=0.00e+00  tau=1.00e+02  ‖x∘y‖=0.00e+00  ΔF=0.00e+00
# · Critério externo satisfeito ·
# F(z*) = [ 0.00149827 -1.03870748]
#
# === Início 17 ===
# Iter ex  0: ||d||=0.00e+00  tau=1.00e+00  ‖x∘y‖=1.41e+00  ΔF=4.13e+00
# Iter ex  1: ||d||=0.00e+00  tau=1.00e+01  ‖x∘y‖=6.02e-16  ΔF=1.41e+01
# Iter ex  2: ||d||=0.00e+00  tau=1.00e+02  ‖x∘y‖=6.02e-16  ΔF=0.00e+00
# · Critério externo satisfeito ·
# F(z*) = [ 5.76619416 -3.4012901 ]
#
# === Início 18 ===
# Iter ex  0: ||d||=0.00e+00  tau=1.00e+00  ‖x∘y‖=1.00e+00  ΔF=9.20e+00
# Iter ex  1: ||d||=0.00e+00  tau=1.00e+01  ‖x∘y‖=7.39e-15  ΔF=7.07e+00
# Iter ex  2: ||d||=0.00e+00  tau=1.00e+02  ‖x∘y‖=7.39e-15  ΔF=0.00e+00
# · Critério externo satisfeito ·
# F(z*) = [ 0.11487489 -1.33893198]
#
# === Início 19 ===
# Iter ex  0: ||d||=0.00e+00  tau=1.00e+00  ‖x∘y‖=1.00e+00  ΔF=1.07e+01
# Iter ex  1: ||d||=0.00e+00  tau=1.00e+01  ‖x∘y‖=2.03e-15  ΔF=7.07e+00
# Iter ex  2: ||d||=0.00e+00  tau=1.00e+02  ‖x∘y‖=2.03e-15  ΔF=0.00e+00
# · Critério externo satisfeito ·
# F(z*) = [ 1.1340947  -2.06493883]
#
# === Início 20 ===
# Iter ex  0: ||d||=0.00e+00  tau=1.00e+00  ‖x∘y‖=1.00e+00  ΔF=1.49e+01
# Iter ex  1: ||d||=0.00e+00  tau=1.00e+01  ‖x∘y‖=1.27e-12  ΔF=7.07e+00
# Iter ex  2: ||d||=0.00e+00  tau=1.00e+02  ‖x∘y‖=1.27e-12  ΔF=0.00e+00
# · Critério externo satisfeito ·
# F(z*) = [ 3.52758065 -2.87818547]
#
# === Início 21 ===
# Iter ex  0: ||d||=0.00e+00  tau=1.00e+00  ‖x∘y‖=1.00e+00  ΔF=1.16e+01
# Iter ex  1: ||d||=5.64e-05  tau=1.00e+01  ‖x∘y‖=1.00e-01  ΔF=7.14e+00
# Iter ex  2: ||d||=0.00e+00  tau=1.00e+02  ‖x∘y‖=1.61e-16  ΔF=7.07e-01
# Iter ex  3: ||d||=0.00e+00  tau=1.00e+03  ‖x∘y‖=1.61e-16  ΔF=0.00e+00
# · Critério externo satisfeito ·
# F(z*) = [ 5.45657248 -3.33593075]
#
# === Início 22 ===
# Iter ex  0: ||d||=0.00e+00  tau=1.00e+00  ‖x∘y‖=1.00e+00  ΔF=5.45e+00
# Iter ex  1: ||d||=1.32e-05  tau=1.00e+01  ‖x∘y‖=1.00e-01  ΔF=7.14e+00
# Iter ex  2: ||d||=0.00e+00  tau=1.00e+02  ‖x∘y‖=1.02e-15  ΔF=7.07e-01
# Iter ex  3: ||d||=0.00e+00  tau=1.00e+03  ‖x∘y‖=1.02e-15  ΔF=0.00e+00
# · Critério externo satisfeito ·
# F(z*) = [ 3.27829909 -2.81060738]
#
# === Início 23 ===
# Iter ex  0: ||d||=0.00e+00  tau=1.00e+00  ‖x∘y‖=1.00e+00  ΔF=7.17e+00
# Iter ex  1: ||d||=1.09e-05  tau=1.00e+01  ‖x∘y‖=1.00e-01  ΔF=7.14e+00
# Iter ex  2: ||d||=0.00e+00  tau=1.00e+02  ‖x∘y‖=1.77e-15  ΔF=7.07e-01
# Iter ex  3: ||d||=0.00e+00  tau=1.00e+03  ‖x∘y‖=1.77e-15  ΔF=0.00e+00
# · Critério externo satisfeito ·
# F(z*) = [ 1.29056535 -2.13603052]
#
# === Início 24 ===
# Iter ex  0: ||d||=0.00e+00  tau=1.00e+00  ‖x∘y‖=1.00e+00  ΔF=1.80e+01
# Iter ex  1: ||d||=0.00e+00  tau=1.00e+01  ‖x∘y‖=3.48e-15  ΔF=7.49e+00
# Iter ex  2: ||d||=0.00e+00  tau=1.00e+02  ‖x∘y‖=3.48e-15  ΔF=0.00e+00
# · Critério externo satisfeito ·
# F(z*) = [ 0.57905026 -1.76095352]
#
# === Início 25 ===
# Iter ex  0: ||d||=0.00e+00  tau=1.00e+00  ‖x∘y‖=1.00e+00  ΔF=8.81e+00
# Iter ex  1: ||d||=0.00e+00  tau=1.00e+01  ‖x∘y‖=1.00e-01  ΔF=7.22e+00
# Iter ex  2: ||d||=0.00e+00  tau=1.00e+02  ‖x∘y‖=1.47e-06  ΔF=7.07e-01
# Iter ex  3: ||d||=0.00e+00  tau=1.00e+03  ‖x∘y‖=5.00e-08  ΔF=1.73e-09
# · Critério externo satisfeito ·
# F(z*) = [ 0.18022705 -1.42453156]
#
# === Início 26 ===
# Iter ex  0: ||d||=0.00e+00  tau=1.00e+00  ‖x∘y‖=1.00e+00  ΔF=3.48e+00
# Iter ex  1: ||d||=0.00e+00  tau=1.00e+01  ‖x∘y‖=7.21e-15  ΔF=7.07e+00
# Iter ex  2: ||d||=0.00e+00  tau=1.00e+02  ‖x∘y‖=7.21e-15  ΔF=0.00e+00
# · Critério externo satisfeito ·
# F(z*) = [ 0.17038301 -1.41277477]
#
# === Início 27 ===
# Iter ex  0: ||d||=0.00e+00  tau=1.00e+00  ‖x∘y‖=1.00e+00  ΔF=7.07e+00
# Iter ex  1: ||d||=0.00e+00  tau=1.00e+01  ‖x∘y‖=1.00e-01  ΔF=7.30e+00
# Iter ex  2: ||d||=0.00e+00  tau=1.00e+02  ‖x∘y‖=1.47e-06  ΔF=7.07e-01
# Iter ex  3: ||d||=0.00e+00  tau=1.00e+03  ‖x∘y‖=5.00e-08  ΔF=1.73e-09
# · Critério externo satisfeito ·
# F(z*) = [ 0.27418946 -1.52363103]
#
# === Início 28 ===
# Iter ex  0: ||d||=0.00e+00  tau=1.00e+00  ‖x∘y‖=1.00e+00  ΔF=4.16e+00
# Iter ex  1: ||d||=0.00e+00  tau=1.00e+01  ‖x∘y‖=1.53e-14  ΔF=7.07e+00
# Iter ex  2: ||d||=0.00e+00  tau=1.00e+02  ‖x∘y‖=1.53e-14  ΔF=0.00e+00
# · Critério externo satisfeito ·
# F(z*) = [ 8.49329176 -3.91432527]
#
# === Início 29 ===
# Iter ex  0: ||d||=0.00e+00  tau=1.00e+00  ‖x∘y‖=1.00e+00  ΔF=2.68e+00
# Iter ex  1: ||d||=0.00e+00  tau=1.00e+01  ‖x∘y‖=4.34e-15  ΔF=7.07e+00
# Iter ex  2: ||d||=0.00e+00  tau=1.00e+02  ‖x∘y‖=4.34e-15  ΔF=0.00e+00
# · Critério externo satisfeito ·
# F(z*) = [ 1.7519914  -2.32362812]
#
# === Início 30 ===
# Iter ex  0: ||d||=0.00e+00  tau=1.00e+00  ‖x∘y‖=1.00e+00  ΔF=2.64e+00
# Iter ex  1: ||d||=0.00e+00  tau=1.00e+01  ‖x∘y‖=6.14e-09  ΔF=7.07e+00
# Iter ex  2: ||d||=0.00e+00  tau=1.00e+02  ‖x∘y‖=6.14e-09  ΔF=0.00e+00
# · Critério externo satisfeito ·
# F(z*) = [ 0.50229946 -1.70873088]
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
